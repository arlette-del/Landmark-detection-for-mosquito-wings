# %% [markdown]
# setup/ import

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import random
import os

import tensorflow as tf

import wandb
from wandb.integration.keras import WandbMetricsLogger, WandbCallback, WandbModelCheckpoint

from sklearn.model_selection import train_test_split

from tensorflow.keras.layers import Dense, Input
from tensorflow.keras.models import Model
from tensorflow.keras.callbacks import EarlyStopping
from tensorflow.keras import layers, Model
from tensorflow.keras.callbacks import ReduceLROnPlateau

# %%
print('Tensorflow version:', tf.__version__)
print('Weights and biases version:', wandb.__version__)
# Out:
# Tensorflow version: 2.19.0
# Weights and biases version: 0.21.1

# %% [markdown]
# load data

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
X_train = np.load('/content/drive/MyDrive/Arlette/Sets for Training /Dataset with iPhone/reduced datasets/train_aug_images_160x320_25.npy')
X_val = np.load('/content/drive/MyDrive/Arlette/Sets for Training /Dataset with iPhone/val_images_160x320.npy')
X_test = np.load('/content/drive/MyDrive/Arlette/Sets for Training /Dataset with iPhone/test_images_160x320.npy')

y_train_heatmaps = np.load('/content/drive/MyDrive/Arlette/Sets for Training /Dataset with iPhone/train_aug_heatmaps_40x80_25.npy')
y_val_heatmaps = np.load('/content/drive/MyDrive/Arlette/Sets for Training /Dataset with iPhone/val_heatmaps_40x80.npy')
y_test_heatmaps = np.load('/content/drive/MyDrive/Arlette/Sets for Training /Dataset with iPhone/test_heatmaps_40x80.npy')

# %%
print(X_train.shape)
print(y_train_heatmaps.shape)
# Out:
# (740, 160, 320, 3)
# (740, 40, 80, 18)

# %% [markdown]
# define hyperparameters

# %%
def get_config(model_name='unet_with_iPhone_full_augmentation_25_dataset',
               img_size=(160, 320),
               batch_size=16,
               learning_rate_transfer=1e-3,
               learning_rate_tuning=1e-5,
               max_epochs_transfer=50,
               max_epochs_tuning=100,
               early_stop_patience=10,
               steps_per_epoch=81,
               dropout=0.5,
               seed=42):

    # cosine decay
    cosine_decay_steps = steps_per_epoch * max_epochs_tuning
    learning_schedule = {
        'initial_learning_rate': learning_rate_tuning,
        'decay_steps': cosine_decay_steps,
        'warmup_target': learning_rate_tuning,
        'warmup_steps': int(cosine_decay_steps * 0.02)
    }

    # config dictionary
    config = {
        'model_name': model_name,
        'img_size': img_size,
        'batch_size': batch_size,
        'learning_rate_transfer': learning_rate_transfer,
        'learning_rate_tuning': learning_rate_tuning,
        'max_epochs_transfer': max_epochs_transfer,
        'max_epochs_tuning': max_epochs_tuning,
        'early_stop_patience': early_stop_patience,
        'steps_per_epoch': steps_per_epoch,
        'cosine_decay_steps': cosine_decay_steps,
        'dropout': dropout,
        'learning_schedule': learning_schedule,
        'seed': seed
    }

    return config

# %%
config = get_config()
SEED = config['seed']
img_size = config['img_size']
batch_size = config['batch_size']
seed = config['seed']

# %% [markdown]
# create tensorflow datasets

# %%
train_dataset = tf.data.Dataset.from_tensor_slices((X_train, y_train_heatmaps))
train_dataset = train_dataset.shuffle(buffer_size=1000).batch(batch_size).prefetch(tf.data.AUTOTUNE)

val_dataset = tf.data.Dataset.from_tensor_slices((X_val, y_val_heatmaps)).batch(batch_size).prefetch(tf.data.AUTOTUNE)
test_dataset = tf.data.Dataset.from_tensor_slices((X_test, y_test_heatmaps)).batch(batch_size).prefetch(tf.data.AUTOTUNE)

# %% [markdown]
# define metrics // convert heatmap to coords

# %%
# loss
class BCEDiceLoss(tf.keras.losses.Loss):
    def __init__(self, alpha=0.5, smooth=1e-6, name="bce_dice_loss"):
        super().__init__(name=name)
        self.alpha = alpha
        self.smooth = smooth

    def call(self, y_true, y_pred):
        # Cclamp predictions
        y_pred = tf.clip_by_value(y_pred, 1e-6, 1.0 - 1e-6)

        # BCE
        bce = tf.keras.losses.binary_crossentropy(y_true, y_pred)
        bce = tf.reduce_mean(bce)

        # dice
        intersection = tf.reduce_sum(y_true * y_pred, axis=[1,2])
        pred_sum = tf.reduce_sum(y_pred, axis=[1,2])
        target_sum = tf.reduce_sum(y_true, axis=[1,2])
        dice = (2.0 * intersection + self.smooth) / (pred_sum + target_sum + self.smooth)
        dice_loss = 1.0 - dice
        dice_loss = tf.reduce_mean(dice_loss)

        # combine
        loss = self.alpha * bce + (1.0 - self.alpha) * dice_loss
        return loss

# metric

# converts heatmaps in pixel coords, based on highest value (argmax)
def heatmaps_to_pixel_coords(y_heatmaps, img_size=(160,320)):
    H_img, W_img = img_size
    B,H,W,C = tf.unstack(tf.shape(y_heatmaps))

    y_flat = tf.reshape(y_heatmaps, [B, H*W, C])
    idx = tf.argmax(y_flat, axis=1, output_type=tf.int32)  # [B,C]

    x = tf.cast(idx % W, tf.float32) / tf.cast(W-1, tf.float32) * tf.cast(W_img-1, tf.float32)
    y = tf.cast(idx // W, tf.float32) / tf.cast(H-1, tf.float32) * tf.cast(H_img-1, tf.float32)

    coords = tf.stack([x,y], axis=-1)  # [B,C,2]
    return coords

# mean pixel distance (euclidean dsitance) between ground truth and predicted landamarks on img size
def mean_pixel_error(y_true, y_pred, img_size=(160,320)):
    y_true_coords = heatmaps_to_pixel_coords(y_true, img_size)
    y_pred_coords = heatmaps_to_pixel_coords(y_pred, img_size)

    dist = tf.sqrt(tf.reduce_sum(tf.square(y_true_coords - y_pred_coords), axis=-1))  # [B,C]
    return tf.reduce_mean(dist)  # scalar

# %% [markdown]
# define model

# %%
def build_compact_unet_40x80(input_shape=(160,320,3), num_landmarks=18):
    inputs = layers.Input(shape=input_shape)

    # encoder
    c1 = layers.Conv2D(32, 3, activation='relu', padding='same')(inputs)
    c1 = layers.Conv2D(32, 3, activation='relu', padding='same')(c1)
    p1 = layers.MaxPooling2D((2,2))(c1)  # 80x160

    c2 = layers.Conv2D(64, 3, activation='relu', padding='same')(p1)
    c2 = layers.Conv2D(64, 3, activation='relu', padding='same')(c2)
    p2 = layers.MaxPooling2D((2,2))(c2)  # 40x80

    # bottleneck
    b = layers.Conv2D(128, 3, activation='relu', padding='same')(p2)
    b = layers.Conv2D(128, 3, activation='relu', padding='same')(b)

    # decoder
    u1 = layers.UpSampling2D((2,2), interpolation='bilinear')(b)  # 80x160
    u1 = layers.Concatenate()([u1, c2])
    u1 = layers.Conv2D(64, 3, activation='relu', padding='same')(u1)
    u1 = layers.Conv2D(64, 3, activation='relu', padding='same')(u1)
    u1 = layers.Dropout(0.1)(u1)

    u2 = layers.UpSampling2D((2,2), interpolation='bilinear')(u1)  # 160x320
    u2 = layers.Concatenate()([u2, c1])
    u2 = layers.Conv2D(32, 3, activation='relu', padding='same')(u2)
    u2 = layers.Conv2D(32, 3, activation='relu', padding='same')(u2)
    u2 = layers.Dropout(0.1)(u2)

    # output 40x80
    out = layers.Conv2D(num_landmarks, 1, activation='sigmoid', padding='same')(u2)
    out = layers.AveragePooling2D(pool_size=(4,4))(out)  # 160/4=40, 320/4=80

    model = Model(inputs, out)
    return model

# %%
input_shape = (160, 320, 3)
num_landmarks = 18

model = build_compact_unet_40x80(input_shape=input_shape, num_landmarks=num_landmarks)

# loss bce + loss (0.5)
loss_fn = BCEDiceLoss(alpha=0.5)

# compile
model.compile(optimizer=tf.keras.optimizers.Adam(learning_rate=config['learning_rate_transfer']),
              loss=loss_fn,
              metrics=[mean_pixel_error])

model.summary()
# Out:
# Model: "functional"
# ┏━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)        ┃ Output Shape      ┃    Param # ┃ Connected to      ┃
# ┡━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━┩
# │ input_layer         │ (None, 160, 320,  │          0 │ -                 │
# │ (InputLayer)        │ 3)                │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d (Conv2D)     │ (None, 160, 320,  │        896 │ input_layer[0][0] │
# │                     │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_1 (Conv2D)   │ (None, 160, 320,  │      9,248 │ conv2d[0][0]      │
# │                     │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ max_pooling2d       │ (None, 80, 160,   │          0 │ conv2d_1[0][0]    │
# │ (MaxPooling2D)      │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_2 (Conv2D)   │ (None, 80, 160,   │     18,496 │ max_pooling2d[0]… │
# │                     │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_3 (Conv2D)   │ (None, 80, 160,   │     36,928 │ conv2d_2[0][0]    │
# │                     │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ max_pooling2d_1     │ (None, 40, 80,    │          0 │ conv2d_3[0][0]    │
# │ (MaxPooling2D)      │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_4 (Conv2D)   │ (None, 40, 80,    │     73,856 │ max_pooling2d_1[… │
# │                     │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_5 (Conv2D)   │ (None, 40, 80,    │    147,584 │ conv2d_4[0][0]    │
# │                     │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ up_sampling2d       │ (None, 80, 160,   │          0 │ conv2d_5[0][0]    │
# │ (UpSampling2D)      │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ concatenate         │ (None, 80, 160,   │          0 │ up_sampling2d[0]… │
# │ (Concatenate)       │ 192)              │            │ conv2d_3[0][0]    │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_6 (Conv2D)   │ (None, 80, 160,   │    110,656 │ concatenate[0][0] │
# │                     │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_7 (Conv2D)   │ (None, 80, 160,   │     36,928 │ conv2d_6[0][0]    │
# │                     │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dropout (Dropout)   │ (None, 80, 160,   │          0 │ conv2d_7[0][0]    │
# │                     │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ up_sampling2d_1     │ (None, 160, 320,  │          0 │ dropout[0][0]     │
# │ (UpSampling2D)      │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ concatenate_1       │ (None, 160, 320,  │          0 │ up_sampling2d_1[… │
# │ (Concatenate)       │ 96)               │            │ conv2d_1[0][0]    │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_8 (Conv2D)   │ (None, 160, 320,  │     27,680 │ concatenate_1[0]… │
# │                     │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_9 (Conv2D)   │ (None, 160, 320,  │      9,248 │ conv2d_8[0][0]    │
# │                     │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dropout_1 (Dropout) │ (None, 160, 320,  │          0 │ conv2d_9[0][0]    │
# │                     │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_10 (Conv2D)  │ (None, 160, 320,  │        594 │ dropout_1[0][0]   │
# │                     │ 18)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ average_pooling2d   │ (None, 40, 80,    │          0 │ conv2d_10[0][0]   │
# │ (AveragePooling2D)  │ 18)               │            │                   │
# └─────────────────────┴───────────────────┴────────────┴───────────────────┘
#  Total params: 472,114 (1.80 MB)
#  Trainable params: 472,114 (1.80 MB)
#  Non-trainable params: 0 (0.00 B)

# %%
wandb.init(project='mosquito_landmarks',name=f"{config['model_name']}_transfer",config=config)

early_stopping = EarlyStopping(
    monitor='val_loss',
    mode='min',
    patience=config['early_stop_patience'],
    restore_best_weights=True,
    verbose=1)

reduce_lr = ReduceLROnPlateau(
    monitor='val_loss',
    factor=0.5,
    patience=5,
    min_lr=1e-6,
    verbose=1,
    mode='min')

callbacks = [
    early_stopping,
    reduce_lr,
    WandbMetricsLogger(),
    WandbModelCheckpoint("wandb_model.keras")]
# Out:
# /usr/local/lib/python3.12/dist-packages/notebook/notebookapp.py:191: SyntaxWarning: invalid escape sequence '\/'
#   | |_| | '_ \/ _` / _` |  _/ -_)
# wandb: Logging into wandb.ai. (Learn how to deploy a W&B server locally: https://wandb.me/wandb-server)
# wandb: You can find your API key in your browser here: https://wandb.ai/authorize?ref=models
# wandb: Paste an API key from your profile and hit enter:
#  ··········
# wandb: WARNING If you're specifying your api key in code, ensure this code is not shared publicly.
# wandb: WARNING Consider setting the WANDB_API_KEY environment variable, or running `wandb login` from the command line.
# wandb: No netrc file found, creating one.
# wandb: Appending key for api.wandb.ai to your netrc file: /root/.netrc
# wandb: Currently logged in as: arlettedel (arlettedel-universit-t-hamburg) to https://api.wandb.ai. Use `wandb login --relogin` to force relogin
# Tracking run with wandb version 0.21.1
# Run data is saved locally in <code>/content/wandb/run-20250829_221339-3swf9ebo</code>
# Syncing run <strong><a href='https://wandb.ai/arlettedel-universit-t-hamburg/mosquito_landmarks/runs/3swf9ebo' target="_blank">unet_with_iPhone_full_augmentation_25_dataset_transfer</a></strong> to <a href='https://wandb.ai/arlettedel-universit-t-hamburg/mosquito_landmarks' target="_blank">Weights & Biases</a> (<a href='https://wandb.me/developer-guide' target="_blank">docs</a>)<br>
#  View project at <a href='https://wandb.ai/arlettedel-universit-t-hamburg/mosquito_landmarks' target="_blank">https://wandb.ai/arlettedel-universit-t-hamburg/mosquito_landmarks</a>
#  View run at <a href='https://wandb.ai/arlettedel-universit-t-hamburg/mosquito_landmarks/runs/3swf9ebo' target="_blank">https://wandb.ai/arlettedel-universit-t-hamburg/mosquito_landmarks/runs/3swf9ebo</a>

# %%
history = model.fit(train_dataset, validation_data=val_dataset,
                    epochs=config['max_epochs_transfer'],
                    callbacks=callbacks,
                    verbose=1)
# Out:
# Epoch 1/50
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 64s 807ms/step - loss: 0.7003 - mean_pixel_error: 137.5793 - val_loss: 0.5538 - val_mean_pixel_error: 186.0718 - learning_rate: 0.0010
# Epoch 2/50
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 14s 307ms/step - loss: 0.5494 - mean_pixel_error: 130.5152 - val_loss: 0.5538 - val_mean_pixel_error: 185.2484 - learning_rate: 0.0010
# Epoch 3/50
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 14s 307ms/step - loss: 0.5491 - mean_pixel_error: 131.2142 - val_loss: 0.5544 - val_mean_pixel_error: 187.8748 - learning_rate: 0.0010
# Epoch 4/50
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 14s 308ms/step - loss: 0.5489 - mean_pixel_error: 131.3521 - val_loss: 0.5537 - val_mean_pixel_error: 185.4383 - learning_rate: 0.0010
# Epoch 5/50
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 15s 311ms/step - loss: 0.5496 - mean_pixel_error: 126.8382 - val_loss: 0.5507 - val_mean_pixel_error: 149.5133 - learning_rate: 0.0010
# Epoch 6/50
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 15s 314ms/step - loss: 0.5352 - mean_pixel_error: 135.5534 - val_loss: 0.4851 - val_mean_pixel_error: 126.1249 - learning_rate: 0.0010
# Epoch 7/50
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 15s 313ms/step - loss: 0.4875 - mean_pixel_error: 92.7520 - val_loss: 0.4725 - val_mean_pixel_error: 113.6864 - learning_rate: 0.0010
# Epoch 8/50
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 15s 314ms/step - loss: 0.4554 - mean_pixel_error: 73.5179 - val_loss: 0.4460 - val_mean_pixel_error: 75.1807 - learning_rate: 0.0010
# Epoch 9/50
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 15s 315ms/step - loss: 0.4365 - mean_pixel_error: 60.4452 - val_loss: 0.4487 - val_mean_pixel_error: 53.0300 - learning_rate: 0.0010
# Epoch 10/50
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 15s 316ms/step - loss: 0.4264 - mean_pixel_error: 54.4002 - val_loss: 0.4162 - val_mean_pixel_error: 53.9715 - learning_rate: 0.0010
# Epoch 11/50
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 15s 317ms/step - loss: 0.4124 - mean_pixel_error: 48.1826 - val_loss: 0.4049 - val_mean_pixel_error: 51.7701 - learning_rate: 0.0010
# Epoch 12/50
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 15s 317ms/step - loss: 0.3933 - mean_pixel_error: 36.1398 - val_loss: 0.3745 - val_mean_pixel_error: 36.4198 - learning_rate: 0.0010
# Epoch 13/50
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 15s 318ms/step - loss: 0.3712 - mean_pixel_error: 27.0779 - val_loss: 0.3527 - val_mean_pixel_error: 24.4013 - learning_rate: 0.0010
# Epoch 14/50
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 15s 318ms/step - loss: 0.3515 - mean_pixel_error: 22.6209 - val_loss: 0.3419 - val_mean_pixel_error: 19.5239 - learning_rate: 0.0010
# Epoch 15/50
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 15s 319ms/step - loss: 0.3404 - mean_pixel_error: 20.5170 - val_loss: 0.3173 - val_mean_pixel_error: 17.3717 - learning_rate: 0.0010
# Epoch 16/50
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 15s 320ms/step - loss: 0.3188 - mean_pixel_error: 15.0471 - val_loss: 0.3065 - val_mean_pixel_error: 13.5782 - learning_rate: 0.0010
# Epoch 17/50
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 15s 320ms/step - loss: 0.3098 - mean_pixel_error: 13.4950 - val_loss: 0.2919 - val_mean_pixel_error: 9.8632 - learning_rate: 0.0010
# Epoch 18/50
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 15s 319ms/step - loss: 0.2911 - mean_pixel_error: 10.6623 - val_loss: 0.2795 - val_mean_pixel_error: 10.0935 - learning_rate: 0.0010
# Epoch 19/50
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 15s 321ms/step - loss: 0.2814 - mean_pixel_error: 9.2286 - val_loss: 0.2817 - val_mean_pixel_error: 9.2167 - learning_rate: 0.0010
# Epoch 20/50
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 15s 319ms/step - loss: 0.2748 - mean_pixel_error: 8.3202 - val_loss: 0.2657 - val_mean_pixel_error: 6.9377 - learning_rate: 0.0010
# Epoch 21/50
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 15s 320ms/step - loss: 0.2654 - mean_pixel_error: 7.1972 - val_loss: 0.2566 - val_mean_pixel_error: 7.5042 - learning_rate: 0.0010
# Epoch 22/50
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 15s 320ms/step - loss: 0.2548 - mean_pixel_error: 6.7373 - val_loss: 0.2515 - val_mean_pixel_error: 6.2481 - learning_rate: 0.0010
# Epoch 23/50
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 15s 321ms/step - loss: 0.2533 - mean_pixel_error: 6.8642 - val_loss: 0.2471 - val_mean_pixel_error: 5.6647 - learning_rate: 0.0010
# Epoch 24/50
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 15s 320ms/step - loss: 0.2454 - mean_pixel_error: 6.1329 - val_loss: 0.2482 - val_mean_pixel_error: 6.3737 - learning_rate: 0.0010
# Epoch 25/50
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 15s 321ms/step - loss: 0.2440 - mean_pixel_error: 6.1682 - val_loss: 0.2482 - val_mean_pixel_error: 5.8915 - learning_rate: 0.0010
# Epoch 26/50
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 15s 321ms/step - loss: 0.2441 - mean_pixel_error: 5.9334 - val_loss: 0.2379 - val_mean_pixel_error: 5.3649 - learning_rate: 0.0010
# Epoch 27/50
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 15s 321ms/step - loss: 0.2360 - mean_pixel_error: 5.6310 - val_loss: 0.2361 - val_mean_pixel_error: 5.3188 - learning_rate: 0.0010
# Epoch 28/50
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 15s 321ms/step - loss: 0.2361 - mean_pixel_error: 5.9293 - val_loss: 0.2360 - val_mean_pixel_error: 5.1545 - learning_rate: 0.0010
# Epoch 29/50
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 15s 320ms/step - loss: 0.2325 - mean_pixel_error: 5.4188 - val_loss: 0.2345 - val_mean_pixel_error: 5.3285 - learning_rate: 0.0010
# Epoch 30/50
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 15s 321ms/step - loss: 0.2299 - mean_pixel_error: 5.2701 - val_loss: 0.2361 - val_mean_pixel_error: 5.1804 - learning_rate: 0.0010
# Epoch 31/50
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 15s 321ms/step - loss: 0.2287 - mean_pixel_error: 5.2806 - val_loss: 0.2299 - val_mean_pixel_error: 4.7625 - learning_rate: 0.0010
# Epoch 32/50
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 15s 322ms/step - loss: 0.2277 - mean_pixel_error: 5.1379 - val_loss: 0.2292 - val_mean_pixel_error: 4.8332 - learning_rate: 0.0010
# Epoch 33/50
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 15s 320ms/step - loss: 0.2255 - mean_pixel_error: 5.1854 - val_loss: 0.2266 - val_mean_pixel_error: 4.7702 - learning_rate: 0.0010
# Epoch 34/50
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 15s 320ms/step - loss: 0.2226 - mean_pixel_error: 4.8895 - val_loss: 0.2266 - val_mean_pixel_error: 4.5503 - learning_rate: 0.0010
# Epoch 35/50
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 15s 321ms/step - loss: 0.2222 - mean_pixel_error: 4.8578 - val_loss: 0.2257 - val_mean_pixel_error: 4.6322 - learning_rate: 0.0010
# Epoch 36/50
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 15s 321ms/step - loss: 0.2221 - mean_pixel_error: 4.9105 - val_loss: 0.2256 - val_mean_pixel_error: 4.6542 - learning_rate: 0.0010
# Epoch 37/50
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 15s 321ms/step - loss: 0.2200 - mean_pixel_error: 4.7862 - val_loss: 0.2245 - val_mean_pixel_error: 4.4399 - learning_rate: 0.0010
# Epoch 38/50
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 15s 321ms/step - loss: 0.2201 - mean_pixel_error: 4.7275 - val_loss: 0.2259 - val_mean_pixel_error: 4.6005 - learning_rate: 0.0010
# Epoch 39/50
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 15s 321ms/step - loss: 0.2198 - mean_pixel_error: 4.8578 - val_loss: 0.2219 - val_mean_pixel_error: 4.3645 - learning_rate: 0.0010
# Epoch 40/50
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 15s 321ms/step - loss: 0.2170 - mean_pixel_error: 4.6181 - val_loss: 0.2206 - val_mean_pixel_error: 4.1814 - learning_rate: 0.0010
# Epoch 41/50
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 15s 320ms/step - loss: 0.2159 - mean_pixel_error: 4.7003 - val_loss: 0.2233 - val_mean_pixel_error: 4.4499 - learning_rate: 0.0010
# Epoch 42/50
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 15s 322ms/step - loss: 0.2152 - mean_pixel_error: 4.5353 - val_loss: 0.2194 - val_mean_pixel_error: 4.3366 - learning_rate: 0.0010
# Epoch 43/50
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 15s 321ms/step - loss: 0.2141 - mean_pixel_error: 4.5609 - val_loss: 0.2199 - val_mean_pixel_error: 4.2362 - learning_rate: 0.0010
# Epoch 44/50
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 15s 321ms/step - loss: 0.2146 - mean_pixel_error: 4.5266 - val_loss: 0.2193 - val_mean_pixel_error: 4.2054 - learning_rate: 0.0010
# Epoch 45/50
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 15s 321ms/step - loss: 0.2124 - mean_pixel_error: 4.5256 - val_loss: 0.2192 - val_mean_pixel_error: 4.2439 - learning_rate: 0.0010
# Epoch 46/50
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 15s 321ms/step - loss: 0.2124 - mean_pixel_error: 4.3750 - val_loss: 0.2186 - val_mean_pixel_error: 4.2780 - learning_rate: 0.0010
# Epoch 47/50
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 15s 321ms/step - loss: 0.2114 - mean_pixel_error: 4.4412 - val_loss: 0.2176 - val_mean_pixel_error: 4.0463 - learning_rate: 0.0010
# Epoch 48/50
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 15s 321ms/step - loss: 0.2106 - mean_pixel_error: 4.3809 - val_loss: 0.2181 - val_mean_pixel_error: 4.1370 - learning_rate: 0.0010
# Epoch 49/50
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 15s 321ms/step - loss: 0.2112 - mean_pixel_error: 4.3749 - val_loss: 0.2185 - val_mean_pixel_error: 4.2193 - learning_rate: 0.0010
# Epoch 50/50
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 15s 321ms/step - loss: 0.2115 - mean_pixel_error: 4.5941 - val_loss: 0.2187 - val_mean_pixel_error: 4.2122 - learning_rate: 0.0010
# Restoring model weights from the end of the best epoch: 47.

# %% [markdown]
# plot loss for train and evaluation

# %%
fig, ax1 = plt.subplots(figsize=(8, 5))

# y1: loss
ax1.plot(history.history['loss'], label='Train Loss', linestyle='-', color='black')
ax1.plot(history.history['val_loss'], label='Val Loss', linestyle='-', color='gray')
ax1.set_xlabel('Epochs', color='black')
ax1.set_ylabel('Loss', color='black')
ax1.tick_params(axis='y', labelcolor='black')
ax1.tick_params(axis='x', labelcolor='black')

# y2: MPE
ax2 = ax1.twinx()
ax2.plot(history.history['mean_pixel_error'], label='Train MPE', linestyle='--', color='black')
ax2.plot(history.history['val_mean_pixel_error'], label='Val MPE', linestyle='--', color='gray')
ax2.set_ylabel('Mean Pixel Error [px]', color='black')
ax2.tick_params(axis='y', labelcolor='black')

lines_1, labels_1 = ax1.get_legend_handles_labels()
lines_2, labels_2 = ax2.get_legend_handles_labels()
ax1.legend(lines_1 + lines_2, labels_1 + labels_2, loc='upper right')

plt.title("Training Loss & Mean Pixel Error", color='black')
plt.show()

# %% [markdown]
# mini evaluation test set

# %%
# converts heatmaps in normalized coordinates
def heatmaps_to_normalized_coords(y_heatmaps):
    B, H, W, C = y_heatmaps.shape
    y_flat = tf.reshape(y_heatmaps, [B, H*W, C])
    idx = tf.argmax(y_flat, axis=1, output_type=tf.int32)  # [B,C]

    # coords to pixel
    x = tf.cast(idx % W, tf.float32)
    y = tf.cast(idx // W, tf.float32)

    # normalisieren auf 0-1
    x_norm = x / (W - 1)
    y_norm = y / (H - 1)

    coords_norm = tf.stack([x_norm, y_norm], axis=-1)  # [B,C,2]
    return coords_norm.numpy()

# %%
pred_heatmaps_test = model.predict(X_test)
# Out:
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 4s 135ms/step

# %%
pred_coords_norm = heatmaps_to_normalized_coords(pred_heatmaps_test)
true_coords_norm = heatmaps_to_normalized_coords(y_test_heatmaps)

# %%
print(true_coords_norm.shape)
print(pred_coords_norm.shape)
# Out:
# (987, 18, 2)
# (987, 18, 2)

# %%
# image size
H, W = 160, 320

# convert to pixel size
diff_pixel = (true_coords_norm - pred_coords_norm) * np.array([H, W])
distances_pixel = np.linalg.norm(diff_pixel, axis=-1)

# prediction errors
mpe_mean = distances_pixel.mean()
mpe_std = distances_pixel.std()
mpe_median = np.median(distances_pixel)

print(f"Mean Prediction Error (MPE) in pixels: {mpe_mean:.2f} ± {mpe_std:.2f}")
print(f"Median Prediction Error in pixels: {mpe_median:.2f}")
# Out:
# Mean Prediction Error (MPE) in pixels: 4.82 ± 4.71
# Median Prediction Error in pixels: 2.03

# %% [markdown]
# save predictions in normalized pixel coords for evaluation

# %%
save_dir2 = '/content/drive/MyDrive/Arlette/Model_Outputs'
os.makedirs(save_dir2, exist_ok=True)
np.save(f"{save_dir2}/predictions_norm_UNET_full_augmentation_25.npy", pred_coords_norm)

# %% [markdown]
# save model weights and output

# %%
save_dir = '/content/drive/MyDrive/Arlette/model_weights'
os.makedirs(save_dir, exist_ok=True)

model.save(f'{save_dir}/UNET_full_augmentation_25.keras')
model.save_weights(f'{save_dir}/UNET_full_augmentation_25.weights.h5')
