# %% [markdown]
# setup/ import

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import random
import os

import tensorflow as tf

import wandb
from wandb.integration.keras import WandbMetricsLogger, WandbCallback, WandbModelCheckpoint

from sklearn.model_selection import train_test_split

from tensorflow.keras.layers import Dense, Input
from tensorflow.keras.models import Model
from tensorflow.keras.callbacks import EarlyStopping
from tensorflow.keras import layers, Model
from tensorflow.keras.callbacks import ReduceLROnPlateau

# %%
print('Tensorflow version:', tf.__version__)
print('Weights and biases version:', wandb.__version__)
# Out:
# Tensorflow version: 2.19.0
# Weights and biases version: 0.21.1

# %% [markdown]
# load data

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
X_train = np.load('/content/drive/MyDrive/Arlette/Sets for Training /Dataset with iPhone/train_aug_images_320x640.npy')
X_val = np.load('/content/drive/MyDrive/Arlette/Sets for Training /Dataset with iPhone/val_images_320x640.npy')
X_test = np.load('/content/drive/MyDrive/Arlette/Sets for Training /Dataset with iPhone/test_images_320x640.npy')

y_train_heatmaps = np.load('/content/drive/MyDrive/Arlette/Sets for Training /Dataset with iPhone/train_aug_heatmaps_40x80.npy')
y_val_heatmaps = np.load('/content/drive/MyDrive/Arlette/Sets for Training /Dataset with iPhone/val_heatmaps_40x80.npy')
y_test_heatmaps = np.load('/content/drive/MyDrive/Arlette/Sets for Training /Dataset with iPhone/test_heatmaps_40x80.npy')

# %% [markdown]
# define hyperparameters

# %%
def get_config(model_name='unet_with_iPhone_full_augmentation_320_640',
               img_size=(320, 640),
               batch_size=8,
               learning_rate_transfer=1e-3,
               learning_rate_tuning=1e-5,
               max_epochs_transfer=50,
               max_epochs_tuning=100,
               early_stop_patience=10,
               steps_per_epoch=81,
               dropout=0.5,
               seed=42):

    # cosine decay
    cosine_decay_steps = steps_per_epoch * max_epochs_tuning
    learning_schedule = {
        'initial_learning_rate': learning_rate_tuning,
        'decay_steps': cosine_decay_steps,
        'warmup_target': learning_rate_tuning,
        'warmup_steps': int(cosine_decay_steps * 0.02)
    }

    # config dictionary
    config = {
        'model_name': model_name,
        'img_size': img_size,
        'batch_size': batch_size,
        'learning_rate_transfer': learning_rate_transfer,
        'learning_rate_tuning': learning_rate_tuning,
        'max_epochs_transfer': max_epochs_transfer,
        'max_epochs_tuning': max_epochs_tuning,
        'early_stop_patience': early_stop_patience,
        'steps_per_epoch': steps_per_epoch,
        'cosine_decay_steps': cosine_decay_steps,
        'dropout': dropout,
        'learning_schedule': learning_schedule,
        'seed': seed
    }

    return config

# %%
config = get_config()
SEED = config['seed']
img_size = config['img_size']
batch_size = config['batch_size']
seed = config['seed']

# %% [markdown]
# create tensorflow datasets

# %%
train_dataset = tf.data.Dataset.from_tensor_slices((X_train, y_train_heatmaps))
train_dataset = train_dataset.shuffle(buffer_size=1000).batch(batch_size).prefetch(tf.data.AUTOTUNE)

val_dataset = tf.data.Dataset.from_tensor_slices((X_val, y_val_heatmaps)).batch(batch_size).prefetch(tf.data.AUTOTUNE)
test_dataset = tf.data.Dataset.from_tensor_slices((X_test, y_test_heatmaps)).batch(batch_size).prefetch(tf.data.AUTOTUNE)

# %% [markdown]
# define metrics // convert heatmap to coords

# %%
# loss
class BCEDiceLoss(tf.keras.losses.Loss):
    def __init__(self, alpha=0.5, smooth=1e-6, name="bce_dice_loss"):
        super().__init__(name=name)
        self.alpha = alpha
        self.smooth = smooth

    def call(self, y_true, y_pred):
        # Cclamp predictions
        y_pred = tf.clip_by_value(y_pred, 1e-6, 1.0 - 1e-6)

        # BCE
        bce = tf.keras.losses.binary_crossentropy(y_true, y_pred)
        bce = tf.reduce_mean(bce)

        # dice
        intersection = tf.reduce_sum(y_true * y_pred, axis=[1,2])
        pred_sum = tf.reduce_sum(y_pred, axis=[1,2])
        target_sum = tf.reduce_sum(y_true, axis=[1,2])
        dice = (2.0 * intersection + self.smooth) / (pred_sum + target_sum + self.smooth)
        dice_loss = 1.0 - dice
        dice_loss = tf.reduce_mean(dice_loss)

        # combine
        loss = self.alpha * bce + (1.0 - self.alpha) * dice_loss
        return loss

# metric

# converts heatmaps in pixel coords, based on highest value (argmax)
def heatmaps_to_pixel_coords(y_heatmaps, img_size=(320,640)):
    H_img, W_img = img_size
    B,H,W,C = tf.unstack(tf.shape(y_heatmaps))

    y_flat = tf.reshape(y_heatmaps, [B, H*W, C])
    idx = tf.argmax(y_flat, axis=1, output_type=tf.int32)  # [B,C]

    x = tf.cast(idx % W, tf.float32) / tf.cast(W-1, tf.float32) * tf.cast(W_img-1, tf.float32)
    y = tf.cast(idx // W, tf.float32) / tf.cast(H-1, tf.float32) * tf.cast(H_img-1, tf.float32)

    coords = tf.stack([x,y], axis=-1)  # [B,C,2]
    return coords

# mean pixel distance (euclidean dsitance) between ground truth and predicted landamarks on img size
def mean_pixel_error(y_true, y_pred, img_size=(320,640)):
    y_true_coords = heatmaps_to_pixel_coords(y_true, img_size)
    y_pred_coords = heatmaps_to_pixel_coords(y_pred, img_size)

    dist = tf.sqrt(tf.reduce_sum(tf.square(y_true_coords - y_pred_coords), axis=-1))  # [B,C]
    return tf.reduce_mean(dist)  # scalar

# %% [markdown]
# define model

# %%
def build_compact_unet_40x80(input_shape=(320,640,3), num_landmarks=18):
    inputs = layers.Input(shape=input_shape)

    # encoder
    c1 = layers.Conv2D(32, 3, activation='relu', padding='same')(inputs)
    c1 = layers.Conv2D(32, 3, activation='relu', padding='same')(c1)
    p1 = layers.MaxPooling2D((2,2))(c1)

    c2 = layers.Conv2D(64, 3, activation='relu', padding='same')(p1)
    c2 = layers.Conv2D(64, 3, activation='relu', padding='same')(c2)
    p2 = layers.MaxPooling2D((2,2))(c2)

    # bottleneck
    b = layers.Conv2D(128, 3, activation='relu', padding='same')(p2)
    b = layers.Conv2D(128, 3, activation='relu', padding='same')(b)

    # decoder
    u1 = layers.UpSampling2D((2,2), interpolation='bilinear')(b)
    u1 = layers.Concatenate()([u1, c2])
    u1 = layers.Conv2D(64, 3, activation='relu', padding='same')(u1)
    u1 = layers.Conv2D(64, 3, activation='relu', padding='same')(u1)
    u1 = layers.Dropout(0.1)(u1)

    u2 = layers.UpSampling2D((2,2), interpolation='bilinear')(u1)
    u2 = layers.Concatenate()([u2, c1])
    u2 = layers.Conv2D(32, 3, activation='relu', padding='same')(u2)
    u2 = layers.Conv2D(32, 3, activation='relu', padding='same')(u2)
    u2 = layers.Dropout(0.1)(u2)

    # output 40x80
    out = layers.Conv2D(num_landmarks, 1, activation='sigmoid', padding='same')(u2)
    out = layers.AveragePooling2D(pool_size=(8,8))(out)

    model = Model(inputs, out)
    return model

# %%
input_shape = (320, 640, 3)
num_landmarks = 18

model = build_compact_unet_40x80(input_shape=input_shape, num_landmarks=num_landmarks)

# loss bce + loss (0.5)
loss_fn = BCEDiceLoss(alpha=0.5)

# compile
model.compile(optimizer=tf.keras.optimizers.Adam(learning_rate=config['learning_rate_transfer']),
              loss=loss_fn,
              metrics=[mean_pixel_error])

model.summary()
# Out:
# Model: "functional_1"
# ┏━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)        ┃ Output Shape      ┃    Param # ┃ Connected to      ┃
# ┡━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━┩
# │ input_layer_1       │ (None, 320, 640,  │          0 │ -                 │
# │ (InputLayer)        │ 3)                │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_11 (Conv2D)  │ (None, 320, 640,  │        896 │ input_layer_1[0]… │
# │                     │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_12 (Conv2D)  │ (None, 320, 640,  │      9,248 │ conv2d_11[0][0]   │
# │                     │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ max_pooling2d_2     │ (None, 160, 320,  │          0 │ conv2d_12[0][0]   │
# │ (MaxPooling2D)      │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_13 (Conv2D)  │ (None, 160, 320,  │     18,496 │ max_pooling2d_2[… │
# │                     │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_14 (Conv2D)  │ (None, 160, 320,  │     36,928 │ conv2d_13[0][0]   │
# │                     │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ max_pooling2d_3     │ (None, 80, 160,   │          0 │ conv2d_14[0][0]   │
# │ (MaxPooling2D)      │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_15 (Conv2D)  │ (None, 80, 160,   │     73,856 │ max_pooling2d_3[… │
# │                     │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_16 (Conv2D)  │ (None, 80, 160,   │    147,584 │ conv2d_15[0][0]   │
# │                     │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ up_sampling2d_2     │ (None, 160, 320,  │          0 │ conv2d_16[0][0]   │
# │ (UpSampling2D)      │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ concatenate_2       │ (None, 160, 320,  │          0 │ up_sampling2d_2[… │
# │ (Concatenate)       │ 192)              │            │ conv2d_14[0][0]   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_17 (Conv2D)  │ (None, 160, 320,  │    110,656 │ concatenate_2[0]… │
# │                     │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_18 (Conv2D)  │ (None, 160, 320,  │     36,928 │ conv2d_17[0][0]   │
# │                     │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dropout_2 (Dropout) │ (None, 160, 320,  │          0 │ conv2d_18[0][0]   │
# │                     │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ up_sampling2d_3     │ (None, 320, 640,  │          0 │ dropout_2[0][0]   │
# │ (UpSampling2D)      │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ concatenate_3       │ (None, 320, 640,  │          0 │ up_sampling2d_3[… │
# │ (Concatenate)       │ 96)               │            │ conv2d_12[0][0]   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_19 (Conv2D)  │ (None, 320, 640,  │     27,680 │ concatenate_3[0]… │
# │                     │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_20 (Conv2D)  │ (None, 320, 640,  │      9,248 │ conv2d_19[0][0]   │
# │                     │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dropout_3 (Dropout) │ (None, 320, 640,  │          0 │ conv2d_20[0][0]   │
# │                     │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_21 (Conv2D)  │ (None, 320, 640,  │        594 │ dropout_3[0][0]   │
# │                     │ 18)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ average_pooling2d_1 │ (None, 40, 80,    │          0 │ conv2d_21[0][0]   │
# │ (AveragePooling2D)  │ 18)               │            │                   │
# └─────────────────────┴───────────────────┴────────────┴───────────────────┘
#  Total params: 472,114 (1.80 MB)
#  Trainable params: 472,114 (1.80 MB)
#  Non-trainable params: 0 (0.00 B)

# %%
wandb.init(project='mosquito_landmarks',name=f"{config['model_name']}_transfer",config=config)

early_stopping = EarlyStopping(
    monitor='val_loss',
    mode='min',
    patience=config['early_stop_patience'],
    restore_best_weights=True,
    verbose=1)

reduce_lr = ReduceLROnPlateau(
    monitor='val_loss',
    factor=0.5,
    patience=5,
    min_lr=1e-6,
    verbose=1,
    mode='min')

callbacks = [
    early_stopping,
    reduce_lr,
    WandbMetricsLogger(),
    WandbModelCheckpoint("wandb_model.keras")]
# Out:
# Finishing previous runs because reinit is set to 'default'.
#  View run <strong style="color:#cdcd00">unet_with_iPhone_full_augmentation_320_640_transfer</strong> at: <a href='https://wandb.ai/arlettedel-universit-t-hamburg/mosquito_landmarks/runs/sar65ln3' target="_blank">https://wandb.ai/arlettedel-universit-t-hamburg/mosquito_landmarks/runs/sar65ln3</a><br> View project at: <a href='https://wandb.ai/arlettedel-universit-t-hamburg/mosquito_landmarks' target="_blank">https://wandb.ai/arlettedel-universit-t-hamburg/mosquito_landmarks</a><br>Synced 5 W&B file(s), 0 media file(s), 0 artifact file(s) and 0 other file(s)
# Find logs at: <code>./wandb/run-20250830_092516-sar65ln3/logs</code>
# Tracking run with wandb version 0.21.1
# Run data is saved locally in <code>/content/wandb/run-20250830_092900-g299nh9q</code>
# Syncing run <strong><a href='https://wandb.ai/arlettedel-universit-t-hamburg/mosquito_landmarks/runs/g299nh9q' target="_blank">unet_with_iPhone_full_augmentation_320_640_transfer</a></strong> to <a href='https://wandb.ai/arlettedel-universit-t-hamburg/mosquito_landmarks' target="_blank">Weights & Biases</a> (<a href='https://wandb.me/developer-guide' target="_blank">docs</a>)<br>
#  View project at <a href='https://wandb.ai/arlettedel-universit-t-hamburg/mosquito_landmarks' target="_blank">https://wandb.ai/arlettedel-universit-t-hamburg/mosquito_landmarks</a>
#  View run at <a href='https://wandb.ai/arlettedel-universit-t-hamburg/mosquito_landmarks/runs/g299nh9q' target="_blank">https://wandb.ai/arlettedel-universit-t-hamburg/mosquito_landmarks/runs/g299nh9q</a>

# %%
history = model.fit(train_dataset, validation_data=val_dataset,
                    epochs=config['max_epochs_transfer'],
                    callbacks=callbacks,
                    verbose=1)
# Out:
# Epoch 1/50
# 371/371 ━━━━━━━━━━━━━━━━━━━━ 229s 527ms/step - loss: 0.6001 - mean_pixel_error: 284.1566 - val_loss: 0.5332 - val_mean_pixel_error: 380.7913 - learning_rate: 0.0010
# Epoch 2/50
# 371/371 ━━━━━━━━━━━━━━━━━━━━ 174s 470ms/step - loss: 0.5151 - mean_pixel_error: 247.4139 - val_loss: 0.5156 - val_mean_pixel_error: 377.1548 - learning_rate: 0.0010
# Epoch 3/50
# 371/371 ━━━━━━━━━━━━━━━━━━━━ 174s 470ms/step - loss: 0.5128 - mean_pixel_error: 244.9729 - val_loss: 0.5138 - val_mean_pixel_error: 359.7160 - learning_rate: 0.0010
# Epoch 4/50
# 371/371 ━━━━━━━━━━━━━━━━━━━━ 174s 470ms/step - loss: 0.5122 - mean_pixel_error: 241.6853 - val_loss: 0.5150 - val_mean_pixel_error: 370.6023 - learning_rate: 0.0010
# Epoch 5/50
# 371/371 ━━━━━━━━━━━━━━━━━━━━ 174s 469ms/step - loss: 0.5115 - mean_pixel_error: 244.3385 - val_loss: 0.5121 - val_mean_pixel_error: 347.6761 - learning_rate: 0.0010
# Epoch 6/50
# 371/371 ━━━━━━━━━━━━━━━━━━━━ 174s 469ms/step - loss: 0.5110 - mean_pixel_error: 240.2855 - val_loss: 0.5129 - val_mean_pixel_error: 332.1736 - learning_rate: 0.0010
# Epoch 7/50
# 371/371 ━━━━━━━━━━━━━━━━━━━━ 174s 469ms/step - loss: 0.5108 - mean_pixel_error: 238.0961 - val_loss: 0.5116 - val_mean_pixel_error: 336.5735 - learning_rate: 0.0010
# Epoch 8/50
# 371/371 ━━━━━━━━━━━━━━━━━━━━ 173s 467ms/step - loss: 0.5108 - mean_pixel_error: 239.0202 - val_loss: 0.5114 - val_mean_pixel_error: 332.9564 - learning_rate: 0.0010
# Epoch 9/50
# 371/371 ━━━━━━━━━━━━━━━━━━━━ 173s 466ms/step - loss: 0.5107 - mean_pixel_error: 238.2018 - val_loss: 0.5113 - val_mean_pixel_error: 343.2121 - learning_rate: 0.0010
# Epoch 10/50
# 371/371 ━━━━━━━━━━━━━━━━━━━━ 173s 466ms/step - loss: 0.5106 - mean_pixel_error: 237.7872 - val_loss: 0.5116 - val_mean_pixel_error: 330.0662 - learning_rate: 0.0010
# Epoch 11/50
# 371/371 ━━━━━━━━━━━━━━━━━━━━ 172s 465ms/step - loss: 0.5110 - mean_pixel_error: 237.0251 - val_loss: 0.5118 - val_mean_pixel_error: 331.0409 - learning_rate: 0.0010
# Epoch 12/50
# 371/371 ━━━━━━━━━━━━━━━━━━━━ 172s 464ms/step - loss: 0.5104 - mean_pixel_error: 235.6407 - val_loss: 0.5114 - val_mean_pixel_error: 333.3127 - learning_rate: 0.0010
# Epoch 13/50
# 371/371 ━━━━━━━━━━━━━━━━━━━━ 0s 420ms/step - loss: 0.5102 - mean_pixel_error: 234.1567
# Epoch 13: ReduceLROnPlateau reducing learning rate to 0.0005000000237487257.
# 371/371 ━━━━━━━━━━━━━━━━━━━━ 172s 465ms/step - loss: 0.5102 - mean_pixel_error: 234.1627 - val_loss: 0.5117 - val_mean_pixel_error: 336.3544 - learning_rate: 0.0010
# Epoch 14/50
# 371/371 ━━━━━━━━━━━━━━━━━━━━ 172s 464ms/step - loss: 0.5097 - mean_pixel_error: 237.4798 - val_loss: 0.5114 - val_mean_pixel_error: 338.1381 - learning_rate: 5.0000e-04
# Epoch 15/50
# 371/371 ━━━━━━━━━━━━━━━━━━━━ 172s 464ms/step - loss: 0.5095 - mean_pixel_error: 236.0342 - val_loss: 0.5115 - val_mean_pixel_error: 345.1014 - learning_rate: 5.0000e-04
# Epoch 16/50
# 371/371 ━━━━━━━━━━━━━━━━━━━━ 172s 464ms/step - loss: 0.5095 - mean_pixel_error: 237.2869 - val_loss: 0.5113 - val_mean_pixel_error: 342.0312 - learning_rate: 5.0000e-04
# Epoch 17/50
# 371/371 ━━━━━━━━━━━━━━━━━━━━ 172s 464ms/step - loss: 0.5096 - mean_pixel_error: 236.3589 - val_loss: 0.5120 - val_mean_pixel_error: 348.3643 - learning_rate: 5.0000e-04
# Epoch 18/50
# 371/371 ━━━━━━━━━━━━━━━━━━━━ 172s 465ms/step - loss: 0.5095 - mean_pixel_error: 236.4018 - val_loss: 0.5122 - val_mean_pixel_error: 337.9131 - learning_rate: 5.0000e-04
# Epoch 19/50
# 371/371 ━━━━━━━━━━━━━━━━━━━━ 172s 465ms/step - loss: 0.5091 - mean_pixel_error: 235.0704 - val_loss: 0.5112 - val_mean_pixel_error: 326.0563 - learning_rate: 5.0000e-04
# Epoch 20/50
# 371/371 ━━━━━━━━━━━━━━━━━━━━ 172s 464ms/step - loss: 0.5090 - mean_pixel_error: 235.0940 - val_loss: 0.5112 - val_mean_pixel_error: 345.4138 - learning_rate: 5.0000e-04
# Epoch 21/50
# 371/371 ━━━━━━━━━━━━━━━━━━━━ 0s 419ms/step - loss: 0.5089 - mean_pixel_error: 234.1250
# Epoch 21: ReduceLROnPlateau reducing learning rate to 0.0002500000118743628.
# 371/371 ━━━━━━━━━━━━━━━━━━━━ 172s 464ms/step - loss: 0.5089 - mean_pixel_error: 234.1267 - val_loss: 0.5116 - val_mean_pixel_error: 345.1014 - learning_rate: 5.0000e-04
# Epoch 22/50
# 371/371 ━━━━━━━━━━━━━━━━━━━━ 172s 464ms/step - loss: 0.5086 - mean_pixel_error: 234.6641 - val_loss: 0.5114 - val_mean_pixel_error: 345.1014 - learning_rate: 2.5000e-04
# Epoch 23/50
# 371/371 ━━━━━━━━━━━━━━━━━━━━ 172s 464ms/step - loss: 0.5083 - mean_pixel_error: 233.9780 - val_loss: 0.5118 - val_mean_pixel_error: 345.1014 - learning_rate: 2.5000e-04
# Epoch 24/50
# 371/371 ━━━━━━━━━━━━━━━━━━━━ 172s 464ms/step - loss: 0.5080 - mean_pixel_error: 232.9492 - val_loss: 0.5113 - val_mean_pixel_error: 345.1014 - learning_rate: 2.5000e-04
# Epoch 25/50
# 371/371 ━━━━━━━━━━━━━━━━━━━━ 172s 464ms/step - loss: 0.5082 - mean_pixel_error: 234.3105 - val_loss: 0.5113 - val_mean_pixel_error: 344.6573 - learning_rate: 2.5000e-04
# Epoch 26/50
# 371/371 ━━━━━━━━━━━━━━━━━━━━ 0s 420ms/step - loss: 0.5079 - mean_pixel_error: 235.0776
# Epoch 26: ReduceLROnPlateau reducing learning rate to 0.0001250000059371814.
# 371/371 ━━━━━━━━━━━━━━━━━━━━ 172s 464ms/step - loss: 0.5079 - mean_pixel_error: 235.0761 - val_loss: 0.5122 - val_mean_pixel_error: 347.6927 - learning_rate: 2.5000e-04
# Epoch 27/50
# 371/371 ━━━━━━━━━━━━━━━━━━━━ 172s 465ms/step - loss: 0.5079 - mean_pixel_error: 235.5036 - val_loss: 0.5113 - val_mean_pixel_error: 347.6956 - learning_rate: 1.2500e-04
# Epoch 28/50
# 371/371 ━━━━━━━━━━━━━━━━━━━━ 172s 465ms/step - loss: 0.5079 - mean_pixel_error: 232.2080 - val_loss: 0.5114 - val_mean_pixel_error: 348.3643 - learning_rate: 1.2500e-04
# Epoch 29/50
# 371/371 ━━━━━━━━━━━━━━━━━━━━ 172s 464ms/step - loss: 0.5076 - mean_pixel_error: 235.3187 - val_loss: 0.5116 - val_mean_pixel_error: 345.1014 - learning_rate: 1.2500e-04
# Epoch 29: early stopping
# Restoring model weights from the end of the best epoch: 19.

# %% [markdown]
# plot loss for train and evaluation

# %%
fig, ax1 = plt.subplots(figsize=(8, 5))

# y1: loss
ax1.plot(history.history['loss'], label='Train Loss', linestyle='-', color='black')
ax1.plot(history.history['val_loss'], label='Val Loss', linestyle='-', color='gray')
ax1.set_xlabel('Epochs', color='black')
ax1.set_ylabel('Loss', color='black')
ax1.tick_params(axis='y', labelcolor='black')
ax1.tick_params(axis='x', labelcolor='black')

# y2: MPE
ax2 = ax1.twinx()
ax2.plot(history.history['mean_pixel_error'], label='Train MPE', linestyle='--', color='black')
ax2.plot(history.history['val_mean_pixel_error'], label='Val MPE', linestyle='--', color='gray')
ax2.set_ylabel('Mean Pixel Error [px]', color='black')
ax2.tick_params(axis='y', labelcolor='black')

lines_1, labels_1 = ax1.get_legend_handles_labels()
lines_2, labels_2 = ax2.get_legend_handles_labels()
ax1.legend(lines_1 + lines_2, labels_1 + labels_2, loc='upper right')

plt.title("Training Loss & Mean Pixel Error", color='black')
plt.show()

# %% [markdown]
# mini evaluation test set

# %%
# converts heatmaps in normalized coordinates
def heatmaps_to_normalized_coords(y_heatmaps):
    B, H, W, C = y_heatmaps.shape
    y_flat = tf.reshape(y_heatmaps, [B, H*W, C])
    idx = tf.argmax(y_flat, axis=1, output_type=tf.int32)  # [B,C]

    # coords to pixel
    x = tf.cast(idx % W, tf.float32)
    y = tf.cast(idx // W, tf.float32)

    # normalisieren auf 0-1
    x_norm = x / (W - 1)
    y_norm = y / (H - 1)

    coords_norm = tf.stack([x_norm, y_norm], axis=-1)  # [B,C,2]
    return coords_norm.numpy()

# %%
pred_heatmaps_test = model.predict(X_test)
# Out:
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 59s 1s/step

# %%
pred_coords_norm = heatmaps_to_normalized_coords(pred_heatmaps_test)
true_coords_norm = heatmaps_to_normalized_coords(y_test_heatmaps)

# %%
print(true_coords_norm.shape)
print(pred_coords_norm.shape)
# Out:
# (987, 18, 2)
# (987, 18, 2)

# %%
# image size
H, W = 320, 640

# convert to pixel size
diff_pixel = (true_coords_norm - pred_coords_norm) * np.array([H, W])
distances_pixel = np.linalg.norm(diff_pixel, axis=-1)

# prediction errors
mpe_mean = distances_pixel.mean()
mpe_std = distances_pixel.std()
mpe_median = np.median(distances_pixel)

print(f"Mean Prediction Error (MPE) in pixels: {mpe_mean:.2f} ± {mpe_std:.2f}")
print(f"Median Prediction Error in pixels: {mpe_median:.2f}")
# Out:
# Mean Prediction Error (MPE) in pixels: 272.52 ± 77.75
# Median Prediction Error in pixels: 262.60

# %% [markdown]
# save predictions in normalized pixel coords for evaluation

# %%
save_dir2 = '/content/drive/MyDrive/Arlette/Model_Outputs'
os.makedirs(save_dir2, exist_ok=True)
np.save(f"{save_dir2}/predictions_norm_UNET_full_augmentation_320_640.npy", pred_coords_norm)

# %% [markdown]
# save model weights and output

# %%
save_dir = '/content/drive/MyDrive/Arlette/model_weights'
os.makedirs(save_dir, exist_ok=True)

model.save(f'{save_dir}/UNET_full_augmentation_320_640.keras')
model.save_weights(f'{save_dir}/UNET_full_augmentation_320_640.weights.h5')
