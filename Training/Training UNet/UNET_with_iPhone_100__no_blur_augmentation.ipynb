# %% [markdown]
# setup/ import

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import random
import os

import tensorflow as tf

import wandb
from wandb.integration.keras import WandbMetricsLogger, WandbCallback, WandbModelCheckpoint

from sklearn.model_selection import train_test_split

from tensorflow.keras.layers import Dense, Input
from tensorflow.keras.models import Model
from tensorflow.keras.callbacks import EarlyStopping
from tensorflow.keras import layers, Model
from tensorflow.keras.callbacks import ReduceLROnPlateau

# %%
print('Tensorflow version:', tf.__version__)
print('Weights and biases version:', wandb.__version__)
# Out:
# Tensorflow version: 2.19.0
# Weights and biases version: 0.21.1

# %% [markdown]
# load data

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
X_train = np.load('/content/drive/MyDrive/Arlette/Sets for Training /Dataset with iPhone/train_aug_images_no_blur_160x320.npy')
X_val = np.load('/content/drive/MyDrive/Arlette/Sets for Training /Dataset with iPhone/val_images_160x320.npy')
X_test = np.load('/content/drive/MyDrive/Arlette/Sets for Training /Dataset with iPhone/test_images_160x320.npy')

y_train_heatmaps = np.load('/content/drive/MyDrive/Arlette/Sets for Training /Dataset with iPhone/train_aug_no_blur_heatmaps_40x80.npy')
y_val_heatmaps = np.load('/content/drive/MyDrive/Arlette/Sets for Training /Dataset with iPhone/val_heatmaps_40x80.npy')
y_test_heatmaps = np.load('/content/drive/MyDrive/Arlette/Sets for Training /Dataset with iPhone/test_heatmaps_40x80.npy')

# %% [markdown]
# define hyperparameters

# %%
def get_config(model_name='UNET_with_iPhone_no_blur_augmentation',
               img_size=(160, 320),
               batch_size=16,
               learning_rate_transfer=1e-3,
               learning_rate_tuning=1e-5,
               max_epochs_transfer=50,
               max_epochs_tuning=100,
               early_stop_patience=10,
               steps_per_epoch=81,
               dropout=0.5,
               seed=42):

    # cosine decay
    cosine_decay_steps = steps_per_epoch * max_epochs_tuning
    learning_schedule = {
        'initial_learning_rate': learning_rate_tuning,
        'decay_steps': cosine_decay_steps,
        'warmup_target': learning_rate_tuning,
        'warmup_steps': int(cosine_decay_steps * 0.02)
    }

    # config dictionary
    config = {
        'model_name': model_name,
        'img_size': img_size,
        'batch_size': batch_size,
        'learning_rate_transfer': learning_rate_transfer,
        'learning_rate_tuning': learning_rate_tuning,
        'max_epochs_transfer': max_epochs_transfer,
        'max_epochs_tuning': max_epochs_tuning,
        'early_stop_patience': early_stop_patience,
        'steps_per_epoch': steps_per_epoch,
        'cosine_decay_steps': cosine_decay_steps,
        'dropout': dropout,
        'learning_schedule': learning_schedule,
        'seed': seed
    }

    return config

# %%
config = get_config()
SEED = config['seed']
img_size = config['img_size']
batch_size = config['batch_size']
seed = config['seed']

# %% [markdown]
# create tensorflow datasets

# %%
train_dataset = tf.data.Dataset.from_tensor_slices((X_train, y_train_heatmaps))
train_dataset = train_dataset.shuffle(buffer_size=1000).batch(batch_size).prefetch(tf.data.AUTOTUNE)

val_dataset = tf.data.Dataset.from_tensor_slices((X_val, y_val_heatmaps)).batch(batch_size).prefetch(tf.data.AUTOTUNE)
test_dataset = tf.data.Dataset.from_tensor_slices((X_test, y_test_heatmaps)).batch(batch_size).prefetch(tf.data.AUTOTUNE)

# %% [markdown]
# define metrics // convert heatmap to coords

# %%
# loss
class BCEDiceLoss(tf.keras.losses.Loss):
    def __init__(self, alpha=0.5, smooth=1e-6, name="bce_dice_loss"):
        super().__init__(name=name)
        self.alpha = alpha
        self.smooth = smooth

    def call(self, y_true, y_pred):
        # Cclamp predictions
        y_pred = tf.clip_by_value(y_pred, 1e-6, 1.0 - 1e-6)

        # BCE
        bce = tf.keras.losses.binary_crossentropy(y_true, y_pred)
        bce = tf.reduce_mean(bce)

        # dice
        intersection = tf.reduce_sum(y_true * y_pred, axis=[1,2])
        pred_sum = tf.reduce_sum(y_pred, axis=[1,2])
        target_sum = tf.reduce_sum(y_true, axis=[1,2])
        dice = (2.0 * intersection + self.smooth) / (pred_sum + target_sum + self.smooth)
        dice_loss = 1.0 - dice
        dice_loss = tf.reduce_mean(dice_loss)

        # combine
        loss = self.alpha * bce + (1.0 - self.alpha) * dice_loss
        return loss

# metric

# converts heatmaps in pixel coords, based on highest value (argmax)
def heatmaps_to_pixel_coords(y_heatmaps, img_size=(160,320)):
    H_img, W_img = img_size
    B,H,W,C = tf.unstack(tf.shape(y_heatmaps))

    y_flat = tf.reshape(y_heatmaps, [B, H*W, C])
    idx = tf.argmax(y_flat, axis=1, output_type=tf.int32)  # [B,C]

    x = tf.cast(idx % W, tf.float32) / tf.cast(W-1, tf.float32) * tf.cast(W_img-1, tf.float32)
    y = tf.cast(idx // W, tf.float32) / tf.cast(H-1, tf.float32) * tf.cast(H_img-1, tf.float32)

    coords = tf.stack([x,y], axis=-1)  # [B,C,2]
    return coords

# mean pixel distance (euclidean dsitance) between ground truth and predicted landamarks on img size
def mean_pixel_error(y_true, y_pred, img_size=(160,320)):
    y_true_coords = heatmaps_to_pixel_coords(y_true, img_size)
    y_pred_coords = heatmaps_to_pixel_coords(y_pred, img_size)

    dist = tf.sqrt(tf.reduce_sum(tf.square(y_true_coords - y_pred_coords), axis=-1))  # [B,C]
    return tf.reduce_mean(dist)  # scalar

# %% [markdown]
# define model

# %%
def build_compact_unet_40x80(input_shape=(160,320,3), num_landmarks=18):
    inputs = layers.Input(shape=input_shape)

    # encoder
    c1 = layers.Conv2D(32, 3, activation='relu', padding='same')(inputs)
    c1 = layers.Conv2D(32, 3, activation='relu', padding='same')(c1)
    p1 = layers.MaxPooling2D((2,2))(c1)  # 80x160

    c2 = layers.Conv2D(64, 3, activation='relu', padding='same')(p1)
    c2 = layers.Conv2D(64, 3, activation='relu', padding='same')(c2)
    p2 = layers.MaxPooling2D((2,2))(c2)  # 40x80

    # bottleneck
    b = layers.Conv2D(128, 3, activation='relu', padding='same')(p2)
    b = layers.Conv2D(128, 3, activation='relu', padding='same')(b)

    # decoder
    u1 = layers.UpSampling2D((2,2), interpolation='bilinear')(b)  # 80x160
    u1 = layers.Concatenate()([u1, c2])
    u1 = layers.Conv2D(64, 3, activation='relu', padding='same')(u1)
    u1 = layers.Conv2D(64, 3, activation='relu', padding='same')(u1)
    u1 = layers.Dropout(0.1)(u1)

    u2 = layers.UpSampling2D((2,2), interpolation='bilinear')(u1)  # 160x320
    u2 = layers.Concatenate()([u2, c1])
    u2 = layers.Conv2D(32, 3, activation='relu', padding='same')(u2)
    u2 = layers.Conv2D(32, 3, activation='relu', padding='same')(u2)
    u2 = layers.Dropout(0.1)(u2)

    # output 40x80
    out = layers.Conv2D(num_landmarks, 1, activation='sigmoid', padding='same')(u2)
    out = layers.AveragePooling2D(pool_size=(4,4))(out)  # 160/4=40, 320/4=80

    model = Model(inputs, out)
    return model

# %%
input_shape = (160, 320, 3)
num_landmarks = 18

model = build_compact_unet_40x80(input_shape=input_shape, num_landmarks=num_landmarks)

# loss bce + loss (0.5)
loss_fn = BCEDiceLoss(alpha=0.5)

# compile
model.compile(optimizer=tf.keras.optimizers.Adam(learning_rate=config['learning_rate_transfer']),
              loss=loss_fn,
              metrics=[mean_pixel_error])

model.summary()
# Out:
# Model: "functional"
# ┏━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)        ┃ Output Shape      ┃    Param # ┃ Connected to      ┃
# ┡━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━┩
# │ input_layer         │ (None, 160, 320,  │          0 │ -                 │
# │ (InputLayer)        │ 3)                │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d (Conv2D)     │ (None, 160, 320,  │        896 │ input_layer[0][0] │
# │                     │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_1 (Conv2D)   │ (None, 160, 320,  │      9,248 │ conv2d[0][0]      │
# │                     │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ max_pooling2d       │ (None, 80, 160,   │          0 │ conv2d_1[0][0]    │
# │ (MaxPooling2D)      │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_2 (Conv2D)   │ (None, 80, 160,   │     18,496 │ max_pooling2d[0]… │
# │                     │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_3 (Conv2D)   │ (None, 80, 160,   │     36,928 │ conv2d_2[0][0]    │
# │                     │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ max_pooling2d_1     │ (None, 40, 80,    │          0 │ conv2d_3[0][0]    │
# │ (MaxPooling2D)      │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_4 (Conv2D)   │ (None, 40, 80,    │     73,856 │ max_pooling2d_1[… │
# │                     │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_5 (Conv2D)   │ (None, 40, 80,    │    147,584 │ conv2d_4[0][0]    │
# │                     │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ up_sampling2d       │ (None, 80, 160,   │          0 │ conv2d_5[0][0]    │
# │ (UpSampling2D)      │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ concatenate         │ (None, 80, 160,   │          0 │ up_sampling2d[0]… │
# │ (Concatenate)       │ 192)              │            │ conv2d_3[0][0]    │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_6 (Conv2D)   │ (None, 80, 160,   │    110,656 │ concatenate[0][0] │
# │                     │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_7 (Conv2D)   │ (None, 80, 160,   │     36,928 │ conv2d_6[0][0]    │
# │                     │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dropout (Dropout)   │ (None, 80, 160,   │          0 │ conv2d_7[0][0]    │
# │                     │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ up_sampling2d_1     │ (None, 160, 320,  │          0 │ dropout[0][0]     │
# │ (UpSampling2D)      │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ concatenate_1       │ (None, 160, 320,  │          0 │ up_sampling2d_1[… │
# │ (Concatenate)       │ 96)               │            │ conv2d_1[0][0]    │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_8 (Conv2D)   │ (None, 160, 320,  │     27,680 │ concatenate_1[0]… │
# │                     │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_9 (Conv2D)   │ (None, 160, 320,  │      9,248 │ conv2d_8[0][0]    │
# │                     │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dropout_1 (Dropout) │ (None, 160, 320,  │          0 │ conv2d_9[0][0]    │
# │                     │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_10 (Conv2D)  │ (None, 160, 320,  │        594 │ dropout_1[0][0]   │
# │                     │ 18)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ average_pooling2d   │ (None, 40, 80,    │          0 │ conv2d_10[0][0]   │
# │ (AveragePooling2D)  │ 18)               │            │                   │
# └─────────────────────┴───────────────────┴────────────┴───────────────────┘
#  Total params: 472,114 (1.80 MB)
#  Trainable params: 472,114 (1.80 MB)
#  Non-trainable params: 0 (0.00 B)

# %%
wandb.init(project='mosquito_landmarks',name=f"{config['model_name']}_transfer",config=config)

early_stopping = EarlyStopping(
    monitor='val_loss',
    mode='min',
    patience=config['early_stop_patience'],
    restore_best_weights=True,
    verbose=1)

reduce_lr = ReduceLROnPlateau(
    monitor='val_loss',
    factor=0.5,
    patience=5,
    min_lr=1e-6,
    verbose=1,
    mode='min')

callbacks = [
    early_stopping,
    reduce_lr,
    WandbMetricsLogger(),
    WandbModelCheckpoint("wandb_model.keras")]
# Out:
# /usr/local/lib/python3.12/dist-packages/notebook/notebookapp.py:191: SyntaxWarning: invalid escape sequence '\/'
#   | |_| | '_ \/ _` / _` |  _/ -_)
# wandb: Logging into wandb.ai. (Learn how to deploy a W&B server locally: https://wandb.me/wandb-server)
# wandb: You can find your API key in your browser here: https://wandb.ai/authorize?ref=models
# wandb: Paste an API key from your profile and hit enter:
#  ··········
# wandb: WARNING If you're specifying your api key in code, ensure this code is not shared publicly.
# wandb: WARNING Consider setting the WANDB_API_KEY environment variable, or running `wandb login` from the command line.
# wandb: No netrc file found, creating one.
# wandb: Appending key for api.wandb.ai to your netrc file: /root/.netrc
# wandb: Currently logged in as: arlettedel (arlettedel-universit-t-hamburg) to https://api.wandb.ai. Use `wandb login --relogin` to force relogin
# Tracking run with wandb version 0.21.1
# Run data is saved locally in <code>/content/wandb/run-20250829_143530-1tgmxc4a</code>
# Syncing run <strong><a href='https://wandb.ai/arlettedel-universit-t-hamburg/mosquito_landmarks/runs/1tgmxc4a' target="_blank">UNET_with_iPhone_no_blur_augmentation_transfer</a></strong> to <a href='https://wandb.ai/arlettedel-universit-t-hamburg/mosquito_landmarks' target="_blank">Weights & Biases</a> (<a href='https://wandb.me/developer-guide' target="_blank">docs</a>)<br>
#  View project at <a href='https://wandb.ai/arlettedel-universit-t-hamburg/mosquito_landmarks' target="_blank">https://wandb.ai/arlettedel-universit-t-hamburg/mosquito_landmarks</a>
#  View run at <a href='https://wandb.ai/arlettedel-universit-t-hamburg/mosquito_landmarks/runs/1tgmxc4a' target="_blank">https://wandb.ai/arlettedel-universit-t-hamburg/mosquito_landmarks/runs/1tgmxc4a</a>

# %%
history = model.fit(train_dataset, validation_data=val_dataset,
                    epochs=config['max_epochs_transfer'],
                    callbacks=callbacks,
                    verbose=1)
# Out:
# Epoch 1/50
# 186/186 ━━━━━━━━━━━━━━━━━━━━ 88s 332ms/step - loss: 0.6066 - mean_pixel_error: 134.1373 - val_loss: 0.5544 - val_mean_pixel_error: 191.1127 - learning_rate: 0.0010
# Epoch 2/50
# 186/186 ━━━━━━━━━━━━━━━━━━━━ 45s 241ms/step - loss: 0.5457 - mean_pixel_error: 128.7261 - val_loss: 0.4821 - val_mean_pixel_error: 120.6146 - learning_rate: 0.0010
# Epoch 3/50
# 186/186 ━━━━━━━━━━━━━━━━━━━━ 44s 238ms/step - loss: 0.4696 - mean_pixel_error: 96.6940 - val_loss: 0.4286 - val_mean_pixel_error: 60.5152 - learning_rate: 0.0010
# Epoch 4/50
# 186/186 ━━━━━━━━━━━━━━━━━━━━ 44s 239ms/step - loss: 0.4103 - mean_pixel_error: 48.5480 - val_loss: 0.3612 - val_mean_pixel_error: 26.1826 - learning_rate: 0.0010
# Epoch 5/50
# 186/186 ━━━━━━━━━━━━━━━━━━━━ 44s 238ms/step - loss: 0.3526 - mean_pixel_error: 22.7412 - val_loss: 0.3187 - val_mean_pixel_error: 13.4384 - learning_rate: 0.0010
# Epoch 6/50
# 186/186 ━━━━━━━━━━━━━━━━━━━━ 44s 238ms/step - loss: 0.3159 - mean_pixel_error: 14.1639 - val_loss: 0.2921 - val_mean_pixel_error: 9.4871 - learning_rate: 0.0010
# Epoch 7/50
# 186/186 ━━━━━━━━━━━━━━━━━━━━ 44s 238ms/step - loss: 0.2853 - mean_pixel_error: 9.3795 - val_loss: 0.2721 - val_mean_pixel_error: 7.9158 - learning_rate: 0.0010
# Epoch 8/50
# 186/186 ━━━━━━━━━━━━━━━━━━━━ 44s 238ms/step - loss: 0.2621 - mean_pixel_error: 7.1827 - val_loss: 0.2495 - val_mean_pixel_error: 6.4147 - learning_rate: 0.0010
# Epoch 9/50
# 186/186 ━━━━━━━━━━━━━━━━━━━━ 44s 238ms/step - loss: 0.2482 - mean_pixel_error: 6.3895 - val_loss: 0.2451 - val_mean_pixel_error: 5.6578 - learning_rate: 0.0010
# Epoch 10/50
# 186/186 ━━━━━━━━━━━━━━━━━━━━ 44s 238ms/step - loss: 0.2416 - mean_pixel_error: 5.9769 - val_loss: 0.2394 - val_mean_pixel_error: 5.5906 - learning_rate: 0.0010
# Epoch 11/50
# 186/186 ━━━━━━━━━━━━━━━━━━━━ 44s 238ms/step - loss: 0.2326 - mean_pixel_error: 5.4630 - val_loss: 0.2296 - val_mean_pixel_error: 5.1463 - learning_rate: 0.0010
# Epoch 12/50
# 186/186 ━━━━━━━━━━━━━━━━━━━━ 44s 238ms/step - loss: 0.2274 - mean_pixel_error: 5.2324 - val_loss: 0.2233 - val_mean_pixel_error: 4.7165 - learning_rate: 0.0010
# Epoch 13/50
# 186/186 ━━━━━━━━━━━━━━━━━━━━ 44s 238ms/step - loss: 0.2237 - mean_pixel_error: 5.0536 - val_loss: 0.2218 - val_mean_pixel_error: 4.5382 - learning_rate: 0.0010
# Epoch 14/50
# 186/186 ━━━━━━━━━━━━━━━━━━━━ 44s 238ms/step - loss: 0.2214 - mean_pixel_error: 4.9491 - val_loss: 0.2195 - val_mean_pixel_error: 4.5088 - learning_rate: 0.0010
# Epoch 15/50
# 186/186 ━━━━━━━━━━━━━━━━━━━━ 44s 238ms/step - loss: 0.2194 - mean_pixel_error: 4.8616 - val_loss: 0.2190 - val_mean_pixel_error: 4.3629 - learning_rate: 0.0010
# Epoch 16/50
# 186/186 ━━━━━━━━━━━━━━━━━━━━ 44s 238ms/step - loss: 0.2180 - mean_pixel_error: 4.7892 - val_loss: 0.2255 - val_mean_pixel_error: 4.6095 - learning_rate: 0.0010
# Epoch 17/50
# 186/186 ━━━━━━━━━━━━━━━━━━━━ 44s 238ms/step - loss: 0.2222 - mean_pixel_error: 4.8975 - val_loss: 0.2165 - val_mean_pixel_error: 4.1651 - learning_rate: 0.0010
# Epoch 18/50
# 186/186 ━━━━━━━━━━━━━━━━━━━━ 44s 238ms/step - loss: 0.2155 - mean_pixel_error: 4.6577 - val_loss: 0.2146 - val_mean_pixel_error: 4.1205 - learning_rate: 0.0010
# Epoch 19/50
# 186/186 ━━━━━━━━━━━━━━━━━━━━ 44s 238ms/step - loss: 0.2136 - mean_pixel_error: 4.5874 - val_loss: 0.2135 - val_mean_pixel_error: 3.9081 - learning_rate: 0.0010
# Epoch 20/50
# 186/186 ━━━━━━━━━━━━━━━━━━━━ 44s 238ms/step - loss: 0.2123 - mean_pixel_error: 4.4716 - val_loss: 0.2142 - val_mean_pixel_error: 3.9979 - learning_rate: 0.0010
# Epoch 21/50
# 186/186 ━━━━━━━━━━━━━━━━━━━━ 44s 238ms/step - loss: 0.2118 - mean_pixel_error: 4.4646 - val_loss: 0.2118 - val_mean_pixel_error: 3.9279 - learning_rate: 0.0010
# Epoch 22/50
# 186/186 ━━━━━━━━━━━━━━━━━━━━ 44s 238ms/step - loss: 0.2109 - mean_pixel_error: 4.4770 - val_loss: 0.2116 - val_mean_pixel_error: 3.8924 - learning_rate: 0.0010
# Epoch 23/50
# 186/186 ━━━━━━━━━━━━━━━━━━━━ 44s 238ms/step - loss: 0.2095 - mean_pixel_error: 4.3708 - val_loss: 0.2100 - val_mean_pixel_error: 3.8561 - learning_rate: 0.0010
# Epoch 24/50
# 186/186 ━━━━━━━━━━━━━━━━━━━━ 44s 238ms/step - loss: 0.2087 - mean_pixel_error: 4.3666 - val_loss: 0.2117 - val_mean_pixel_error: 4.0586 - learning_rate: 0.0010
# Epoch 25/50
# 186/186 ━━━━━━━━━━━━━━━━━━━━ 44s 238ms/step - loss: 0.2120 - mean_pixel_error: 4.5689 - val_loss: 0.2119 - val_mean_pixel_error: 3.9981 - learning_rate: 0.0010
# Epoch 26/50
# 186/186 ━━━━━━━━━━━━━━━━━━━━ 44s 238ms/step - loss: 0.2090 - mean_pixel_error: 4.3489 - val_loss: 0.2102 - val_mean_pixel_error: 4.0766 - learning_rate: 0.0010
# Epoch 27/50
# 186/186 ━━━━━━━━━━━━━━━━━━━━ 44s 238ms/step - loss: 0.2073 - mean_pixel_error: 4.3359 - val_loss: 0.2093 - val_mean_pixel_error: 3.9602 - learning_rate: 0.0010
# Epoch 28/50
# 186/186 ━━━━━━━━━━━━━━━━━━━━ 44s 238ms/step - loss: 0.2064 - mean_pixel_error: 4.2690 - val_loss: 0.2074 - val_mean_pixel_error: 3.9074 - learning_rate: 0.0010
# Epoch 29/50
# 186/186 ━━━━━━━━━━━━━━━━━━━━ 44s 238ms/step - loss: 0.2058 - mean_pixel_error: 4.2417 - val_loss: 0.2080 - val_mean_pixel_error: 3.8859 - learning_rate: 0.0010
# Epoch 30/50
# 186/186 ━━━━━━━━━━━━━━━━━━━━ 44s 238ms/step - loss: 0.2051 - mean_pixel_error: 4.1632 - val_loss: 0.2082 - val_mean_pixel_error: 3.8146 - learning_rate: 0.0010
# Epoch 31/50
# 186/186 ━━━━━━━━━━━━━━━━━━━━ 44s 238ms/step - loss: 0.2055 - mean_pixel_error: 4.1259 - val_loss: 0.2083 - val_mean_pixel_error: 3.7738 - learning_rate: 0.0010
# Epoch 32/50
# 186/186 ━━━━━━━━━━━━━━━━━━━━ 44s 239ms/step - loss: 0.2043 - mean_pixel_error: 4.0563 - val_loss: 0.2068 - val_mean_pixel_error: 3.8100 - learning_rate: 0.0010
# Epoch 33/50
# 186/186 ━━━━━━━━━━━━━━━━━━━━ 44s 238ms/step - loss: 0.2043 - mean_pixel_error: 4.0182 - val_loss: 0.2070 - val_mean_pixel_error: 3.7225 - learning_rate: 0.0010
# Epoch 34/50
# 186/186 ━━━━━━━━━━━━━━━━━━━━ 44s 238ms/step - loss: 0.2037 - mean_pixel_error: 4.0244 - val_loss: 0.2093 - val_mean_pixel_error: 3.7717 - learning_rate: 0.0010
# Epoch 35/50
# 186/186 ━━━━━━━━━━━━━━━━━━━━ 44s 238ms/step - loss: 0.2050 - mean_pixel_error: 4.0395 - val_loss: 0.2063 - val_mean_pixel_error: 3.6107 - learning_rate: 0.0010
# Epoch 36/50
# 186/186 ━━━━━━━━━━━━━━━━━━━━ 44s 239ms/step - loss: 0.2033 - mean_pixel_error: 3.9695 - val_loss: 0.2060 - val_mean_pixel_error: 3.6258 - learning_rate: 0.0010
# Epoch 37/50
# 186/186 ━━━━━━━━━━━━━━━━━━━━ 44s 238ms/step - loss: 0.2035 - mean_pixel_error: 3.9691 - val_loss: 0.2129 - val_mean_pixel_error: 3.9572 - learning_rate: 0.0010
# Epoch 38/50
# 186/186 ━━━━━━━━━━━━━━━━━━━━ 44s 238ms/step - loss: 0.2080 - mean_pixel_error: 4.1008 - val_loss: 0.2049 - val_mean_pixel_error: 3.4353 - learning_rate: 0.0010
# Epoch 39/50
# 186/186 ━━━━━━━━━━━━━━━━━━━━ 44s 237ms/step - loss: 0.2021 - mean_pixel_error: 3.8310 - val_loss: 0.2049 - val_mean_pixel_error: 3.4724 - learning_rate: 0.0010
# Epoch 40/50
# 186/186 ━━━━━━━━━━━━━━━━━━━━ 44s 238ms/step - loss: 0.2022 - mean_pixel_error: 3.8412 - val_loss: 0.2046 - val_mean_pixel_error: 3.3734 - learning_rate: 0.0010
# Epoch 41/50
# 186/186 ━━━━━━━━━━━━━━━━━━━━ 45s 241ms/step - loss: 0.2015 - mean_pixel_error: 3.7506 - val_loss: 0.2062 - val_mean_pixel_error: 3.4514 - learning_rate: 0.0010
# Epoch 42/50
# 186/186 ━━━━━━━━━━━━━━━━━━━━ 44s 237ms/step - loss: 0.2026 - mean_pixel_error: 3.7562 - val_loss: 0.2055 - val_mean_pixel_error: 3.2672 - learning_rate: 0.0010
# Epoch 43/50
# 186/186 ━━━━━━━━━━━━━━━━━━━━ 44s 238ms/step - loss: 0.2036 - mean_pixel_error: 3.7956 - val_loss: 0.2039 - val_mean_pixel_error: 3.3073 - learning_rate: 0.0010
# Epoch 44/50
# 186/186 ━━━━━━━━━━━━━━━━━━━━ 44s 238ms/step - loss: 0.2012 - mean_pixel_error: 3.7051 - val_loss: 0.2052 - val_mean_pixel_error: 3.3032 - learning_rate: 0.0010
# Epoch 45/50
# 186/186 ━━━━━━━━━━━━━━━━━━━━ 44s 238ms/step - loss: 0.2011 - mean_pixel_error: 3.6579 - val_loss: 0.2060 - val_mean_pixel_error: 3.3624 - learning_rate: 0.0010
# Epoch 46/50
# 186/186 ━━━━━━━━━━━━━━━━━━━━ 44s 237ms/step - loss: 0.2012 - mean_pixel_error: 3.6607 - val_loss: 0.2045 - val_mean_pixel_error: 3.2979 - learning_rate: 0.0010
# Epoch 47/50
# 186/186 ━━━━━━━━━━━━━━━━━━━━ 44s 238ms/step - loss: 0.2006 - mean_pixel_error: 3.6223 - val_loss: 0.2047 - val_mean_pixel_error: 3.2560 - learning_rate: 0.0010
# Epoch 48/50
# 185/186 ━━━━━━━━━━━━━━━━━━━━ 0s 214ms/step - loss: 0.2015 - mean_pixel_error: 3.6388
# Epoch 48: ReduceLROnPlateau reducing learning rate to 0.0005000000237487257.
# 186/186 ━━━━━━━━━━━━━━━━━━━━ 44s 238ms/step - loss: 0.2015 - mean_pixel_error: 3.6388 - val_loss: 0.2042 - val_mean_pixel_error: 3.3122 - learning_rate: 0.0010
# Epoch 49/50
# 186/186 ━━━━━━━━━━━━━━━━━━━━ 44s 237ms/step - loss: 0.1998 - mean_pixel_error: 3.5607 - val_loss: 0.2030 - val_mean_pixel_error: 3.1612 - learning_rate: 5.0000e-04
# Epoch 50/50
# 186/186 ━━━━━━━━━━━━━━━━━━━━ 44s 238ms/step - loss: 0.1996 - mean_pixel_error: 3.5430 - val_loss: 0.2030 - val_mean_pixel_error: 3.0934 - learning_rate: 5.0000e-04
# Restoring model weights from the end of the best epoch: 49.

# %% [markdown]
# plot loss for train and evaluation

# %%
fig, ax1 = plt.subplots(figsize=(8, 5))

# y1: loss
ax1.plot(history.history['loss'], label='Train Loss', linestyle='-', color='black')
ax1.plot(history.history['val_loss'], label='Val Loss', linestyle='-', color='gray')
ax1.set_xlabel('Epochs', color='black')
ax1.set_ylabel('Loss', color='black')
ax1.tick_params(axis='y', labelcolor='black')
ax1.tick_params(axis='x', labelcolor='black')

# y2: MPE
ax2 = ax1.twinx()
ax2.plot(history.history['mean_pixel_error'], label='Train MPE', linestyle='--', color='black')
ax2.plot(history.history['val_mean_pixel_error'], label='Val MPE', linestyle='--', color='gray')
ax2.set_ylabel('Mean Pixel Error [px]', color='black')
ax2.tick_params(axis='y', labelcolor='black')

lines_1, labels_1 = ax1.get_legend_handles_labels()
lines_2, labels_2 = ax2.get_legend_handles_labels()
ax1.legend(lines_1 + lines_2, labels_1 + labels_2, loc='upper right')

plt.title("Training Loss & Mean Pixel Error", color='black')
plt.show()

# %% [markdown]
# mini evaluation test set

# %%
# converts heatmaps in normalized coordinates
def heatmaps_to_normalized_coords(y_heatmaps):
    B, H, W, C = y_heatmaps.shape
    y_flat = tf.reshape(y_heatmaps, [B, H*W, C])
    idx = tf.argmax(y_flat, axis=1, output_type=tf.int32)  # [B,C]

    # coords to pixel
    x = tf.cast(idx % W, tf.float32)
    y = tf.cast(idx // W, tf.float32)

    # normalisieren auf 0-1
    x_norm = x / (W - 1)
    y_norm = y / (H - 1)

    coords_norm = tf.stack([x_norm, y_norm], axis=-1)  # [B,C,2]
    return coords_norm.numpy()

# %%
pred_heatmaps_test = model.predict(X_test)
# Out:
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 19s 365ms/step

# %%
pred_coords_norm = heatmaps_to_normalized_coords(pred_heatmaps_test)
true_coords_norm = heatmaps_to_normalized_coords(y_test_heatmaps)

# %%
print(true_coords_norm.shape)
print(pred_coords_norm.shape)
# Out:
# (987, 18, 2)
# (987, 18, 2)

# %%
# image size
H, W = 160, 320

# convert to pixel size
diff_pixel = (true_coords_norm - pred_coords_norm) * np.array([H, W])
distances_pixel = np.linalg.norm(diff_pixel, axis=-1)

# prediction errors
mpe_mean = distances_pixel.mean()
mpe_std = distances_pixel.std()
mpe_median = np.median(distances_pixel)

print(f"Mean Prediction Error (MPE) in pixels: {mpe_mean:.2f} ± {mpe_std:.2f}")
print(f"Median Prediction Error in pixels: {mpe_median:.2f}")
# Out:
# Mean Prediction Error (MPE) in pixels: 3.83 ± 4.07
# Median Prediction Error in pixels: 2.03

# %% [markdown]
# save predictions in normalized pixel coords for evaluation

# %%
save_dir2 = '/content/drive/MyDrive/Arlette/Model_Outputs'
os.makedirs(save_dir2, exist_ok=True)
np.save(f"{save_dir2}/predictions_norm_UNET_no_blur_augmentation.npy", pred_coords_norm)

# %% [markdown]
# save model weights and output

# %%
save_dir = '/content/drive/MyDrive/Arlette/model_weights'
os.makedirs(save_dir, exist_ok=True)

model.save(f'{save_dir}/UNET_no_blur_augmentation.keras')
model.save_weights(f'{save_dir}/UNET_no_blur_augmentation.weights.h5')
