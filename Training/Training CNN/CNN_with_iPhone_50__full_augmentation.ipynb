# %% [markdown]
# setup/ import

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import random
import os

import tensorflow as tf

import wandb
from wandb.integration.keras import WandbMetricsLogger, WandbCallback, WandbModelCheckpoint

from sklearn.model_selection import train_test_split

from tensorflow.keras.layers import Dense, Input
from tensorflow.keras.models import Model
from tensorflow.keras.callbacks import EarlyStopping
from tensorflow.keras import layers

# %%
print('Tensorflow version:', tf.__version__)
print('Weights and biases version:', wandb.__version__)
# Out:
# Tensorflow version: 2.19.0
# Weights and biases version: 0.21.1

# %% [markdown]
# load data

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
X_train = np.load('/content/drive/MyDrive/Arlette/Sets for Training /Dataset with iPhone/reduced datasets/train_aug_images_160x320_50.npy')
X_val = np.load('/content/drive/MyDrive/Arlette/Sets for Training /Dataset with iPhone/val_images_160x320.npy')
X_test = np.load('/content/drive/MyDrive/Arlette/Sets for Training /Dataset with iPhone/test_images_160x320.npy')

y_train = np.load('/content/drive/MyDrive/Arlette/Sets for Training /Dataset with iPhone/reduced datasets/train_aug_landmarks_50.npy')
y_val = np.load('/content/drive/MyDrive/Arlette/Sets for Training /Dataset with iPhone/val_landmarks.npy')
y_test = np.load('/content/drive/MyDrive/Arlette/Sets for Training /Dataset with iPhone/test_landmarks.npy')

# %%
print(X_train.shape)
print(y_train.shape)
# Out:
# (1480, 160, 320, 3)
# (1480, 18, 2)

# %% [markdown]
# define hyperparameters

# %%
def get_config(model_name='CNN_withIphone_100_augmentation_50_dataset',
               img_size=(160, 320),
               batch_size=16,
               learning_rate_transfer=1e-3,
               learning_rate_tuning=5e-4,
               max_epochs_transfer=50,
               max_epochs_tuning=100,
               early_stop_patience=10,
               steps_per_epoch=81,
               dropout=0.5,
               seed=42):

    # cosine decay
    cosine_decay_steps = steps_per_epoch * max_epochs_tuning
    learning_schedule = {
        'initial_learning_rate': learning_rate_tuning,
        'decay_steps': cosine_decay_steps,
        'warmup_target': learning_rate_tuning,
        'warmup_steps': int(cosine_decay_steps * 0.02)
    }

    # config dictionary
    config = {
        'model_name': model_name,
        'img_size': img_size,
        'batch_size': batch_size,
        'learning_rate_transfer': learning_rate_transfer,
        'learning_rate_tuning': learning_rate_tuning,
        'max_epochs_transfer': max_epochs_transfer,
        'max_epochs_tuning': max_epochs_tuning,
        'early_stop_patience': early_stop_patience,
        'steps_per_epoch': steps_per_epoch,
        'cosine_decay_steps': cosine_decay_steps,
        'dropout': dropout,
        'learning_schedule': learning_schedule,
        'seed': seed
    }

    return config

# %%
config = get_config()
SEED = config['seed']
img_size = config['img_size']
batch_size = config['batch_size']
seed = config['seed']

# %% [markdown]
# create tensorflow dataset

# %%
train_dataset = tf.data.Dataset.from_tensor_slices((X_train, y_train))
train_dataset = train_dataset.shuffle(buffer_size=1000).batch(batch_size).prefetch(tf.data.AUTOTUNE)

val_dataset = tf.data.Dataset.from_tensor_slices((X_val, y_val)).batch(batch_size).prefetch(tf.data.AUTOTUNE)
test_dataset = tf.data.Dataset.from_tensor_slices((X_test, y_test)).batch(batch_size).prefetch(tf.data.AUTOTUNE)

# %% [markdown]
# define loss and metric

# %%
# loss in normalized units [0,1]
# computes mean squared error per landmark in normalized coordinates
# arg: y_true and y_pred in tensor shape (batch_size, num_landmarks, 2) [0,1]
# returns scalar tensor: average MSE over all landmarks in the batch
def landmark_mse(y_true, y_pred):
    y_true = tf.cast(y_true, tf.float32)
    y_pred = tf.cast(y_pred, tf.float32)
    return tf.reduce_mean(tf.reduce_sum(tf.square(y_true - y_pred), axis=-1))


# metric
# mean pixel error
# computes average euclidean distance per landmark in pixels
# arg: y_true and y_pred in tensor shape (batch_size, num_landmarks, 2) [0,1]
#      img_size: tuple [int, int], image height and with (H, W)
# returns scalar tensor: mean pixel error over batch
def mean_pixel_error_metric_160_320(y_true, y_pred):
    H, W = 160,320
    y_true = tf.cast(y_true, tf.float32)
    y_pred = tf.cast(y_pred, tf.float32)
    y_true_px = y_true * tf.constant([W, H], dtype=tf.float32)
    y_pred_px = y_pred * tf.constant([W, H], dtype=tf.float32)
    dist = tf.sqrt(tf.reduce_sum(tf.square(y_true_px - y_pred_px), axis=-1))
    return tf.reduce_mean(dist)

# %% [markdown]
# define model

# %%
from tensorflow.keras.applications import ResNet50

def build_resnet50_landmark_model(input_shape=(160, 320, 3),
                                  num_landmarks=18,
                                  trainable_backbone=False):
    backbone = ResNet50(
        include_top=False,
        weights='imagenet',
        input_shape=input_shape,
        pooling=None
    )
    backbone.trainable = trainable_backbone

    inputs = tf.keras.Input(shape=input_shape)
    x = backbone(inputs, training=False)
    x = tf.keras.layers.GlobalAveragePooling2D()(x)

    # head
    x = tf.keras.layers.Dense(256, activation='relu')(x)
    x = tf.keras.layers.Dropout(0.3)(x)
    x = tf.keras.layers.Dense(128, activation='relu')(x)
    x = tf.keras.layers.Dropout(0.3)(x)

    # output
    x = tf.keras.layers.Dense(num_landmarks * 2, activation='sigmoid')(x)
    outputs = tf.keras.layers.Reshape((num_landmarks, 2))(x)

    return tf.keras.Model(inputs, outputs, name='resnet50_landmark_model')

# %%
input_shape = (160, 320, 3)
num_landmarks = 18

model = build_resnet50_landmark_model(input_shape=input_shape, num_landmarks=num_landmarks)

model.compile(optimizer=tf.keras.optimizers.Adam(learning_rate=config['learning_rate_transfer']),
              loss=landmark_mse,
              metrics=[mean_pixel_error_metric_160_320])

model.summary()
# Out:
# Model: "resnet50_landmark_model"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ input_layer_1 (InputLayer)      │ (None, 160, 320, 3)    │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ resnet50 (Functional)           │ (None, 5, 10, 2048)    │    23,587,712 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ global_average_pooling2d        │ (None, 2048)           │             0 │
# │ (GlobalAveragePooling2D)        │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense (Dense)                   │ (None, 256)            │       524,544 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout (Dropout)               │ (None, 256)            │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_1 (Dense)                 │ (None, 128)            │        32,896 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_1 (Dropout)             │ (None, 128)            │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_2 (Dense)                 │ (None, 36)             │         4,644 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ reshape (Reshape)               │ (None, 18, 2)          │             0 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 24,149,796 (92.12 MB)
#  Trainable params: 562,084 (2.14 MB)
#  Non-trainable params: 23,587,712 (89.98 MB)

# %% [markdown]
# callbacks // weights and biases

# %%
wandb.init(project='mosquito_landmarks',name=f"{config['model_name']}",config=config)

callbacks = [EarlyStopping(monitor='val_loss',
            patience=config['early_stop_patience'],
            restore_best_weights=True,
            verbose=1),
            WandbMetricsLogger(),
            WandbModelCheckpoint("wandb_model.keras")]
# Out:
# wandb: Logging into wandb.ai. (Learn how to deploy a W&B server locally: https://wandb.me/wandb-server)
# wandb: You can find your API key in your browser here: https://wandb.ai/authorize?ref=models
# wandb: Paste an API key from your profile and hit enter:
#  ··········
# wandb: WARNING If you're specifying your api key in code, ensure this code is not shared publicly.
# wandb: WARNING Consider setting the WANDB_API_KEY environment variable, or running `wandb login` from the command line.
# wandb: No netrc file found, creating one.
# wandb: Appending key for api.wandb.ai to your netrc file: /root/.netrc
# wandb: Currently logged in as: arlettedel (arlettedel-universit-t-hamburg) to https://api.wandb.ai. Use `wandb login --relogin` to force relogin
# Tracking run with wandb version 0.21.1
# Run data is saved locally in <code>/content/wandb/run-20250829_202004-8n0en6sg</code>
# Syncing run <strong><a href='https://wandb.ai/arlettedel-universit-t-hamburg/mosquito_landmarks/runs/8n0en6sg' target="_blank">CNN_withIphone_100_augmentation_50_dataset</a></strong> to <a href='https://wandb.ai/arlettedel-universit-t-hamburg/mosquito_landmarks' target="_blank">Weights & Biases</a> (<a href='https://wandb.me/developer-guide' target="_blank">docs</a>)<br>
#  View project at <a href='https://wandb.ai/arlettedel-universit-t-hamburg/mosquito_landmarks' target="_blank">https://wandb.ai/arlettedel-universit-t-hamburg/mosquito_landmarks</a>
#  View run at <a href='https://wandb.ai/arlettedel-universit-t-hamburg/mosquito_landmarks/runs/8n0en6sg' target="_blank">https://wandb.ai/arlettedel-universit-t-hamburg/mosquito_landmarks/runs/8n0en6sg</a>

# %% [markdown]
# train model

# %%
history = model.fit(train_dataset, validation_data=val_dataset,
                    epochs=config['max_epochs_transfer'],
                    callbacks=callbacks,
                    verbose=1)
# Out:
# Epoch 1/50
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 40s 261ms/step - loss: 0.0995 - mean_pixel_error_metric_160_320: 81.5721 - val_loss: 0.0859 - val_mean_pixel_error_metric_160_320: 78.8154
# Epoch 2/50
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 10s 106ms/step - loss: 0.0850 - mean_pixel_error_metric_160_320: 77.8127 - val_loss: 0.0772 - val_mean_pixel_error_metric_160_320: 74.1555
# Epoch 3/50
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 9s 100ms/step - loss: 0.0809 - mean_pixel_error_metric_160_320: 75.3293 - val_loss: 0.0895 - val_mean_pixel_error_metric_160_320: 77.0608
# Epoch 4/50
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 9s 99ms/step - loss: 0.0728 - mean_pixel_error_metric_160_320: 68.9778 - val_loss: 0.0530 - val_mean_pixel_error_metric_160_320: 56.6605
# Epoch 5/50
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 9s 99ms/step - loss: 0.0569 - mean_pixel_error_metric_160_320: 57.7097 - val_loss: 0.0389 - val_mean_pixel_error_metric_160_320: 43.2665
# Epoch 6/50
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 9s 102ms/step - loss: 0.0366 - mean_pixel_error_metric_160_320: 42.7579 - val_loss: 0.0143 - val_mean_pixel_error_metric_160_320: 24.8331
# Epoch 7/50
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 9s 99ms/step - loss: 0.0259 - mean_pixel_error_metric_160_320: 33.6164 - val_loss: 0.0123 - val_mean_pixel_error_metric_160_320: 22.0747
# Epoch 8/50
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 9s 99ms/step - loss: 0.0234 - mean_pixel_error_metric_160_320: 31.6865 - val_loss: 0.0092 - val_mean_pixel_error_metric_160_320: 18.7805
# Epoch 9/50
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 9s 98ms/step - loss: 0.0216 - mean_pixel_error_metric_160_320: 29.3117 - val_loss: 0.0113 - val_mean_pixel_error_metric_160_320: 20.6833
# Epoch 10/50
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 9s 98ms/step - loss: 0.0198 - mean_pixel_error_metric_160_320: 28.6032 - val_loss: 0.0103 - val_mean_pixel_error_metric_160_320: 18.3240
# Epoch 11/50
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 9s 99ms/step - loss: 0.0177 - mean_pixel_error_metric_160_320: 26.1635 - val_loss: 0.0060 - val_mean_pixel_error_metric_160_320: 14.1026
# Epoch 12/50
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 9s 97ms/step - loss: 0.0160 - mean_pixel_error_metric_160_320: 24.3630 - val_loss: 0.0076 - val_mean_pixel_error_metric_160_320: 16.9549
# Epoch 13/50
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 9s 97ms/step - loss: 0.0194 - mean_pixel_error_metric_160_320: 27.1173 - val_loss: 0.0065 - val_mean_pixel_error_metric_160_320: 15.2818
# Epoch 14/50
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 9s 97ms/step - loss: 0.0237 - mean_pixel_error_metric_160_320: 29.7854 - val_loss: 0.0076 - val_mean_pixel_error_metric_160_320: 17.9129
# Epoch 15/50
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 9s 97ms/step - loss: 0.0332 - mean_pixel_error_metric_160_320: 36.4304 - val_loss: 0.0117 - val_mean_pixel_error_metric_160_320: 20.1338
# Epoch 16/50
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 9s 98ms/step - loss: 0.0308 - mean_pixel_error_metric_160_320: 34.9334 - val_loss: 0.0079 - val_mean_pixel_error_metric_160_320: 17.7976
# Epoch 17/50
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 9s 99ms/step - loss: 0.0296 - mean_pixel_error_metric_160_320: 33.4857 - val_loss: 0.0055 - val_mean_pixel_error_metric_160_320: 13.7526
# Epoch 18/50
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 9s 98ms/step - loss: 0.0313 - mean_pixel_error_metric_160_320: 35.0212 - val_loss: 0.0051 - val_mean_pixel_error_metric_160_320: 12.9025
# Epoch 19/50
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 9s 98ms/step - loss: 0.0344 - mean_pixel_error_metric_160_320: 37.1386 - val_loss: 0.0164 - val_mean_pixel_error_metric_160_320: 26.0196
# Epoch 20/50
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 9s 97ms/step - loss: 0.0316 - mean_pixel_error_metric_160_320: 34.9325 - val_loss: 0.0073 - val_mean_pixel_error_metric_160_320: 17.3544
# Epoch 21/50
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 9s 98ms/step - loss: 0.0319 - mean_pixel_error_metric_160_320: 34.8843 - val_loss: 0.0138 - val_mean_pixel_error_metric_160_320: 19.4303
# Epoch 22/50
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 9s 99ms/step - loss: 0.0347 - mean_pixel_error_metric_160_320: 36.9325 - val_loss: 0.0050 - val_mean_pixel_error_metric_160_320: 12.6374
# Epoch 23/50
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 9s 98ms/step - loss: 0.0333 - mean_pixel_error_metric_160_320: 35.7800 - val_loss: 0.0054 - val_mean_pixel_error_metric_160_320: 14.2014
# Epoch 24/50
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 9s 97ms/step - loss: 0.0312 - mean_pixel_error_metric_160_320: 34.5127 - val_loss: 0.0060 - val_mean_pixel_error_metric_160_320: 15.8242
# Epoch 25/50
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 9s 97ms/step - loss: 0.0297 - mean_pixel_error_metric_160_320: 33.3969 - val_loss: 0.0084 - val_mean_pixel_error_metric_160_320: 19.3259
# Epoch 26/50
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 9s 97ms/step - loss: 0.0291 - mean_pixel_error_metric_160_320: 32.8088 - val_loss: 0.0052 - val_mean_pixel_error_metric_160_320: 14.0487
# Epoch 27/50
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 9s 97ms/step - loss: 0.0296 - mean_pixel_error_metric_160_320: 33.0789 - val_loss: 0.0058 - val_mean_pixel_error_metric_160_320: 14.9369
# Epoch 28/50
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 9s 97ms/step - loss: 0.0315 - mean_pixel_error_metric_160_320: 34.5419 - val_loss: 0.0122 - val_mean_pixel_error_metric_160_320: 22.8303
# Epoch 29/50
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 9s 101ms/step - loss: 0.0308 - mean_pixel_error_metric_160_320: 34.4268 - val_loss: 0.0038 - val_mean_pixel_error_metric_160_320: 10.7332
# Epoch 30/50
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 9s 98ms/step - loss: 0.0303 - mean_pixel_error_metric_160_320: 33.7154 - val_loss: 0.0053 - val_mean_pixel_error_metric_160_320: 14.8009
# Epoch 31/50
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 9s 99ms/step - loss: 0.0424 - mean_pixel_error_metric_160_320: 41.2232 - val_loss: 0.0085 - val_mean_pixel_error_metric_160_320: 19.1333
# Epoch 32/50
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 9s 98ms/step - loss: 0.0301 - mean_pixel_error_metric_160_320: 33.7055 - val_loss: 0.0096 - val_mean_pixel_error_metric_160_320: 17.1130
# Epoch 33/50
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 9s 98ms/step - loss: 0.0308 - mean_pixel_error_metric_160_320: 33.9829 - val_loss: 0.0051 - val_mean_pixel_error_metric_160_320: 12.4718
# Epoch 34/50
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 9s 98ms/step - loss: 0.0306 - mean_pixel_error_metric_160_320: 33.4759 - val_loss: 0.0046 - val_mean_pixel_error_metric_160_320: 13.0898
# Epoch 35/50
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 9s 98ms/step - loss: 0.0325 - mean_pixel_error_metric_160_320: 35.0445 - val_loss: 0.0045 - val_mean_pixel_error_metric_160_320: 12.8525
# Epoch 36/50
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 9s 99ms/step - loss: 0.0290 - mean_pixel_error_metric_160_320: 32.1790 - val_loss: 0.0036 - val_mean_pixel_error_metric_160_320: 10.7471
# Epoch 37/50
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 9s 98ms/step - loss: 0.0282 - mean_pixel_error_metric_160_320: 32.1470 - val_loss: 0.0113 - val_mean_pixel_error_metric_160_320: 22.9590
# Epoch 38/50
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 9s 97ms/step - loss: 0.0310 - mean_pixel_error_metric_160_320: 34.5067 - val_loss: 0.0073 - val_mean_pixel_error_metric_160_320: 17.7557
# Epoch 39/50
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 9s 97ms/step - loss: 0.0294 - mean_pixel_error_metric_160_320: 32.2284 - val_loss: 0.0045 - val_mean_pixel_error_metric_160_320: 12.2711
# Epoch 40/50
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 9s 98ms/step - loss: 0.0290 - mean_pixel_error_metric_160_320: 31.9023 - val_loss: 0.0066 - val_mean_pixel_error_metric_160_320: 14.7411
# Epoch 41/50
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 9s 98ms/step - loss: 0.0295 - mean_pixel_error_metric_160_320: 32.4014 - val_loss: 0.0053 - val_mean_pixel_error_metric_160_320: 14.6268
# Epoch 42/50
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 9s 97ms/step - loss: 0.0292 - mean_pixel_error_metric_160_320: 31.8459 - val_loss: 0.0052 - val_mean_pixel_error_metric_160_320: 14.1000
# Epoch 43/50
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 9s 100ms/step - loss: 0.0340 - mean_pixel_error_metric_160_320: 36.3517 - val_loss: 0.0035 - val_mean_pixel_error_metric_160_320: 9.9468
# Epoch 44/50
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 9s 97ms/step - loss: 0.0308 - mean_pixel_error_metric_160_320: 33.3636 - val_loss: 0.0057 - val_mean_pixel_error_metric_160_320: 12.8167
# Epoch 45/50
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 9s 98ms/step - loss: 0.0325 - mean_pixel_error_metric_160_320: 34.7038 - val_loss: 0.0043 - val_mean_pixel_error_metric_160_320: 11.9168
# Epoch 46/50
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 9s 98ms/step - loss: 0.0358 - mean_pixel_error_metric_160_320: 37.1539 - val_loss: 0.0051 - val_mean_pixel_error_metric_160_320: 12.1937
# Epoch 47/50
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 9s 98ms/step - loss: 0.0319 - mean_pixel_error_metric_160_320: 34.7649 - val_loss: 0.0050 - val_mean_pixel_error_metric_160_320: 14.1333
# Epoch 48/50
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 9s 98ms/step - loss: 0.0280 - mean_pixel_error_metric_160_320: 31.5414 - val_loss: 0.0042 - val_mean_pixel_error_metric_160_320: 11.8895
# Epoch 49/50
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 9s 99ms/step - loss: 0.0313 - mean_pixel_error_metric_160_320: 34.2372 - val_loss: 0.0034 - val_mean_pixel_error_metric_160_320: 10.3667
# Epoch 50/50
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 9s 97ms/step - loss: 0.0322 - mean_pixel_error_metric_160_320: 34.1980 - val_loss: 0.0042 - val_mean_pixel_error_metric_160_320: 11.1986
# Restoring model weights from the end of the best epoch: 49.

# %% [markdown]
# fine tuning

# %%
# unfreeze layer for fine tuning
for layer in model.layers:
    layer.trainable = True

# new optimizer for fine tuning
optimizer = tf.keras.optimizers.Adam(
    learning_rate=config['learning_rate_tuning'])

model.compile(optimizer=optimizer, loss=landmark_mse)

# callback fine tuning
callbacks_ft = [
    EarlyStopping(
        monitor='val_loss',
        patience=config['early_stop_patience'],
        restore_best_weights=True,
        verbose=1),
    WandbMetricsLogger(),
    WandbModelCheckpoint("wandb_model_finetuned.keras")]

# wandb
wandb.init(
    project='mosquito_landmarks',
    name=f"{config['model_name']}_finetune",
    config=config,
    reinit=True)  # important for new run

# fine tuning
history_ft = model.fit(
    train_dataset,
    validation_data=val_dataset,
    epochs=config['max_epochs_tuning'],
    callbacks=callbacks_ft,
    verbose=1)
# Out:
# Finishing previous runs because reinit is set to True.
# <br>    <style><br>        .wandb-row {<br>            display: flex;<br>            flex-direction: row;<br>            flex-wrap: wrap;<br>            justify-content: flex-start;<br>            width: 100%;<br>        }<br>        .wandb-col {<br>            display: flex;<br>            flex-direction: column;<br>            flex-basis: 100%;<br>            flex: 1;<br>            padding: 10px;<br>        }<br>    </style><br><div class="wandb-row"><div class="wandb-col"><h3>Run history:</h3><br/><table class="wandb"><tr><td>epoch/epoch</td><td>▁▁▁▁▂▂▂▂▂▃▃▃▃▃▃▄▄▄▄▄▅▅▅▅▅▅▆▆▆▆▆▆▇▇▇▇▇▇██</td></tr><tr><td>epoch/learning_rate</td><td>▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁</td></tr><tr><td>epoch/loss</td><td>█▇▇▆▄▂▁▂▁▁▁▃▂▂▂▂▃▃▂▂▂▂▂▂▂▂▂▂▂▂▂▂▂▂▃▂▂▂▂▂</td></tr><tr><td>epoch/mean_pixel_error_metric_160_320</td><td>██▇▆▅▂▂▂▁▁▁▂▂▂▂▂▂▂▂▂▂▂▂▂▂▃▂▂▂▂▂▂▂▂▂▂▂▂▂▂</td></tr><tr><td>epoch/val_loss</td><td>█▇█▅▄▂▁▂▂▁▁▁▂▁▁▂▁▂▁▁▁▁▁▂▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁</td></tr><tr><td>epoch/val_mean_pixel_error_metric_160_320</td><td>███▆▄▂▂▂▂▁▂▂▂▂▁▃▂▂▁▁▂▁▂▂▁▂▂▁▁▁▂▁▁▁▁▁▁▁▁▁</td></tr></table><br/></div><div class="wandb-col"><h3>Run summary:</h3><br/><table class="wandb"><tr><td>epoch/epoch</td><td>49</td></tr><tr><td>epoch/learning_rate</td><td>0.001</td></tr><tr><td>epoch/loss</td><td>0.02914</td></tr><tr><td>epoch/mean_pixel_error_metric_160_320</td><td>32.09752</td></tr><tr><td>epoch/val_loss</td><td>0.00415</td></tr><tr><td>epoch/val_mean_pixel_error_metric_160_320</td><td>11.1986</td></tr></table><br/></div></div>
#  View run <strong style="color:#cdcd00">CNN_withIphone_100_augmentation_50_dataset</strong> at: <a href='https://wandb.ai/arlettedel-universit-t-hamburg/mosquito_landmarks/runs/8n0en6sg' target="_blank">https://wandb.ai/arlettedel-universit-t-hamburg/mosquito_landmarks/runs/8n0en6sg</a><br> View project at: <a href='https://wandb.ai/arlettedel-universit-t-hamburg/mosquito_landmarks' target="_blank">https://wandb.ai/arlettedel-universit-t-hamburg/mosquito_landmarks</a><br>Synced 5 W&B file(s), 0 media file(s), 100 artifact file(s) and 0 other file(s)
# Find logs at: <code>./wandb/run-20250829_202004-8n0en6sg/logs</code>
# wandb: WARNING Using a boolean value for 'reinit' is deprecated. Use 'return_previous' or 'finish_previous' instead.
# Tracking run with wandb version 0.21.1
# Run data is saved locally in <code>/content/wandb/run-20250829_202851-2q42hj2w</code>
# Syncing run <strong><a href='https://wandb.ai/arlettedel-universit-t-hamburg/mosquito_landmarks/runs/2q42hj2w' target="_blank">CNN_withIphone_100_augmentation_50_dataset_finetune</a></strong> to <a href='https://wandb.ai/arlettedel-universit-t-hamburg/mosquito_landmarks' target="_blank">Weights & Biases</a> (<a href='https://wandb.me/developer-guide' target="_blank">docs</a>)<br>
#  View project at <a href='https://wandb.ai/arlettedel-universit-t-hamburg/mosquito_landmarks' target="_blank">https://wandb.ai/arlettedel-universit-t-hamburg/mosquito_landmarks</a>
#  View run at <a href='https://wandb.ai/arlettedel-universit-t-hamburg/mosquito_landmarks/runs/2q42hj2w' target="_blank">https://wandb.ai/arlettedel-universit-t-hamburg/mosquito_landmarks/runs/2q42hj2w</a>
# Epoch 1/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 110s 582ms/step - loss: 0.1050 - mean_pixel_error_metric_160_320: 69.9093 - val_loss: 0.1220 - val_mean_pixel_error_metric_160_320: 85.7034
# Epoch 2/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 22s 240ms/step - loss: 0.0056 - mean_pixel_error_metric_160_320: 16.4393 - val_loss: 0.0916 - val_mean_pixel_error_metric_160_320: 80.7433
# Epoch 3/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 22s 240ms/step - loss: 0.0038 - mean_pixel_error_metric_160_320: 13.5339 - val_loss: 0.1149 - val_mean_pixel_error_metric_160_320: 84.9318
# Epoch 4/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 22s 237ms/step - loss: 0.0037 - mean_pixel_error_metric_160_320: 13.1331 - val_loss: 0.0913 - val_mean_pixel_error_metric_160_320: 80.7780
# Epoch 5/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 22s 235ms/step - loss: 0.0029 - mean_pixel_error_metric_160_320: 11.7207 - val_loss: 0.0917 - val_mean_pixel_error_metric_160_320: 76.4493
# Epoch 6/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 22s 240ms/step - loss: 0.0031 - mean_pixel_error_metric_160_320: 11.5774 - val_loss: 0.0531 - val_mean_pixel_error_metric_160_320: 55.0330
# Epoch 7/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 23s 246ms/step - loss: 0.0028 - mean_pixel_error_metric_160_320: 11.1025 - val_loss: 0.0118 - val_mean_pixel_error_metric_160_320: 25.9873
# Epoch 8/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 22s 239ms/step - loss: 0.0025 - mean_pixel_error_metric_160_320: 10.8300 - val_loss: 0.0042 - val_mean_pixel_error_metric_160_320: 15.0730
# Epoch 9/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 22s 237ms/step - loss: 0.0026 - mean_pixel_error_metric_160_320: 10.8295 - val_loss: 0.0030 - val_mean_pixel_error_metric_160_320: 11.4025
# Epoch 10/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 22s 237ms/step - loss: 0.0026 - mean_pixel_error_metric_160_320: 10.6727 - val_loss: 0.0033 - val_mean_pixel_error_metric_160_320: 11.4771
# Epoch 11/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 22s 239ms/step - loss: 0.0049 - mean_pixel_error_metric_160_320: 13.7521 - val_loss: 0.0025 - val_mean_pixel_error_metric_160_320: 10.8439
# Epoch 12/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 22s 238ms/step - loss: 0.0029 - mean_pixel_error_metric_160_320: 11.6765 - val_loss: 0.0021 - val_mean_pixel_error_metric_160_320: 9.7158
# Epoch 13/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 22s 237ms/step - loss: 0.0025 - mean_pixel_error_metric_160_320: 10.8415 - val_loss: 0.0022 - val_mean_pixel_error_metric_160_320: 10.3438
# Epoch 14/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 22s 238ms/step - loss: 0.0026 - mean_pixel_error_metric_160_320: 10.6324 - val_loss: 0.0021 - val_mean_pixel_error_metric_160_320: 9.7508
# Epoch 15/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 22s 238ms/step - loss: 0.0023 - mean_pixel_error_metric_160_320: 10.1692 - val_loss: 0.0019 - val_mean_pixel_error_metric_160_320: 9.2492
# Epoch 16/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 22s 239ms/step - loss: 0.0023 - mean_pixel_error_metric_160_320: 9.8290 - val_loss: 0.0017 - val_mean_pixel_error_metric_160_320: 8.6303
# Epoch 17/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 22s 236ms/step - loss: 0.0020 - mean_pixel_error_metric_160_320: 9.5449 - val_loss: 0.0020 - val_mean_pixel_error_metric_160_320: 9.6229
# Epoch 18/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 22s 236ms/step - loss: 0.0022 - mean_pixel_error_metric_160_320: 9.9071 - val_loss: 0.0018 - val_mean_pixel_error_metric_160_320: 9.0568
# Epoch 19/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 23s 243ms/step - loss: 0.0023 - mean_pixel_error_metric_160_320: 9.8568 - val_loss: 0.0021 - val_mean_pixel_error_metric_160_320: 9.9260
# Epoch 20/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 22s 238ms/step - loss: 0.0022 - mean_pixel_error_metric_160_320: 9.6156 - val_loss: 0.0028 - val_mean_pixel_error_metric_160_320: 11.7799
# Epoch 21/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 22s 238ms/step - loss: 0.0023 - mean_pixel_error_metric_160_320: 9.5643 - val_loss: 0.0017 - val_mean_pixel_error_metric_160_320: 8.5543
# Epoch 22/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 22s 236ms/step - loss: 0.0022 - mean_pixel_error_metric_160_320: 9.7178 - val_loss: 0.0021 - val_mean_pixel_error_metric_160_320: 10.0495
# Epoch 23/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 22s 238ms/step - loss: 0.0024 - mean_pixel_error_metric_160_320: 9.5923 - val_loss: 0.0016 - val_mean_pixel_error_metric_160_320: 8.2667
# Epoch 24/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 22s 241ms/step - loss: 0.0019 - mean_pixel_error_metric_160_320: 9.0507 - val_loss: 0.0016 - val_mean_pixel_error_metric_160_320: 8.2289
# Epoch 25/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 22s 236ms/step - loss: 0.0021 - mean_pixel_error_metric_160_320: 9.2603 - val_loss: 0.0016 - val_mean_pixel_error_metric_160_320: 8.1456
# Epoch 26/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 22s 236ms/step - loss: 0.0039 - mean_pixel_error_metric_160_320: 13.6289 - val_loss: 0.0030 - val_mean_pixel_error_metric_160_320: 11.6307
# Epoch 27/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 22s 235ms/step - loss: 0.0023 - mean_pixel_error_metric_160_320: 10.0207 - val_loss: 0.0024 - val_mean_pixel_error_metric_160_320: 10.9229
# Epoch 28/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 22s 235ms/step - loss: 0.0022 - mean_pixel_error_metric_160_320: 9.7453 - val_loss: 0.0021 - val_mean_pixel_error_metric_160_320: 10.3958
# Epoch 29/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 22s 235ms/step - loss: 0.0022 - mean_pixel_error_metric_160_320: 9.6570 - val_loss: 0.0016 - val_mean_pixel_error_metric_160_320: 8.5077
# Epoch 30/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 22s 237ms/step - loss: 0.0019 - mean_pixel_error_metric_160_320: 8.9117 - val_loss: 0.0016 - val_mean_pixel_error_metric_160_320: 8.1084
# Epoch 31/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 22s 238ms/step - loss: 0.0020 - mean_pixel_error_metric_160_320: 8.9779 - val_loss: 0.0013 - val_mean_pixel_error_metric_160_320: 7.1624
# Epoch 32/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 22s 238ms/step - loss: 0.0020 - mean_pixel_error_metric_160_320: 8.7946 - val_loss: 0.0013 - val_mean_pixel_error_metric_160_320: 6.7975
# Epoch 33/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 22s 235ms/step - loss: 0.0019 - mean_pixel_error_metric_160_320: 8.7381 - val_loss: 0.0016 - val_mean_pixel_error_metric_160_320: 8.6164
# Epoch 34/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 22s 236ms/step - loss: 0.0025 - mean_pixel_error_metric_160_320: 10.6629 - val_loss: 0.0021 - val_mean_pixel_error_metric_160_320: 9.6715
# Epoch 35/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 22s 235ms/step - loss: 0.0023 - mean_pixel_error_metric_160_320: 9.3036 - val_loss: 0.0058 - val_mean_pixel_error_metric_160_320: 16.3191
# Epoch 36/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 22s 235ms/step - loss: 0.0023 - mean_pixel_error_metric_160_320: 9.6920 - val_loss: 0.0016 - val_mean_pixel_error_metric_160_320: 8.1192
# Epoch 37/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 22s 235ms/step - loss: 0.0021 - mean_pixel_error_metric_160_320: 9.2575 - val_loss: 0.0017 - val_mean_pixel_error_metric_160_320: 8.6804
# Epoch 38/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 22s 238ms/step - loss: 0.0024 - mean_pixel_error_metric_160_320: 9.9391 - val_loss: 0.0196 - val_mean_pixel_error_metric_160_320: 27.3640
# Epoch 39/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 22s 238ms/step - loss: 0.0083 - mean_pixel_error_metric_160_320: 15.6723 - val_loss: 0.3068 - val_mean_pixel_error_metric_160_320: 127.7659
# Epoch 40/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 22s 236ms/step - loss: 0.0026 - mean_pixel_error_metric_160_320: 10.9470 - val_loss: 0.5083 - val_mean_pixel_error_metric_160_320: 165.8981
# Epoch 41/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 22s 236ms/step - loss: 0.0027 - mean_pixel_error_metric_160_320: 11.3927 - val_loss: 0.0021 - val_mean_pixel_error_metric_160_320: 8.8095
# Epoch 42/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 22s 237ms/step - loss: 0.0022 - mean_pixel_error_metric_160_320: 9.6446 - val_loss: 0.0017 - val_mean_pixel_error_metric_160_320: 7.6971
# Epoch 42: early stopping
# Restoring model weights from the end of the best epoch: 32.

# %% [markdown]
# plot loss for train and evaluation

# %%
fig, ax1 = plt.subplots(figsize=(8, 5))

# y1: loss
ax1.plot(history.history['loss'], label='Train Loss', linestyle='-', color='black')
ax1.plot(history.history['val_loss'], label='Val Loss', linestyle='-', color='gray')
ax1.set_xlabel('Epochs', color='black')
ax1.set_ylabel('Loss', color='black')
ax1.tick_params(axis='y', labelcolor='black')
ax1.tick_params(axis='x', labelcolor='black')

# y2: MPE
ax2 = ax1.twinx()
ax2.plot(history.history['mean_pixel_error_metric_160_320'], label='Train MPE', linestyle='--', color='black')
ax2.plot(history.history['val_mean_pixel_error_metric_160_320'], label='Val MPE', linestyle='--', color='gray')
ax2.set_ylabel('Mean Pixel Error [px]', color='black')
ax2.tick_params(axis='y', labelcolor='black')

lines_1, labels_1 = ax1.get_legend_handles_labels()
lines_2, labels_2 = ax2.get_legend_handles_labels()
ax1.legend(lines_1 + lines_2, labels_1 + labels_2, loc='upper right')

plt.title("Training Loss & Mean Pixel Error", color='black')
plt.show()

# %% [markdown]
# mini evaluation test set

# %%
#mpe +- std
pred_coords_norm = model.predict(X_test)
# Out:
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 18s 349ms/step

# %%
distances = np.linalg.norm(y_test - pred_coords_norm, axis=-1)

# %%
# image size
H, W = 160, 320

# convert to pixel size
diff_pixel = (y_test - pred_coords_norm) * np.array([H, W])
distances_pixel = np.linalg.norm(diff_pixel, axis=-1)

# prediction errors
mpe_mean = distances_pixel.mean()
mpe_std = distances_pixel.std()
mpe_median = np.median(distances_pixel)

print(f"Mean Prediction Error (MPE) in pixels: {mpe_mean:.2f} ± {mpe_std:.2f}")
print(f"Median Prediction Error in pixels: {mpe_median:.2f}")
# Out:
# Mean Prediction Error (MPE) in pixels: 6.23 ± 5.41
# Median Prediction Error in pixels: 5.03

# %% [markdown]
# save predictions in normalized pixel coords for evaluation

# %%
save_dir2 = '/content/drive/MyDrive/Arlette/Model_Outputs'
os.makedirs(save_dir2, exist_ok=True)
np.save(f"{save_dir2}/predictions_norm_CNN_full_augmentation_50_.npy", pred_coords_norm)

# %% [markdown]
# save model weights and output

# %%
#save best config based on validation loss

# %%
save_dir = '/content/drive/MyDrive/Arlette/model_weights'
os.makedirs(save_dir, exist_ok=True)

model.save(f'{save_dir}/CNN_full_augmentation_50.keras')
model.save_weights(f'{save_dir}/CNN_full_augmentation_50.weights.h5')
