# %% [markdown]
# setup/ import

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import random
import os

import tensorflow as tf

import wandb
from wandb.integration.keras import WandbMetricsLogger, WandbCallback, WandbModelCheckpoint

from sklearn.model_selection import train_test_split

from tensorflow.keras.layers import Dense, Input
from tensorflow.keras.models import Model
from tensorflow.keras.callbacks import EarlyStopping
from tensorflow.keras import layers

# %%
print('Tensorflow version:', tf.__version__)
print('Weights and biases version:', wandb.__version__)
# Out:
# Tensorflow version: 2.19.0
# Weights and biases version: 0.21.1

# %% [markdown]
# load data

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
X_train = np.load('/content/drive/MyDrive/Arlette/Sets for Training /Dataset with iPhone/train_orig_images_160x320.npy')
X_val = np.load('/content/drive/MyDrive/Arlette/Sets for Training /Dataset with iPhone/val_images_160x320.npy')
X_test = np.load('/content/drive/MyDrive/Arlette/Sets for Training /Dataset with iPhone/test_images_160x320.npy')

y_train = np.load('/content/drive/MyDrive/Arlette/Sets for Training /Dataset with iPhone/train_orig_landmarks.npy')
y_val = np.load('/content/drive/MyDrive/Arlette/Sets for Training /Dataset with iPhone/val_landmarks.npy')
y_test = np.load('/content/drive/MyDrive/Arlette/Sets for Training /Dataset with iPhone/test_landmarks.npy')

# %% [markdown]
# define hyperparameters

# %%
def get_config(model_name='resnet50_withIphone_ohne_augmentation',
               img_size=(160, 320),
               batch_size=16,
               learning_rate_transfer=1e-3,
               learning_rate_tuning=5e-4,
               max_epochs_transfer=50,
               max_epochs_tuning=100,
               early_stop_patience=10,
               steps_per_epoch=81,
               dropout=0.5,
               seed=42):

    # cosine decay
    cosine_decay_steps = steps_per_epoch * max_epochs_tuning
    learning_schedule = {
        'initial_learning_rate': learning_rate_tuning,
        'decay_steps': cosine_decay_steps,
        'warmup_target': learning_rate_tuning,
        'warmup_steps': int(cosine_decay_steps * 0.02)
    }

    # config dictionary
    config = {
        'model_name': model_name,
        'img_size': img_size,
        'batch_size': batch_size,
        'learning_rate_transfer': learning_rate_transfer,
        'learning_rate_tuning': learning_rate_tuning,
        'max_epochs_transfer': max_epochs_transfer,
        'max_epochs_tuning': max_epochs_tuning,
        'early_stop_patience': early_stop_patience,
        'steps_per_epoch': steps_per_epoch,
        'cosine_decay_steps': cosine_decay_steps,
        'dropout': dropout,
        'learning_schedule': learning_schedule,
        'seed': seed
    }

    return config

# %%
config = get_config()
SEED = config['seed']
img_size = config['img_size']
batch_size = config['batch_size']
seed = config['seed']

# %% [markdown]
# create tensorflow dataset

# %%
train_dataset = tf.data.Dataset.from_tensor_slices((X_train, y_train))
train_dataset = train_dataset.shuffle(buffer_size=1000).batch(batch_size).prefetch(tf.data.AUTOTUNE)

val_dataset = tf.data.Dataset.from_tensor_slices((X_val, y_val)).batch(batch_size).prefetch(tf.data.AUTOTUNE)
test_dataset = tf.data.Dataset.from_tensor_slices((X_test, y_test)).batch(batch_size).prefetch(tf.data.AUTOTUNE)

# %% [markdown]
# define loss and metric

# %%
# loss in normalized units [0,1]
# computes mean squared error per landmark in normalized coordinates
# arg: y_true and y_pred in tensor shape (batch_size, num_landmarks, 2) [0,1]
# returns scalar tensor: average MSE over all landmarks in the batch
def landmark_mse(y_true, y_pred):
    y_true = tf.cast(y_true, tf.float32)
    y_pred = tf.cast(y_pred, tf.float32)
    return tf.reduce_mean(tf.reduce_sum(tf.square(y_true - y_pred), axis=-1))


# metric
# mean pixel error
# computes average euclidean distance per landmark in pixels
# arg: y_true and y_pred in tensor shape (batch_size, num_landmarks, 2) [0,1]
#      img_size: tuple [int, int], image height and with (H, W)
# returns scalar tensor: mean pixel error over batch
def mean_pixel_error_metric_160_320(y_true, y_pred):
    H, W = 160,320
    y_true = tf.cast(y_true, tf.float32)
    y_pred = tf.cast(y_pred, tf.float32)
    y_true_px = y_true * tf.constant([W, H], dtype=tf.float32)
    y_pred_px = y_pred * tf.constant([W, H], dtype=tf.float32)
    dist = tf.sqrt(tf.reduce_sum(tf.square(y_true_px - y_pred_px), axis=-1))
    return tf.reduce_mean(dist)

# %% [markdown]
# define model

# %%
from tensorflow.keras.applications import ResNet50

def build_resnet50_landmark_model(input_shape=(160, 320, 3),
                                  num_landmarks=18,
                                  trainable_backbone=False):
    backbone = ResNet50(
        include_top=False,
        weights='imagenet',
        input_shape=input_shape,
        pooling=None
    )
    backbone.trainable = trainable_backbone

    inputs = tf.keras.Input(shape=input_shape)
    x = backbone(inputs, training=False)
    x = tf.keras.layers.GlobalAveragePooling2D()(x)

    # head
    x = tf.keras.layers.Dense(256, activation='relu')(x)
    x = tf.keras.layers.Dropout(0.3)(x)
    x = tf.keras.layers.Dense(128, activation='relu')(x)
    x = tf.keras.layers.Dropout(0.3)(x)

    # output
    x = tf.keras.layers.Dense(num_landmarks * 2, activation='sigmoid')(x)
    outputs = tf.keras.layers.Reshape((num_landmarks, 2))(x)

    return tf.keras.Model(inputs, outputs, name='resnet50_landmark_model')

# %%
input_shape = (160, 320, 3)
num_landmarks = 18

model = build_resnet50_landmark_model(input_shape=input_shape, num_landmarks=num_landmarks)

model.compile(optimizer=tf.keras.optimizers.Adam(learning_rate=config['learning_rate_transfer']),
              loss=landmark_mse,
              metrics=[mean_pixel_error_metric_160_320])

model.summary()
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/keras-applications/resnet/resnet50_weights_tf_dim_ordering_tf_kernels_notop.h5
# 94765736/94765736 ━━━━━━━━━━━━━━━━━━━━ 5s 0us/step
# Model: "resnet50_landmark_model"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ input_layer_1 (InputLayer)      │ (None, 160, 320, 3)    │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ resnet50 (Functional)           │ (None, 5, 10, 2048)    │    23,587,712 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ global_average_pooling2d        │ (None, 2048)           │             0 │
# │ (GlobalAveragePooling2D)        │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense (Dense)                   │ (None, 256)            │       524,544 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout (Dropout)               │ (None, 256)            │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_1 (Dense)                 │ (None, 128)            │        32,896 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_1 (Dropout)             │ (None, 128)            │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_2 (Dense)                 │ (None, 36)             │         4,644 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ reshape (Reshape)               │ (None, 18, 2)          │             0 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 24,149,796 (92.12 MB)
#  Trainable params: 562,084 (2.14 MB)
#  Non-trainable params: 23,587,712 (89.98 MB)

# %% [markdown]
# callbacks // weights and biases

# %%
wandb.init(project='mosquito_landmarks',name=f"{config['model_name']}",config=config)

callbacks = [EarlyStopping(monitor='val_loss',
            patience=config['early_stop_patience'],
            restore_best_weights=True,
            verbose=1),
            WandbMetricsLogger(),
            WandbModelCheckpoint("wandb_model.keras")]
# Out:
# /usr/local/lib/python3.12/dist-packages/notebook/notebookapp.py:191: SyntaxWarning: invalid escape sequence '\/'
#   | |_| | '_ \/ _` / _` |  _/ -_)
# wandb: Logging into wandb.ai. (Learn how to deploy a W&B server locally: https://wandb.me/wandb-server)
# wandb: You can find your API key in your browser here: https://wandb.ai/authorize?ref=models
# wandb: Paste an API key from your profile and hit enter:
#  ··········
# wandb: WARNING If you're specifying your api key in code, ensure this code is not shared publicly.
# wandb: WARNING Consider setting the WANDB_API_KEY environment variable, or running `wandb login` from the command line.
# wandb: No netrc file found, creating one.
# wandb: Appending key for api.wandb.ai to your netrc file: /root/.netrc
# wandb: Currently logged in as: arlettedel (arlettedel-universit-t-hamburg) to https://api.wandb.ai. Use `wandb login --relogin` to force relogin
# Tracking run with wandb version 0.21.1
# Run data is saved locally in <code>/content/wandb/run-20250829_105208-lrxu7ifn</code>
# Syncing run <strong><a href='https://wandb.ai/arlettedel-universit-t-hamburg/mosquito_landmarks/runs/lrxu7ifn' target="_blank">resnet50_withIphone_ohne_augmentation</a></strong> to <a href='https://wandb.ai/arlettedel-universit-t-hamburg/mosquito_landmarks' target="_blank">Weights & Biases</a> (<a href='https://wandb.me/developer-guide' target="_blank">docs</a>)<br>
#  View project at <a href='https://wandb.ai/arlettedel-universit-t-hamburg/mosquito_landmarks' target="_blank">https://wandb.ai/arlettedel-universit-t-hamburg/mosquito_landmarks</a>
#  View run at <a href='https://wandb.ai/arlettedel-universit-t-hamburg/mosquito_landmarks/runs/lrxu7ifn' target="_blank">https://wandb.ai/arlettedel-universit-t-hamburg/mosquito_landmarks/runs/lrxu7ifn</a>

# %% [markdown]
# train model

# %%
history = model.fit(train_dataset, validation_data=val_dataset,
                    epochs=config['max_epochs_transfer'],
                    callbacks=callbacks,
                    verbose=1)
# Out:
# Epoch 1/50
# 186/186 ━━━━━━━━━━━━━━━━━━━━ 38s 130ms/step - loss: 0.0887 - mean_pixel_error_metric_160_320: 76.3621 - val_loss: 0.0629 - val_mean_pixel_error_metric_160_320: 64.1440
# Epoch 2/50
# 186/186 ━━━━━━━━━━━━━━━━━━━━ 12s 65ms/step - loss: 0.0603 - mean_pixel_error_metric_160_320: 59.8869 - val_loss: 0.0268 - val_mean_pixel_error_metric_160_320: 37.0362
# Epoch 3/50
# 186/186 ━━━━━━━━━━━━━━━━━━━━ 12s 66ms/step - loss: 0.0398 - mean_pixel_error_metric_160_320: 43.8625 - val_loss: 0.0169 - val_mean_pixel_error_metric_160_320: 27.9582
# Epoch 4/50
# 186/186 ━━━━━━━━━━━━━━━━━━━━ 12s 67ms/step - loss: 0.0229 - mean_pixel_error_metric_160_320: 31.2266 - val_loss: 0.0080 - val_mean_pixel_error_metric_160_320: 17.0902
# Epoch 5/50
# 186/186 ━━━━━━━━━━━━━━━━━━━━ 13s 68ms/step - loss: 0.0152 - mean_pixel_error_metric_160_320: 24.0876 - val_loss: 0.0250 - val_mean_pixel_error_metric_160_320: 28.0746
# Epoch 6/50
# 186/186 ━━━━━━━━━━━━━━━━━━━━ 12s 67ms/step - loss: 0.0291 - mean_pixel_error_metric_160_320: 32.1289 - val_loss: 0.0267 - val_mean_pixel_error_metric_160_320: 30.1477
# Epoch 7/50
# 186/186 ━━━━━━━━━━━━━━━━━━━━ 13s 68ms/step - loss: 0.0236 - mean_pixel_error_metric_160_320: 29.5394 - val_loss: 0.0077 - val_mean_pixel_error_metric_160_320: 17.9521
# Epoch 8/50
# 186/186 ━━━━━━━━━━━━━━━━━━━━ 13s 68ms/step - loss: 0.0208 - mean_pixel_error_metric_160_320: 26.8570 - val_loss: 0.0069 - val_mean_pixel_error_metric_160_320: 16.9460
# Epoch 9/50
# 186/186 ━━━━━━━━━━━━━━━━━━━━ 13s 69ms/step - loss: 0.0233 - mean_pixel_error_metric_160_320: 28.8446 - val_loss: 0.0098 - val_mean_pixel_error_metric_160_320: 18.1228
# Epoch 10/50
# 186/186 ━━━━━━━━━━━━━━━━━━━━ 13s 68ms/step - loss: 0.0247 - mean_pixel_error_metric_160_320: 27.9760 - val_loss: 0.0045 - val_mean_pixel_error_metric_160_320: 11.9968
# Epoch 11/50
# 186/186 ━━━━━━━━━━━━━━━━━━━━ 13s 67ms/step - loss: 0.0190 - mean_pixel_error_metric_160_320: 24.7951 - val_loss: 0.0105 - val_mean_pixel_error_metric_160_320: 17.1913
# Epoch 12/50
# 186/186 ━━━━━━━━━━━━━━━━━━━━ 12s 67ms/step - loss: 0.0192 - mean_pixel_error_metric_160_320: 24.6759 - val_loss: 0.0104 - val_mean_pixel_error_metric_160_320: 18.6666
# Epoch 13/50
# 186/186 ━━━━━━━━━━━━━━━━━━━━ 12s 67ms/step - loss: 0.0192 - mean_pixel_error_metric_160_320: 25.0874 - val_loss: 0.0070 - val_mean_pixel_error_metric_160_320: 17.9571
# Epoch 14/50
# 186/186 ━━━━━━━━━━━━━━━━━━━━ 13s 68ms/step - loss: 0.0241 - mean_pixel_error_metric_160_320: 27.4759 - val_loss: 0.0080 - val_mean_pixel_error_metric_160_320: 18.4972
# Epoch 15/50
# 186/186 ━━━━━━━━━━━━━━━━━━━━ 13s 68ms/step - loss: 0.0239 - mean_pixel_error_metric_160_320: 27.3849 - val_loss: 0.0072 - val_mean_pixel_error_metric_160_320: 18.6524
# Epoch 16/50
# 186/186 ━━━━━━━━━━━━━━━━━━━━ 12s 67ms/step - loss: 0.0214 - mean_pixel_error_metric_160_320: 24.6672 - val_loss: 0.0068 - val_mean_pixel_error_metric_160_320: 17.5385
# Epoch 17/50
# 186/186 ━━━━━━━━━━━━━━━━━━━━ 12s 67ms/step - loss: 0.0220 - mean_pixel_error_metric_160_320: 25.4386 - val_loss: 0.0188 - val_mean_pixel_error_metric_160_320: 24.2976
# Epoch 18/50
# 186/186 ━━━━━━━━━━━━━━━━━━━━ 12s 67ms/step - loss: 0.0302 - mean_pixel_error_metric_160_320: 30.7633 - val_loss: 0.0070 - val_mean_pixel_error_metric_160_320: 18.3456
# Epoch 19/50
# 186/186 ━━━━━━━━━━━━━━━━━━━━ 12s 67ms/step - loss: 0.0236 - mean_pixel_error_metric_160_320: 26.5914 - val_loss: 0.0055 - val_mean_pixel_error_metric_160_320: 15.9574
# Epoch 20/50
# 186/186 ━━━━━━━━━━━━━━━━━━━━ 12s 67ms/step - loss: 0.0208 - mean_pixel_error_metric_160_320: 23.9484 - val_loss: 0.0073 - val_mean_pixel_error_metric_160_320: 17.5817
# Epoch 20: early stopping
# Restoring model weights from the end of the best epoch: 10.

# %% [markdown]
# fine tuning

# %%
# unfreeze layer for fine tuning
for layer in model.layers:
    layer.trainable = True

# new optimizer for fine tuning
optimizer = tf.keras.optimizers.Adam(
    learning_rate=config['learning_rate_tuning'])

model.compile(optimizer=optimizer, loss=landmark_mse)

# callback fine tuning
callbacks_ft = [
    EarlyStopping(
        monitor='val_loss',
        patience=config['early_stop_patience'],
        restore_best_weights=True,
        verbose=1),
    WandbMetricsLogger(),
    WandbModelCheckpoint("wandb_model_finetuned.keras")]

# wandb
wandb.init(
    project='mosquito_landmarks',
    name=f"{config['model_name']}_finetune",
    config=config,
    reinit=True)  # important for new run

# fine tuning
history_ft = model.fit(
    train_dataset,
    validation_data=val_dataset,
    epochs=config['max_epochs_tuning'],
    callbacks=callbacks_ft,
    verbose=1)
# Out:
# Finishing previous runs because reinit is set to True.
# <br>    <style><br>        .wandb-row {<br>            display: flex;<br>            flex-direction: row;<br>            flex-wrap: wrap;<br>            justify-content: flex-start;<br>            width: 100%;<br>        }<br>        .wandb-col {<br>            display: flex;<br>            flex-direction: column;<br>            flex-basis: 100%;<br>            flex: 1;<br>            padding: 10px;<br>        }<br>    </style><br><div class="wandb-row"><div class="wandb-col"><h3>Run history:</h3><br/><table class="wandb"><tr><td>epoch/epoch</td><td>▁▁▂▂▂▃▃▄▄▄▅▅▅▆▆▇▇▇██</td></tr><tr><td>epoch/learning_rate</td><td>▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁</td></tr><tr><td>epoch/loss</td><td>█▅▃▂▁▂▂▂▂▂▂▁▂▂▂▂▂▂▂▂</td></tr><tr><td>epoch/mean_pixel_error_metric_160_320</td><td>█▅▃▂▁▂▂▁▂▁▁▁▁▁▁▁▁▂▁▁</td></tr><tr><td>epoch/val_loss</td><td>█▄▂▁▃▄▁▁▂▁▂▂▁▁▁▁▃▁▁▁</td></tr><tr><td>epoch/val_mean_pixel_error_metric_160_320</td><td>█▄▃▂▃▃▂▂▂▁▂▂▂▂▂▂▃▂▂▂</td></tr></table><br/></div><div class="wandb-col"><h3>Run summary:</h3><br/><table class="wandb"><tr><td>epoch/epoch</td><td>19</td></tr><tr><td>epoch/learning_rate</td><td>0.001</td></tr><tr><td>epoch/loss</td><td>0.02262</td></tr><tr><td>epoch/mean_pixel_error_metric_160_320</td><td>25.30374</td></tr><tr><td>epoch/val_loss</td><td>0.00726</td></tr><tr><td>epoch/val_mean_pixel_error_metric_160_320</td><td>17.58169</td></tr></table><br/></div></div>
#  View run <strong style="color:#cdcd00">resnet50_withIphone_ohne_augmentation</strong> at: <a href='https://wandb.ai/arlettedel-universit-t-hamburg/mosquito_landmarks/runs/lrxu7ifn' target="_blank">https://wandb.ai/arlettedel-universit-t-hamburg/mosquito_landmarks/runs/lrxu7ifn</a><br> View project at: <a href='https://wandb.ai/arlettedel-universit-t-hamburg/mosquito_landmarks' target="_blank">https://wandb.ai/arlettedel-universit-t-hamburg/mosquito_landmarks</a><br>Synced 5 W&B file(s), 0 media file(s), 40 artifact file(s) and 0 other file(s)
# Find logs at: <code>./wandb/run-20250829_105208-lrxu7ifn/logs</code>
# wandb: WARNING Using a boolean value for 'reinit' is deprecated. Use 'return_previous' or 'finish_previous' instead.
# Tracking run with wandb version 0.21.1
# Run data is saved locally in <code>/content/wandb/run-20250829_105725-27oejhau</code>
# Syncing run <strong><a href='https://wandb.ai/arlettedel-universit-t-hamburg/mosquito_landmarks/runs/27oejhau' target="_blank">resnet50_withIphone_ohne_augmentation_finetune</a></strong> to <a href='https://wandb.ai/arlettedel-universit-t-hamburg/mosquito_landmarks' target="_blank">Weights & Biases</a> (<a href='https://wandb.me/developer-guide' target="_blank">docs</a>)<br>
#  View project at <a href='https://wandb.ai/arlettedel-universit-t-hamburg/mosquito_landmarks' target="_blank">https://wandb.ai/arlettedel-universit-t-hamburg/mosquito_landmarks</a>
#  View run at <a href='https://wandb.ai/arlettedel-universit-t-hamburg/mosquito_landmarks/runs/27oejhau' target="_blank">https://wandb.ai/arlettedel-universit-t-hamburg/mosquito_landmarks/runs/27oejhau</a>
# Epoch 1/100
# 186/186 ━━━━━━━━━━━━━━━━━━━━ 114s 328ms/step - loss: 0.0482 - mean_pixel_error_metric_160_320: 40.0553 - val_loss: 0.1001 - val_mean_pixel_error_metric_160_320: 64.8449
# Epoch 2/100
# 186/186 ━━━━━━━━━━━━━━━━━━━━ 35s 190ms/step - loss: 0.0041 - mean_pixel_error_metric_160_320: 13.9332 - val_loss: 0.0836 - val_mean_pixel_error_metric_160_320: 68.2645
# Epoch 3/100
# 186/186 ━━━━━━━━━━━━━━━━━━━━ 36s 195ms/step - loss: 0.0028 - mean_pixel_error_metric_160_320: 11.2060 - val_loss: 0.0807 - val_mean_pixel_error_metric_160_320: 67.8436
# Epoch 4/100
# 186/186 ━━━━━━━━━━━━━━━━━━━━ 35s 190ms/step - loss: 0.0025 - mean_pixel_error_metric_160_320: 10.4894 - val_loss: 0.0257 - val_mean_pixel_error_metric_160_320: 38.6276
# Epoch 5/100
# 186/186 ━━━━━━━━━━━━━━━━━━━━ 35s 190ms/step - loss: 0.0030 - mean_pixel_error_metric_160_320: 11.1267 - val_loss: 0.2370 - val_mean_pixel_error_metric_160_320: 116.8958
# Epoch 6/100
# 186/186 ━━━━━━━━━━━━━━━━━━━━ 35s 190ms/step - loss: 0.0038 - mean_pixel_error_metric_160_320: 12.3742 - val_loss: 0.0020 - val_mean_pixel_error_metric_160_320: 9.8823
# Epoch 7/100
# 186/186 ━━━━━━━━━━━━━━━━━━━━ 36s 194ms/step - loss: 0.0024 - mean_pixel_error_metric_160_320: 10.1690 - val_loss: 0.0019 - val_mean_pixel_error_metric_160_320: 8.7827
# Epoch 8/100
# 186/186 ━━━━━━━━━━━━━━━━━━━━ 35s 190ms/step - loss: 0.0024 - mean_pixel_error_metric_160_320: 9.9588 - val_loss: 0.0020 - val_mean_pixel_error_metric_160_320: 9.1283
# Epoch 9/100
# 186/186 ━━━━━━━━━━━━━━━━━━━━ 35s 188ms/step - loss: 0.0026 - mean_pixel_error_metric_160_320: 10.2013 - val_loss: 0.0016 - val_mean_pixel_error_metric_160_320: 8.3135
# Epoch 10/100
# 186/186 ━━━━━━━━━━━━━━━━━━━━ 36s 191ms/step - loss: 0.0023 - mean_pixel_error_metric_160_320: 9.9103 - val_loss: 0.0014 - val_mean_pixel_error_metric_160_320: 7.2985
# Epoch 11/100
# 186/186 ━━━━━━━━━━━━━━━━━━━━ 35s 188ms/step - loss: 0.0021 - mean_pixel_error_metric_160_320: 9.3947 - val_loss: 0.0015 - val_mean_pixel_error_metric_160_320: 8.1008
# Epoch 12/100
# 186/186 ━━━━━━━━━━━━━━━━━━━━ 35s 190ms/step - loss: 0.0019 - mean_pixel_error_metric_160_320: 8.9758 - val_loss: 0.0014 - val_mean_pixel_error_metric_160_320: 7.4837
# Epoch 13/100
# 186/186 ━━━━━━━━━━━━━━━━━━━━ 36s 192ms/step - loss: 0.0018 - mean_pixel_error_metric_160_320: 8.5463 - val_loss: 0.0014 - val_mean_pixel_error_metric_160_320: 7.4411
# Epoch 14/100
# 186/186 ━━━━━━━━━━━━━━━━━━━━ 36s 192ms/step - loss: 0.0019 - mean_pixel_error_metric_160_320: 8.4902 - val_loss: 0.0013 - val_mean_pixel_error_metric_160_320: 7.3418
# Epoch 15/100
# 186/186 ━━━━━━━━━━━━━━━━━━━━ 35s 189ms/step - loss: 0.0020 - mean_pixel_error_metric_160_320: 8.9446 - val_loss: 0.0014 - val_mean_pixel_error_metric_160_320: 7.7539
# Epoch 16/100
# 186/186 ━━━━━━━━━━━━━━━━━━━━ 35s 188ms/step - loss: 0.0019 - mean_pixel_error_metric_160_320: 8.8003 - val_loss: 0.0013 - val_mean_pixel_error_metric_160_320: 7.2766
# Epoch 17/100
# 186/186 ━━━━━━━━━━━━━━━━━━━━ 35s 189ms/step - loss: 0.0016 - mean_pixel_error_metric_160_320: 8.2242 - val_loss: 0.0011 - val_mean_pixel_error_metric_160_320: 6.4748
# Epoch 18/100
# 186/186 ━━━━━━━━━━━━━━━━━━━━ 35s 188ms/step - loss: 0.0022 - mean_pixel_error_metric_160_320: 9.8296 - val_loss: 0.0017 - val_mean_pixel_error_metric_160_320: 9.0413
# Epoch 19/100
# 186/186 ━━━━━━━━━━━━━━━━━━━━ 35s 188ms/step - loss: 0.0024 - mean_pixel_error_metric_160_320: 9.5641 - val_loss: 0.0074 - val_mean_pixel_error_metric_160_320: 15.8742
# Epoch 20/100
# 186/186 ━━━━━━━━━━━━━━━━━━━━ 35s 187ms/step - loss: 0.0032 - mean_pixel_error_metric_160_320: 10.6177 - val_loss: 0.2664 - val_mean_pixel_error_metric_160_320: 131.7029
# Epoch 21/100
# 186/186 ━━━━━━━━━━━━━━━━━━━━ 35s 187ms/step - loss: 0.0034 - mean_pixel_error_metric_160_320: 11.2565 - val_loss: 0.0042 - val_mean_pixel_error_metric_160_320: 12.5025
# Epoch 22/100
# 186/186 ━━━━━━━━━━━━━━━━━━━━ 35s 188ms/step - loss: 0.0180 - mean_pixel_error_metric_160_320: 21.4891 - val_loss: 0.0070 - val_mean_pixel_error_metric_160_320: 17.5954
# Epoch 23/100
# 186/186 ━━━━━━━━━━━━━━━━━━━━ 35s 189ms/step - loss: 0.0038 - mean_pixel_error_metric_160_320: 11.9032 - val_loss: 0.0025 - val_mean_pixel_error_metric_160_320: 10.3814
# Epoch 24/100
# 186/186 ━━━━━━━━━━━━━━━━━━━━ 35s 187ms/step - loss: 0.0024 - mean_pixel_error_metric_160_320: 10.3247 - val_loss: 0.0020 - val_mean_pixel_error_metric_160_320: 9.3204
# Epoch 25/100
# 186/186 ━━━━━━━━━━━━━━━━━━━━ 35s 187ms/step - loss: 0.0027 - mean_pixel_error_metric_160_320: 10.4999 - val_loss: 0.0015 - val_mean_pixel_error_metric_160_320: 7.7479
# Epoch 26/100
# 186/186 ━━━━━━━━━━━━━━━━━━━━ 35s 187ms/step - loss: 0.0029 - mean_pixel_error_metric_160_320: 10.2173 - val_loss: 0.0042 - val_mean_pixel_error_metric_160_320: 11.8037
# Epoch 27/100
# 186/186 ━━━━━━━━━━━━━━━━━━━━ 35s 187ms/step - loss: 0.0034 - mean_pixel_error_metric_160_320: 10.4317 - val_loss: 0.0052 - val_mean_pixel_error_metric_160_320: 13.4133
# Epoch 27: early stopping
# Restoring model weights from the end of the best epoch: 17.

# %% [markdown]
# plot loss for train and evaluation

# %%
fig, ax1 = plt.subplots(figsize=(8, 5))

# y1: loss
ax1.plot(history.history['loss'], label='Train Loss', linestyle='-', color='black')
ax1.plot(history.history['val_loss'], label='Val Loss', linestyle='-', color='gray')
ax1.set_xlabel('Epochs', color='black')
ax1.set_ylabel('Loss', color='black')
ax1.tick_params(axis='y', labelcolor='black')
ax1.tick_params(axis='x', labelcolor='black')

# y2: MPE
ax2 = ax1.twinx()
ax2.plot(history.history['mean_pixel_error_metric_160_320'], label='Train MPE', linestyle='--', color='black')
ax2.plot(history.history['val_mean_pixel_error_metric_160_320'], label='Val MPE', linestyle='--', color='gray')
ax2.set_ylabel('Mean Pixel Error [px]', color='black')
ax2.tick_params(axis='y', labelcolor='black')

lines_1, labels_1 = ax1.get_legend_handles_labels()
lines_2, labels_2 = ax2.get_legend_handles_labels()
ax1.legend(lines_1 + lines_2, labels_1 + labels_2, loc='upper right')

plt.title("Training Loss & Mean Pixel Error", color='black')
plt.show()

# %% [markdown]
# mini evaluation test set

# %%
#mpe +- std in pixel coords
pred_coords_norm = model.predict(X_test)
# Out:
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 15s 287ms/step

# %%
distances = np.linalg.norm(y_test - pred_coords_norm, axis=-1)

# %%
# image size
H, W = 160, 320

# convert to pixel size
diff_pixel = (y_test - pred_coords_norm) * np.array([H, W])
distances_pixel = np.linalg.norm(diff_pixel, axis=-1)

# prediction errors
mpe_mean = distances_pixel.mean()
mpe_std = distances_pixel.std()
mpe_median = np.median(distances_pixel)

print(f"Mean Prediction Error (MPE) in pixels: {mpe_mean:.2f} ± {mpe_std:.2f}")
print(f"Median Prediction Error in pixels: {mpe_median:.2f}")
# Out:
# Mean Prediction Error (MPE) in pixels: 5.74 ± 4.30
# Median Prediction Error in pixels: 4.94

# %% [markdown]
# save predictions in normalized pixel coords for evaluation

# %%
save_dir2 = '/content/drive/MyDrive/Arlette/Model_Outputs'
os.makedirs(save_dir2, exist_ok=True)
np.save(f"{save_dir2}/predictions_norm_CNN_no_augmentation.npy", pred_coords_norm)

# %% [markdown]
# save model weights and output

# %%
#save best config based on validation loss

# %%
save_dir = '/content/drive/MyDrive/Arlette/model_weights'
os.makedirs(save_dir, exist_ok=True)

model.save(f'{save_dir}/CNN_no_augmentation.keras')
model.save_weights(f'{save_dir}/CNN_no_augmentation.weights.h5')
