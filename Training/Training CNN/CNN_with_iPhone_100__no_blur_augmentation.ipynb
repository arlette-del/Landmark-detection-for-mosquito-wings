# %% [markdown]
# setup/ import

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import random
import os

import tensorflow as tf

import wandb
from wandb.integration.keras import WandbMetricsLogger, WandbCallback, WandbModelCheckpoint

from sklearn.model_selection import train_test_split

from tensorflow.keras.layers import Dense, Input
from tensorflow.keras.models import Model
from tensorflow.keras.callbacks import EarlyStopping
from tensorflow.keras import layers

# %%
print('Tensorflow version:', tf.__version__)
print('Weights and biases version:', wandb.__version__)
# Out:
# Tensorflow version: 2.19.0
# Weights and biases version: 0.21.1

# %% [markdown]
# load data

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
X_train = np.load('/content/drive/MyDrive/Arlette/Sets for Training /Dataset with iPhone/train_aug_images_no_blur_160x320.npy')
X_val = np.load('/content/drive/MyDrive/Arlette/Sets for Training /Dataset with iPhone/val_images_160x320.npy')
X_test = np.load('/content/drive/MyDrive/Arlette/Sets for Training /Dataset with iPhone/test_images_160x320.npy')

y_train = np.load('/content/drive/MyDrive/Arlette/Sets for Training /Dataset with iPhone/train_aug_landmarks_no_blur.npy')
y_val = np.load('/content/drive/MyDrive/Arlette/Sets for Training /Dataset with iPhone/val_landmarks.npy')
y_test = np.load('/content/drive/MyDrive/Arlette/Sets for Training /Dataset with iPhone/test_landmarks.npy')

# %% [markdown]
# define hyperparameters

# %%
def get_config(model_name='CNN_withIphone_100_no_blur_augmentation',
               img_size=(160, 320),
               batch_size=16,
               learning_rate_transfer=1e-3,
               learning_rate_tuning=5e-4,
               max_epochs_transfer=50,
               max_epochs_tuning=100,
               early_stop_patience=10,
               steps_per_epoch=81,
               dropout=0.5,
               seed=42):

    # cosine decay
    cosine_decay_steps = steps_per_epoch * max_epochs_tuning
    learning_schedule = {
        'initial_learning_rate': learning_rate_tuning,
        'decay_steps': cosine_decay_steps,
        'warmup_target': learning_rate_tuning,
        'warmup_steps': int(cosine_decay_steps * 0.02)
    }

    # config dictionary
    config = {
        'model_name': model_name,
        'img_size': img_size,
        'batch_size': batch_size,
        'learning_rate_transfer': learning_rate_transfer,
        'learning_rate_tuning': learning_rate_tuning,
        'max_epochs_transfer': max_epochs_transfer,
        'max_epochs_tuning': max_epochs_tuning,
        'early_stop_patience': early_stop_patience,
        'steps_per_epoch': steps_per_epoch,
        'cosine_decay_steps': cosine_decay_steps,
        'dropout': dropout,
        'learning_schedule': learning_schedule,
        'seed': seed
    }

    return config

# %%
config = get_config()
SEED = config['seed']
img_size = config['img_size']
batch_size = config['batch_size']
seed = config['seed']

# %% [markdown]
# create tensorflow dataset

# %%
train_dataset = tf.data.Dataset.from_tensor_slices((X_train, y_train))
train_dataset = train_dataset.shuffle(buffer_size=1000).batch(batch_size).prefetch(tf.data.AUTOTUNE)

val_dataset = tf.data.Dataset.from_tensor_slices((X_val, y_val)).batch(batch_size).prefetch(tf.data.AUTOTUNE)
test_dataset = tf.data.Dataset.from_tensor_slices((X_test, y_test)).batch(batch_size).prefetch(tf.data.AUTOTUNE)

# %% [markdown]
# define loss and metric

# %%
# loss in normalized units [0,1]
# computes mean squared error per landmark in normalized coordinates
# arg: y_true and y_pred in tensor shape (batch_size, num_landmarks, 2) [0,1]
# returns scalar tensor: average MSE over all landmarks in the batch
def landmark_mse(y_true, y_pred):
    y_true = tf.cast(y_true, tf.float32)
    y_pred = tf.cast(y_pred, tf.float32)
    return tf.reduce_mean(tf.reduce_sum(tf.square(y_true - y_pred), axis=-1))


# metric
# mean pixel error
# computes average euclidean distance per landmark in pixels
# arg: y_true and y_pred in tensor shape (batch_size, num_landmarks, 2) [0,1]
#      img_size: tuple [int, int], image height and with (H, W)
# returns scalar tensor: mean pixel error over batch
def mean_pixel_error_metric_160_320(y_true, y_pred):
    H, W = 160,320
    y_true = tf.cast(y_true, tf.float32)
    y_pred = tf.cast(y_pred, tf.float32)
    y_true_px = y_true * tf.constant([W, H], dtype=tf.float32)
    y_pred_px = y_pred * tf.constant([W, H], dtype=tf.float32)
    dist = tf.sqrt(tf.reduce_sum(tf.square(y_true_px - y_pred_px), axis=-1))
    return tf.reduce_mean(dist)

# %% [markdown]
# define model

# %%
from tensorflow.keras.applications import ResNet50

def build_resnet50_landmark_model(input_shape=(160, 320, 3),
                                  num_landmarks=18,
                                  trainable_backbone=False):
    backbone = ResNet50(
        include_top=False,
        weights='imagenet',
        input_shape=input_shape,
        pooling=None
    )
    backbone.trainable = trainable_backbone

    inputs = tf.keras.Input(shape=input_shape)
    x = backbone(inputs, training=False)
    x = tf.keras.layers.GlobalAveragePooling2D()(x)

    # head
    x = tf.keras.layers.Dense(256, activation='relu')(x)
    x = tf.keras.layers.Dropout(0.3)(x)
    x = tf.keras.layers.Dense(128, activation='relu')(x)
    x = tf.keras.layers.Dropout(0.3)(x)

    # output
    x = tf.keras.layers.Dense(num_landmarks * 2, activation='sigmoid')(x)
    outputs = tf.keras.layers.Reshape((num_landmarks, 2))(x)

    return tf.keras.Model(inputs, outputs, name='resnet50_landmark_model')

# %%
input_shape = (160, 320, 3)
num_landmarks = 18

model = build_resnet50_landmark_model(input_shape=input_shape, num_landmarks=num_landmarks)

model.compile(optimizer=tf.keras.optimizers.Adam(learning_rate=config['learning_rate_transfer']),
              loss=landmark_mse,
              metrics=[mean_pixel_error_metric_160_320])

model.summary()
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/keras-applications/resnet/resnet50_weights_tf_dim_ordering_tf_kernels_notop.h5
# 94765736/94765736 ━━━━━━━━━━━━━━━━━━━━ 1s 0us/step
# Model: "resnet50_landmark_model"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ input_layer_1 (InputLayer)      │ (None, 160, 320, 3)    │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ resnet50 (Functional)           │ (None, 5, 10, 2048)    │    23,587,712 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ global_average_pooling2d        │ (None, 2048)           │             0 │
# │ (GlobalAveragePooling2D)        │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense (Dense)                   │ (None, 256)            │       524,544 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout (Dropout)               │ (None, 256)            │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_1 (Dense)                 │ (None, 128)            │        32,896 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_1 (Dropout)             │ (None, 128)            │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_2 (Dense)                 │ (None, 36)             │         4,644 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ reshape (Reshape)               │ (None, 18, 2)          │             0 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 24,149,796 (92.12 MB)
#  Trainable params: 562,084 (2.14 MB)
#  Non-trainable params: 23,587,712 (89.98 MB)

# %% [markdown]
# callbacks // weights and biases

# %%
wandb.init(project='mosquito_landmarks',name=f"{config['model_name']}",config=config)

callbacks = [EarlyStopping(monitor='val_loss',
            patience=config['early_stop_patience'],
            restore_best_weights=True,
            verbose=1),
            WandbMetricsLogger(),
            WandbModelCheckpoint("wandb_model.keras")]
# Out:
# /usr/local/lib/python3.12/dist-packages/notebook/notebookapp.py:191: SyntaxWarning: invalid escape sequence '\/'
#   | |_| | '_ \/ _` / _` |  _/ -_)
# wandb: Logging into wandb.ai. (Learn how to deploy a W&B server locally: https://wandb.me/wandb-server)
# wandb: You can find your API key in your browser here: https://wandb.ai/authorize?ref=models
# wandb: Paste an API key from your profile and hit enter:
#  ··········
# wandb: WARNING If you're specifying your api key in code, ensure this code is not shared publicly.
# wandb: WARNING Consider setting the WANDB_API_KEY environment variable, or running `wandb login` from the command line.
# wandb: No netrc file found, creating one.
# wandb: Appending key for api.wandb.ai to your netrc file: /root/.netrc
# wandb: Currently logged in as: arlettedel (arlettedel-universit-t-hamburg) to https://api.wandb.ai. Use `wandb login --relogin` to force relogin
# Tracking run with wandb version 0.21.1
# Run data is saved locally in <code>/content/wandb/run-20250829_134945-1a5okzu4</code>
# Syncing run <strong><a href='https://wandb.ai/arlettedel-universit-t-hamburg/mosquito_landmarks/runs/1a5okzu4' target="_blank">CNN_withIphone_100_no_blur_augmentation</a></strong> to <a href='https://wandb.ai/arlettedel-universit-t-hamburg/mosquito_landmarks' target="_blank">Weights & Biases</a> (<a href='https://wandb.me/developer-guide' target="_blank">docs</a>)<br>
#  View project at <a href='https://wandb.ai/arlettedel-universit-t-hamburg/mosquito_landmarks' target="_blank">https://wandb.ai/arlettedel-universit-t-hamburg/mosquito_landmarks</a>
#  View run at <a href='https://wandb.ai/arlettedel-universit-t-hamburg/mosquito_landmarks/runs/1a5okzu4' target="_blank">https://wandb.ai/arlettedel-universit-t-hamburg/mosquito_landmarks/runs/1a5okzu4</a>

# %% [markdown]
# train model

# %%
history = model.fit(train_dataset, validation_data=val_dataset,
                    epochs=config['max_epochs_transfer'],
                    callbacks=callbacks,
                    verbose=1)
# Out:
# Epoch 1/50
# 186/186 ━━━━━━━━━━━━━━━━━━━━ 43s 142ms/step - loss: 0.0949 - mean_pixel_error_metric_160_320: 80.3341 - val_loss: 0.0812 - val_mean_pixel_error_metric_160_320: 76.0994
# Epoch 2/50
# 186/186 ━━━━━━━━━━━━━━━━━━━━ 12s 66ms/step - loss: 0.0751 - mean_pixel_error_metric_160_320: 70.9563 - val_loss: 0.0402 - val_mean_pixel_error_metric_160_320: 42.3771
# Epoch 3/50
# 186/186 ━━━━━━━━━━━━━━━━━━━━ 12s 67ms/step - loss: 0.0457 - mean_pixel_error_metric_160_320: 48.9061 - val_loss: 0.0292 - val_mean_pixel_error_metric_160_320: 34.3067
# Epoch 4/50
# 186/186 ━━━━━━━━━━━━━━━━━━━━ 12s 67ms/step - loss: 0.0338 - mean_pixel_error_metric_160_320: 39.1651 - val_loss: 0.0191 - val_mean_pixel_error_metric_160_320: 30.5773
# Epoch 5/50
# 186/186 ━━━━━━━━━━━━━━━━━━━━ 13s 69ms/step - loss: 0.0338 - mean_pixel_error_metric_160_320: 39.9161 - val_loss: 0.0190 - val_mean_pixel_error_metric_160_320: 32.4479
# Epoch 6/50
# 186/186 ━━━━━━━━━━━━━━━━━━━━ 13s 67ms/step - loss: 0.0378 - mean_pixel_error_metric_160_320: 39.7851 - val_loss: 0.0139 - val_mean_pixel_error_metric_160_320: 27.5602
# Epoch 7/50
# 186/186 ━━━━━━━━━━━━━━━━━━━━ 12s 67ms/step - loss: 0.0335 - mean_pixel_error_metric_160_320: 36.8963 - val_loss: 0.0094 - val_mean_pixel_error_metric_160_320: 20.8585
# Epoch 8/50
# 186/186 ━━━━━━━━━━━━━━━━━━━━ 12s 67ms/step - loss: 0.0304 - mean_pixel_error_metric_160_320: 34.2015 - val_loss: 0.0224 - val_mean_pixel_error_metric_160_320: 29.7974
# Epoch 9/50
# 186/186 ━━━━━━━━━━━━━━━━━━━━ 13s 68ms/step - loss: 0.0333 - mean_pixel_error_metric_160_320: 36.4408 - val_loss: 0.0069 - val_mean_pixel_error_metric_160_320: 16.6806
# Epoch 10/50
# 186/186 ━━━━━━━━━━━━━━━━━━━━ 13s 68ms/step - loss: 0.0318 - mean_pixel_error_metric_160_320: 35.0655 - val_loss: 0.0054 - val_mean_pixel_error_metric_160_320: 13.4603
# Epoch 11/50
# 186/186 ━━━━━━━━━━━━━━━━━━━━ 12s 67ms/step - loss: 0.0310 - mean_pixel_error_metric_160_320: 33.9863 - val_loss: 0.0095 - val_mean_pixel_error_metric_160_320: 22.3314
# Epoch 12/50
# 186/186 ━━━━━━━━━━━━━━━━━━━━ 12s 67ms/step - loss: 0.0320 - mean_pixel_error_metric_160_320: 34.9291 - val_loss: 0.0072 - val_mean_pixel_error_metric_160_320: 17.9816
# Epoch 13/50
# 186/186 ━━━━━━━━━━━━━━━━━━━━ 13s 67ms/step - loss: 0.0311 - mean_pixel_error_metric_160_320: 34.2554 - val_loss: 0.0138 - val_mean_pixel_error_metric_160_320: 24.8308
# Epoch 14/50
# 186/186 ━━━━━━━━━━━━━━━━━━━━ 13s 68ms/step - loss: 0.0317 - mean_pixel_error_metric_160_320: 35.0324 - val_loss: 0.0058 - val_mean_pixel_error_metric_160_320: 13.8763
# Epoch 15/50
# 186/186 ━━━━━━━━━━━━━━━━━━━━ 13s 68ms/step - loss: 0.0317 - mean_pixel_error_metric_160_320: 34.3065 - val_loss: 0.0077 - val_mean_pixel_error_metric_160_320: 18.8810
# Epoch 16/50
# 186/186 ━━━━━━━━━━━━━━━━━━━━ 13s 68ms/step - loss: 0.0294 - mean_pixel_error_metric_160_320: 32.9391 - val_loss: 0.0103 - val_mean_pixel_error_metric_160_320: 17.9425
# Epoch 17/50
# 186/186 ━━━━━━━━━━━━━━━━━━━━ 13s 68ms/step - loss: 0.0316 - mean_pixel_error_metric_160_320: 34.1068 - val_loss: 0.0059 - val_mean_pixel_error_metric_160_320: 14.3932
# Epoch 18/50
# 186/186 ━━━━━━━━━━━━━━━━━━━━ 13s 68ms/step - loss: 0.0300 - mean_pixel_error_metric_160_320: 32.9382 - val_loss: 0.0112 - val_mean_pixel_error_metric_160_320: 17.9110
# Epoch 19/50
# 186/186 ━━━━━━━━━━━━━━━━━━━━ 13s 69ms/step - loss: 0.0425 - mean_pixel_error_metric_160_320: 42.7279 - val_loss: 0.0047 - val_mean_pixel_error_metric_160_320: 13.4927
# Epoch 20/50
# 186/186 ━━━━━━━━━━━━━━━━━━━━ 13s 70ms/step - loss: 0.0322 - mean_pixel_error_metric_160_320: 34.3876 - val_loss: 0.0043 - val_mean_pixel_error_metric_160_320: 12.4672
# Epoch 21/50
# 186/186 ━━━━━━━━━━━━━━━━━━━━ 13s 68ms/step - loss: 0.0295 - mean_pixel_error_metric_160_320: 32.8008 - val_loss: 0.0097 - val_mean_pixel_error_metric_160_320: 18.7517
# Epoch 22/50
# 186/186 ━━━━━━━━━━━━━━━━━━━━ 13s 68ms/step - loss: 0.0289 - mean_pixel_error_metric_160_320: 32.3342 - val_loss: 0.0045 - val_mean_pixel_error_metric_160_320: 12.7834
# Epoch 23/50
# 186/186 ━━━━━━━━━━━━━━━━━━━━ 13s 68ms/step - loss: 0.0290 - mean_pixel_error_metric_160_320: 31.9890 - val_loss: 0.0098 - val_mean_pixel_error_metric_160_320: 20.1225
# Epoch 24/50
# 186/186 ━━━━━━━━━━━━━━━━━━━━ 13s 68ms/step - loss: 0.0280 - mean_pixel_error_metric_160_320: 31.4156 - val_loss: 0.0050 - val_mean_pixel_error_metric_160_320: 13.9606
# Epoch 25/50
# 186/186 ━━━━━━━━━━━━━━━━━━━━ 13s 68ms/step - loss: 0.0298 - mean_pixel_error_metric_160_320: 32.7763 - val_loss: 0.0044 - val_mean_pixel_error_metric_160_320: 13.1504
# Epoch 26/50
# 186/186 ━━━━━━━━━━━━━━━━━━━━ 13s 68ms/step - loss: 0.0302 - mean_pixel_error_metric_160_320: 32.8935 - val_loss: 0.0174 - val_mean_pixel_error_metric_160_320: 28.2600
# Epoch 27/50
# 186/186 ━━━━━━━━━━━━━━━━━━━━ 13s 68ms/step - loss: 0.0291 - mean_pixel_error_metric_160_320: 32.5804 - val_loss: 0.0098 - val_mean_pixel_error_metric_160_320: 16.8802
# Epoch 28/50
# 186/186 ━━━━━━━━━━━━━━━━━━━━ 13s 69ms/step - loss: 0.0298 - mean_pixel_error_metric_160_320: 33.0585 - val_loss: 0.0042 - val_mean_pixel_error_metric_160_320: 11.2033
# Epoch 29/50
# 186/186 ━━━━━━━━━━━━━━━━━━━━ 13s 68ms/step - loss: 0.0306 - mean_pixel_error_metric_160_320: 33.2005 - val_loss: 0.0043 - val_mean_pixel_error_metric_160_320: 12.8568
# Epoch 30/50
# 186/186 ━━━━━━━━━━━━━━━━━━━━ 13s 68ms/step - loss: 0.0294 - mean_pixel_error_metric_160_320: 32.3705 - val_loss: 0.0126 - val_mean_pixel_error_metric_160_320: 20.6993
# Epoch 31/50
# 186/186 ━━━━━━━━━━━━━━━━━━━━ 13s 68ms/step - loss: 0.0308 - mean_pixel_error_metric_160_320: 33.5884 - val_loss: 0.0052 - val_mean_pixel_error_metric_160_320: 14.2744
# Epoch 32/50
# 186/186 ━━━━━━━━━━━━━━━━━━━━ 13s 70ms/step - loss: 0.0300 - mean_pixel_error_metric_160_320: 32.8101 - val_loss: 0.0042 - val_mean_pixel_error_metric_160_320: 10.3899
# Epoch 33/50
# 186/186 ━━━━━━━━━━━━━━━━━━━━ 13s 69ms/step - loss: 0.0304 - mean_pixel_error_metric_160_320: 33.0830 - val_loss: 0.0042 - val_mean_pixel_error_metric_160_320: 12.6866
# Epoch 34/50
# 186/186 ━━━━━━━━━━━━━━━━━━━━ 13s 69ms/step - loss: 0.0279 - mean_pixel_error_metric_160_320: 31.0291 - val_loss: 0.0048 - val_mean_pixel_error_metric_160_320: 10.8394
# Epoch 35/50
# 186/186 ━━━━━━━━━━━━━━━━━━━━ 13s 69ms/step - loss: 0.0323 - mean_pixel_error_metric_160_320: 34.1585 - val_loss: 0.0092 - val_mean_pixel_error_metric_160_320: 18.3303
# Epoch 36/50
# 186/186 ━━━━━━━━━━━━━━━━━━━━ 13s 68ms/step - loss: 0.0296 - mean_pixel_error_metric_160_320: 32.5089 - val_loss: 0.0050 - val_mean_pixel_error_metric_160_320: 13.0416
# Epoch 37/50
# 186/186 ━━━━━━━━━━━━━━━━━━━━ 13s 69ms/step - loss: 0.0288 - mean_pixel_error_metric_160_320: 31.5153 - val_loss: 0.0042 - val_mean_pixel_error_metric_160_320: 11.3858
# Epoch 38/50
# 186/186 ━━━━━━━━━━━━━━━━━━━━ 13s 69ms/step - loss: 0.0303 - mean_pixel_error_metric_160_320: 32.9816 - val_loss: 0.0056 - val_mean_pixel_error_metric_160_320: 15.3421
# Epoch 38: early stopping
# Restoring model weights from the end of the best epoch: 28.

# %% [markdown]
# fine tuning

# %%
# unfreeze layer for fine tuning
for layer in model.layers:
    layer.trainable = True

# new optimizer for fine tuning
optimizer = tf.keras.optimizers.Adam(
    learning_rate=config['learning_rate_tuning'])

model.compile(optimizer=optimizer, loss=landmark_mse)

# callback fine tuning
callbacks_ft = [
    EarlyStopping(
        monitor='val_loss',
        patience=config['early_stop_patience'],
        restore_best_weights=True,
        verbose=1),
    WandbMetricsLogger(),
    WandbModelCheckpoint("wandb_model_finetuned.keras")]

# wandb
wandb.init(
    project='mosquito_landmarks',
    name=f"{config['model_name']}_finetune",
    config=config,
    reinit=True)  # important for new run

# fine tuning
history_ft = model.fit(
    train_dataset,
    validation_data=val_dataset,
    epochs=config['max_epochs_tuning'],
    callbacks=callbacks_ft,
    verbose=1)
# Out:
# Finishing previous runs because reinit is set to True.
# <br>    <style><br>        .wandb-row {<br>            display: flex;<br>            flex-direction: row;<br>            flex-wrap: wrap;<br>            justify-content: flex-start;<br>            width: 100%;<br>        }<br>        .wandb-col {<br>            display: flex;<br>            flex-direction: column;<br>            flex-basis: 100%;<br>            flex: 1;<br>            padding: 10px;<br>        }<br>    </style><br><div class="wandb-row"><div class="wandb-col"><h3>Run history:</h3><br/><table class="wandb"><tr><td>epoch/epoch</td><td>▁▁▁▂▂▂▂▂▃▃▃▃▃▃▄▄▄▄▄▅▅▅▅▅▆▆▆▆▆▆▇▇▇▇▇███</td></tr><tr><td>epoch/learning_rate</td><td>▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁</td></tr><tr><td>epoch/loss</td><td>█▅▂▁▁▂▂▁▁▁▁▁▁▁▁▁▁▁▂▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁</td></tr><tr><td>epoch/mean_pixel_error_metric_160_320</td><td>█▆▃▂▂▂▂▁▂▂▁▂▁▂▁▁▁▁▂▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁</td></tr><tr><td>epoch/val_loss</td><td>█▄▃▂▂▂▁▃▁▁▁▁▂▁▁▂▁▂▁▁▂▁▂▁▁▂▂▁▁▂▁▁▁▁▁▁▁▁</td></tr><tr><td>epoch/val_mean_pixel_error_metric_160_320</td><td>█▄▄▃▃▃▂▃▂▁▂▂▃▁▂▂▁▂▁▁▂▁▂▁▁▃▂▁▁▂▁▁▁▁▂▁▁▂</td></tr></table><br/></div><div class="wandb-col"><h3>Run summary:</h3><br/><table class="wandb"><tr><td>epoch/epoch</td><td>37</td></tr><tr><td>epoch/learning_rate</td><td>0.001</td></tr><tr><td>epoch/loss</td><td>0.03129</td></tr><tr><td>epoch/mean_pixel_error_metric_160_320</td><td>33.90227</td></tr><tr><td>epoch/val_loss</td><td>0.00564</td></tr><tr><td>epoch/val_mean_pixel_error_metric_160_320</td><td>15.34207</td></tr></table><br/></div></div>
#  View run <strong style="color:#cdcd00">CNN_withIphone_100_no_blur_augmentation</strong> at: <a href='https://wandb.ai/arlettedel-universit-t-hamburg/mosquito_landmarks/runs/1a5okzu4' target="_blank">https://wandb.ai/arlettedel-universit-t-hamburg/mosquito_landmarks/runs/1a5okzu4</a><br> View project at: <a href='https://wandb.ai/arlettedel-universit-t-hamburg/mosquito_landmarks' target="_blank">https://wandb.ai/arlettedel-universit-t-hamburg/mosquito_landmarks</a><br>Synced 5 W&B file(s), 0 media file(s), 76 artifact file(s) and 0 other file(s)
# Find logs at: <code>./wandb/run-20250829_134945-1a5okzu4/logs</code>
# wandb: WARNING Using a boolean value for 'reinit' is deprecated. Use 'return_previous' or 'finish_previous' instead.
# Tracking run with wandb version 0.21.1
# Run data is saved locally in <code>/content/wandb/run-20250829_140119-h5blf2qz</code>
# Syncing run <strong><a href='https://wandb.ai/arlettedel-universit-t-hamburg/mosquito_landmarks/runs/h5blf2qz' target="_blank">CNN_withIphone_100_no_blur_augmentation_finetune</a></strong> to <a href='https://wandb.ai/arlettedel-universit-t-hamburg/mosquito_landmarks' target="_blank">Weights & Biases</a> (<a href='https://wandb.me/developer-guide' target="_blank">docs</a>)<br>
#  View project at <a href='https://wandb.ai/arlettedel-universit-t-hamburg/mosquito_landmarks' target="_blank">https://wandb.ai/arlettedel-universit-t-hamburg/mosquito_landmarks</a>
#  View run at <a href='https://wandb.ai/arlettedel-universit-t-hamburg/mosquito_landmarks/runs/h5blf2qz' target="_blank">https://wandb.ai/arlettedel-universit-t-hamburg/mosquito_landmarks/runs/h5blf2qz</a>
# Epoch 1/100
# 186/186 ━━━━━━━━━━━━━━━━━━━━ 126s 345ms/step - loss: 0.0700 - mean_pixel_error_metric_160_320: 51.0801 - val_loss: 0.0697 - val_mean_pixel_error_metric_160_320: 69.8474
# Epoch 2/100
# 186/186 ━━━━━━━━━━━━━━━━━━━━ 35s 191ms/step - loss: 0.0039 - mean_pixel_error_metric_160_320: 13.8038 - val_loss: 0.0902 - val_mean_pixel_error_metric_160_320: 79.3290
# Epoch 3/100
# 186/186 ━━━━━━━━━━━━━━━━━━━━ 36s 193ms/step - loss: 0.0031 - mean_pixel_error_metric_160_320: 12.2689 - val_loss: 0.0702 - val_mean_pixel_error_metric_160_320: 61.8330
# Epoch 4/100
# 186/186 ━━━━━━━━━━━━━━━━━━━━ 36s 192ms/step - loss: 0.0042 - mean_pixel_error_metric_160_320: 12.3561 - val_loss: 0.0222 - val_mean_pixel_error_metric_160_320: 33.1048
# Epoch 5/100
# 186/186 ━━━━━━━━━━━━━━━━━━━━ 36s 192ms/step - loss: 0.0034 - mean_pixel_error_metric_160_320: 12.6152 - val_loss: 0.0023 - val_mean_pixel_error_metric_160_320: 10.2626
# Epoch 6/100
# 186/186 ━━━━━━━━━━━━━━━━━━━━ 36s 191ms/step - loss: 0.0025 - mean_pixel_error_metric_160_320: 10.3781 - val_loss: 0.0077 - val_mean_pixel_error_metric_160_320: 20.3728
# Epoch 7/100
# 186/186 ━━━━━━━━━━━━━━━━━━━━ 36s 192ms/step - loss: 0.0031 - mean_pixel_error_metric_160_320: 11.5824 - val_loss: 0.0021 - val_mean_pixel_error_metric_160_320: 9.8783
# Epoch 8/100
# 186/186 ━━━━━━━━━━━━━━━━━━━━ 36s 191ms/step - loss: 0.0022 - mean_pixel_error_metric_160_320: 9.9200 - val_loss: 0.0029 - val_mean_pixel_error_metric_160_320: 12.3647
# Epoch 9/100
# 186/186 ━━━━━━━━━━━━━━━━━━━━ 36s 191ms/step - loss: 0.0049 - mean_pixel_error_metric_160_320: 15.1932 - val_loss: 0.0027 - val_mean_pixel_error_metric_160_320: 11.7286
# Epoch 10/100
# 186/186 ━━━━━━━━━━━━━━━━━━━━ 36s 191ms/step - loss: 0.0026 - mean_pixel_error_metric_160_320: 10.9172 - val_loss: 0.0056 - val_mean_pixel_error_metric_160_320: 14.8414
# Epoch 11/100
# 186/186 ━━━━━━━━━━━━━━━━━━━━ 36s 191ms/step - loss: 0.0033 - mean_pixel_error_metric_160_320: 12.1215 - val_loss: 0.0028 - val_mean_pixel_error_metric_160_320: 12.1353
# Epoch 12/100
# 186/186 ━━━━━━━━━━━━━━━━━━━━ 36s 191ms/step - loss: 0.0025 - mean_pixel_error_metric_160_320: 10.2563 - val_loss: 0.0021 - val_mean_pixel_error_metric_160_320: 10.0263
# Epoch 13/100
# 186/186 ━━━━━━━━━━━━━━━━━━━━ 36s 191ms/step - loss: 0.0023 - mean_pixel_error_metric_160_320: 10.1341 - val_loss: 0.0024 - val_mean_pixel_error_metric_160_320: 10.7824
# Epoch 14/100
# 186/186 ━━━━━━━━━━━━━━━━━━━━ 36s 192ms/step - loss: 0.0022 - mean_pixel_error_metric_160_320: 10.1154 - val_loss: 0.0021 - val_mean_pixel_error_metric_160_320: 9.9907
# Epoch 15/100
# 186/186 ━━━━━━━━━━━━━━━━━━━━ 35s 190ms/step - loss: 0.0023 - mean_pixel_error_metric_160_320: 9.9398 - val_loss: 0.0021 - val_mean_pixel_error_metric_160_320: 9.9890
# Epoch 16/100
# 186/186 ━━━━━━━━━━━━━━━━━━━━ 36s 191ms/step - loss: 0.0020 - mean_pixel_error_metric_160_320: 9.3712 - val_loss: 0.0018 - val_mean_pixel_error_metric_160_320: 9.2044
# Epoch 17/100
# 186/186 ━━━━━━━━━━━━━━━━━━━━ 36s 191ms/step - loss: 0.0022 - mean_pixel_error_metric_160_320: 9.6463 - val_loss: 0.0021 - val_mean_pixel_error_metric_160_320: 10.3244
# Epoch 18/100
# 186/186 ━━━━━━━━━━━━━━━━━━━━ 36s 192ms/step - loss: 0.0020 - mean_pixel_error_metric_160_320: 8.9202 - val_loss: 0.0017 - val_mean_pixel_error_metric_160_320: 8.6385
# Epoch 19/100
# 186/186 ━━━━━━━━━━━━━━━━━━━━ 35s 190ms/step - loss: 0.0022 - mean_pixel_error_metric_160_320: 9.0059 - val_loss: 0.0019 - val_mean_pixel_error_metric_160_320: 9.4837
# Epoch 20/100
# 186/186 ━━━━━━━━━━━━━━━━━━━━ 35s 190ms/step - loss: 0.0022 - mean_pixel_error_metric_160_320: 9.1250 - val_loss: 0.0025 - val_mean_pixel_error_metric_160_320: 11.7407
# Epoch 21/100
# 186/186 ━━━━━━━━━━━━━━━━━━━━ 36s 191ms/step - loss: 0.0021 - mean_pixel_error_metric_160_320: 9.1113 - val_loss: 0.0020 - val_mean_pixel_error_metric_160_320: 9.6259
# Epoch 22/100
# 186/186 ━━━━━━━━━━━━━━━━━━━━ 36s 191ms/step - loss: 0.0017 - mean_pixel_error_metric_160_320: 8.6151 - val_loss: 0.0013 - val_mean_pixel_error_metric_160_320: 7.0515
# Epoch 23/100
# 186/186 ━━━━━━━━━━━━━━━━━━━━ 36s 192ms/step - loss: 0.0017 - mean_pixel_error_metric_160_320: 8.4587 - val_loss: 0.0018 - val_mean_pixel_error_metric_160_320: 8.9635
# Epoch 24/100
# 186/186 ━━━━━━━━━━━━━━━━━━━━ 35s 190ms/step - loss: 0.0018 - mean_pixel_error_metric_160_320: 8.8329 - val_loss: 0.0015 - val_mean_pixel_error_metric_160_320: 7.9253
# Epoch 25/100
# 186/186 ━━━━━━━━━━━━━━━━━━━━ 36s 192ms/step - loss: 0.0019 - mean_pixel_error_metric_160_320: 8.8291 - val_loss: 0.0013 - val_mean_pixel_error_metric_160_320: 6.7727
# Epoch 26/100
# 186/186 ━━━━━━━━━━━━━━━━━━━━ 36s 192ms/step - loss: 0.0019 - mean_pixel_error_metric_160_320: 8.8208 - val_loss: 0.0012 - val_mean_pixel_error_metric_160_320: 6.4502
# Epoch 27/100
# 186/186 ━━━━━━━━━━━━━━━━━━━━ 35s 191ms/step - loss: 0.0016 - mean_pixel_error_metric_160_320: 8.1641 - val_loss: 0.0013 - val_mean_pixel_error_metric_160_320: 7.6301
# Epoch 28/100
# 186/186 ━━━━━━━━━━━━━━━━━━━━ 36s 191ms/step - loss: 0.0019 - mean_pixel_error_metric_160_320: 8.9421 - val_loss: 0.0013 - val_mean_pixel_error_metric_160_320: 7.2729
# Epoch 29/100
# 186/186 ━━━━━━━━━━━━━━━━━━━━ 36s 191ms/step - loss: 0.0016 - mean_pixel_error_metric_160_320: 8.2529 - val_loss: 0.0011 - val_mean_pixel_error_metric_160_320: 6.0946
# Epoch 30/100
# 186/186 ━━━━━━━━━━━━━━━━━━━━ 36s 194ms/step - loss: 0.0016 - mean_pixel_error_metric_160_320: 8.3417 - val_loss: 0.0853 - val_mean_pixel_error_metric_160_320: 51.3714
# Epoch 31/100
# 186/186 ━━━━━━━━━━━━━━━━━━━━ 35s 190ms/step - loss: 0.0077 - mean_pixel_error_metric_160_320: 15.0323 - val_loss: 0.0074 - val_mean_pixel_error_metric_160_320: 15.7489
# Epoch 32/100
# 186/186 ━━━━━━━━━━━━━━━━━━━━ 35s 190ms/step - loss: 0.0062 - mean_pixel_error_metric_160_320: 13.5820 - val_loss: 0.0028 - val_mean_pixel_error_metric_160_320: 9.6050
# Epoch 33/100
# 186/186 ━━━━━━━━━━━━━━━━━━━━ 35s 190ms/step - loss: 0.0044 - mean_pixel_error_metric_160_320: 13.0124 - val_loss: 0.0362 - val_mean_pixel_error_metric_160_320: 30.8016
# Epoch 34/100
# 186/186 ━━━━━━━━━━━━━━━━━━━━ 36s 191ms/step - loss: 0.0044 - mean_pixel_error_metric_160_320: 13.9692 - val_loss: 0.0019 - val_mean_pixel_error_metric_160_320: 8.5808
# Epoch 35/100
# 186/186 ━━━━━━━━━━━━━━━━━━━━ 36s 192ms/step - loss: 0.0025 - mean_pixel_error_metric_160_320: 10.7620 - val_loss: 0.0027 - val_mean_pixel_error_metric_160_320: 10.9226
# Epoch 36/100
# 186/186 ━━━━━━━━━━━━━━━━━━━━ 35s 190ms/step - loss: 0.0023 - mean_pixel_error_metric_160_320: 10.0405 - val_loss: 0.0019 - val_mean_pixel_error_metric_160_320: 8.6274
# Epoch 37/100
# 186/186 ━━━━━━━━━━━━━━━━━━━━ 35s 190ms/step - loss: 0.0024 - mean_pixel_error_metric_160_320: 10.1449 - val_loss: 0.0024 - val_mean_pixel_error_metric_160_320: 10.5784
# Epoch 38/100
# 186/186 ━━━━━━━━━━━━━━━━━━━━ 36s 191ms/step - loss: 0.0023 - mean_pixel_error_metric_160_320: 9.8813 - val_loss: 0.0018 - val_mean_pixel_error_metric_160_320: 8.4629
# Epoch 39/100
# 186/186 ━━━━━━━━━━━━━━━━━━━━ 36s 191ms/step - loss: 0.0029 - mean_pixel_error_metric_160_320: 10.8298 - val_loss: 0.0046 - val_mean_pixel_error_metric_160_320: 14.6140
# Epoch 39: early stopping
# Restoring model weights from the end of the best epoch: 29.

# %% [markdown]
# plot loss for train and evaluation

# %%
fig, ax1 = plt.subplots(figsize=(8, 5))

# y1: loss
ax1.plot(history.history['loss'], label='Train Loss', linestyle='-', color='black')
ax1.plot(history.history['val_loss'], label='Val Loss', linestyle='-', color='gray')
ax1.set_xlabel('Epochs', color='black')
ax1.set_ylabel('Loss', color='black')
ax1.tick_params(axis='y', labelcolor='black')
ax1.tick_params(axis='x', labelcolor='black')

# y2: MPE
ax2 = ax1.twinx()
ax2.plot(history.history['mean_pixel_error_metric_160_320'], label='Train MPE', linestyle='--', color='black')
ax2.plot(history.history['val_mean_pixel_error_metric_160_320'], label='Val MPE', linestyle='--', color='gray')
ax2.set_ylabel('Mean Pixel Error [px]', color='black')
ax2.tick_params(axis='y', labelcolor='black')

lines_1, labels_1 = ax1.get_legend_handles_labels()
lines_2, labels_2 = ax2.get_legend_handles_labels()
ax1.legend(lines_1 + lines_2, labels_1 + labels_2, loc='upper right')

plt.title("Training Loss & Mean Pixel Error", color='black')
plt.show()

# %% [markdown]
# mini evaluation test set

# %%
#mpe +- std
pred_coords_norm = model.predict(X_test)
# Out:
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 17s 313ms/step

# %%
distances = np.linalg.norm(y_test - pred_coords_norm, axis=-1)

# %%
# image size
H, W = 160, 320

# convert to pixel size
diff_pixel = (y_test - pred_coords_norm) * np.array([H, W])
distances_pixel = np.linalg.norm(diff_pixel, axis=-1)

# prediction errors
mpe_mean = distances_pixel.mean()
mpe_std = distances_pixel.std()
mpe_median = np.median(distances_pixel)

print(f"Mean Prediction Error (MPE) in pixels: {mpe_mean:.2f} ± {mpe_std:.2f}")
print(f"Median Prediction Error in pixels: {mpe_median:.2f}")
# Out:
# Mean Prediction Error (MPE) in pixels: 5.44 ± 4.44
# Median Prediction Error in pixels: 4.47

# %% [markdown]
# save predictions in normalized pixel coords for evaluation

# %%
save_dir2 = '/content/drive/MyDrive/Arlette/Model_Outputs'
os.makedirs(save_dir2, exist_ok=True)
np.save(f"{save_dir2}/predictions_norm_CNN_no_blur_augmentation.npy", pred_coords_norm)

# %% [markdown]
# save model weights and output

# %%
#save best config based on validation loss

# %%
save_dir = '/content/drive/MyDrive/Arlette/model_weights'
os.makedirs(save_dir, exist_ok=True)

model.save(f'{save_dir}/CNN_no_blur_augmentation.keras')
model.save_weights(f'{save_dir}/CNN_no_blur_augmentation.weights.h5')
