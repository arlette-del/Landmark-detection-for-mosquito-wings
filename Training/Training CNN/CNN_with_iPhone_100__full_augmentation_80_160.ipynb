# %% [markdown]
# setup/ import

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import random
import os

import tensorflow as tf

import wandb
from wandb.integration.keras import WandbMetricsLogger, WandbCallback, WandbModelCheckpoint

from sklearn.model_selection import train_test_split

from tensorflow.keras.layers import Dense, Input
from tensorflow.keras.models import Model
from tensorflow.keras.callbacks import EarlyStopping
from tensorflow.keras import layers

# %%
print('Tensorflow version:', tf.__version__)
print('Weights and biases version:', wandb.__version__)
# Out:
# Tensorflow version: 2.19.0
# Weights and biases version: 0.21.1

# %% [markdown]
# load data

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
X_train = np.load('/content/drive/MyDrive/Arlette/Sets for Training /Dataset with iPhone/train_aug_images_80x160.npy')
X_val = np.load('/content/drive/MyDrive/Arlette/Sets for Training /Dataset with iPhone/val_images_80x160.npy')
X_test = np.load('/content/drive/MyDrive/Arlette/Sets for Training /Dataset with iPhone/test_images_80x160.npy')

y_train = np.load('/content/drive/MyDrive/Arlette/Sets for Training /Dataset with iPhone/train_aug_landmarks.npy')
y_val = np.load('/content/drive/MyDrive/Arlette/Sets for Training /Dataset with iPhone/val_landmarks.npy')
y_test = np.load('/content/drive/MyDrive/Arlette/Sets for Training /Dataset with iPhone/test_landmarks.npy')

# %% [markdown]
# define hyperparameters

# %%
def get_config(model_name='resnet50_withIphone_100_augmentation_80_160',
               img_size=(80, 160),
               batch_size=16,
               learning_rate_transfer=1e-3,
               learning_rate_tuning=5e-4,
               max_epochs_transfer=50,
               max_epochs_tuning=100,
               early_stop_patience=10,
               steps_per_epoch=81,
               dropout=0.5,
               seed=42):

    # cosine decay
    cosine_decay_steps = steps_per_epoch * max_epochs_tuning
    learning_schedule = {
        'initial_learning_rate': learning_rate_tuning,
        'decay_steps': cosine_decay_steps,
        'warmup_target': learning_rate_tuning,
        'warmup_steps': int(cosine_decay_steps * 0.02)
    }

    # config dictionary
    config = {
        'model_name': model_name,
        'img_size': img_size,
        'batch_size': batch_size,
        'learning_rate_transfer': learning_rate_transfer,
        'learning_rate_tuning': learning_rate_tuning,
        'max_epochs_transfer': max_epochs_transfer,
        'max_epochs_tuning': max_epochs_tuning,
        'early_stop_patience': early_stop_patience,
        'steps_per_epoch': steps_per_epoch,
        'cosine_decay_steps': cosine_decay_steps,
        'dropout': dropout,
        'learning_schedule': learning_schedule,
        'seed': seed
    }

    return config

# %%
config = get_config()
SEED = config['seed']
img_size = config['img_size']
batch_size = config['batch_size']
seed = config['seed']

# %% [markdown]
# create tensorflow dataset

# %%
train_dataset = tf.data.Dataset.from_tensor_slices((X_train, y_train))
train_dataset = train_dataset.shuffle(buffer_size=1000).batch(batch_size).prefetch(tf.data.AUTOTUNE)

val_dataset = tf.data.Dataset.from_tensor_slices((X_val, y_val)).batch(batch_size).prefetch(tf.data.AUTOTUNE)
test_dataset = tf.data.Dataset.from_tensor_slices((X_test, y_test)).batch(batch_size).prefetch(tf.data.AUTOTUNE)

# %% [markdown]
# define loss and metric

# %%
# loss in normalized units [0,1]
# computes mean squared error per landmark in normalized coordinates
# arg: y_true and y_pred in tensor shape (batch_size, num_landmarks, 2) [0,1]
# returns scalar tensor: average MSE over all landmarks in the batch
def landmark_mse(y_true, y_pred):
    y_true = tf.cast(y_true, tf.float32)
    y_pred = tf.cast(y_pred, tf.float32)
    return tf.reduce_mean(tf.reduce_sum(tf.square(y_true - y_pred), axis=-1))


# metric
# mean pixel error
# computes average euclidean distance per landmark in pixels
# arg: y_true and y_pred in tensor shape (batch_size, num_landmarks, 2) [0,1]
#      img_size: tuple [int, int], image height and with (H, W)
# returns scalar tensor: mean pixel error over batch
def mean_pixel_error_metric_80_160(y_true, y_pred):
    H, W = 80,160
    y_true = tf.cast(y_true, tf.float32)
    y_pred = tf.cast(y_pred, tf.float32)
    y_true_px = y_true * tf.constant([W, H], dtype=tf.float32)
    y_pred_px = y_pred * tf.constant([W, H], dtype=tf.float32)
    dist = tf.sqrt(tf.reduce_sum(tf.square(y_true_px - y_pred_px), axis=-1))
    return tf.reduce_mean(dist)

# %% [markdown]
# define model

# %%
from tensorflow.keras.applications import ResNet50

def build_resnet50_landmark_model(input_shape=(80, 160, 3),
                                  num_landmarks=18,
                                  trainable_backbone=False):
    backbone = ResNet50(
        include_top=False,
        weights='imagenet',
        input_shape=input_shape,
        pooling=None
    )
    backbone.trainable = trainable_backbone

    inputs = tf.keras.Input(shape=input_shape)
    x = backbone(inputs, training=False)
    x = tf.keras.layers.GlobalAveragePooling2D()(x)

    # head
    x = tf.keras.layers.Dense(256, activation='relu')(x)
    x = tf.keras.layers.Dropout(0.3)(x)
    x = tf.keras.layers.Dense(128, activation='relu')(x)
    x = tf.keras.layers.Dropout(0.3)(x)

    # output
    x = tf.keras.layers.Dense(num_landmarks * 2, activation='sigmoid')(x)
    outputs = tf.keras.layers.Reshape((num_landmarks, 2))(x)

    return tf.keras.Model(inputs, outputs, name='resnet50_landmark_model')

# %%
input_shape = (80, 160, 3)
num_landmarks = 18

model = build_resnet50_landmark_model(input_shape=input_shape, num_landmarks=num_landmarks)

model.compile(optimizer=tf.keras.optimizers.Adam(learning_rate=config['learning_rate_transfer']),
              loss=landmark_mse,
              metrics=[mean_pixel_error_metric_80_160])

model.summary()
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/keras-applications/resnet/resnet50_weights_tf_dim_ordering_tf_kernels_notop.h5
# 94765736/94765736 ━━━━━━━━━━━━━━━━━━━━ 0s 0us/step
# Model: "resnet50_landmark_model"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ input_layer_1 (InputLayer)      │ (None, 80, 160, 3)     │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ resnet50 (Functional)           │ (None, 3, 5, 2048)     │    23,587,712 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ global_average_pooling2d        │ (None, 2048)           │             0 │
# │ (GlobalAveragePooling2D)        │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense (Dense)                   │ (None, 256)            │       524,544 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout (Dropout)               │ (None, 256)            │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_1 (Dense)                 │ (None, 128)            │        32,896 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_1 (Dropout)             │ (None, 128)            │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_2 (Dense)                 │ (None, 36)             │         4,644 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ reshape (Reshape)               │ (None, 18, 2)          │             0 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 24,149,796 (92.12 MB)
#  Trainable params: 562,084 (2.14 MB)
#  Non-trainable params: 23,587,712 (89.98 MB)

# %% [markdown]
# callbacks // weights and biases

# %%
wandb.init(project='mosquito_landmarks',name=f"{config['model_name']}",config=config)

callbacks = [EarlyStopping(monitor='val_loss',
            patience=config['early_stop_patience'],
            restore_best_weights=True,
            verbose=1),
            WandbMetricsLogger(),
            WandbModelCheckpoint("wandb_model.keras")]
# Out:
# /usr/local/lib/python3.12/dist-packages/notebook/notebookapp.py:191: SyntaxWarning: invalid escape sequence '\/'
#   | |_| | '_ \/ _` / _` |  _/ -_)
# wandb: Logging into wandb.ai. (Learn how to deploy a W&B server locally: https://wandb.me/wandb-server)
# wandb: You can find your API key in your browser here: https://wandb.ai/authorize?ref=models
# wandb: Paste an API key from your profile and hit enter:
#  ··········
# wandb: WARNING If you're specifying your api key in code, ensure this code is not shared publicly.
# wandb: WARNING Consider setting the WANDB_API_KEY environment variable, or running `wandb login` from the command line.
# wandb: No netrc file found, creating one.
# wandb: Appending key for api.wandb.ai to your netrc file: /root/.netrc
# wandb: Currently logged in as: arlettedel (arlettedel-universit-t-hamburg) to https://api.wandb.ai. Use `wandb login --relogin` to force relogin
# Tracking run with wandb version 0.21.1
# Run data is saved locally in <code>/content/wandb/run-20250830_074300-et1eidxo</code>
# Syncing run <strong><a href='https://wandb.ai/arlettedel-universit-t-hamburg/mosquito_landmarks/runs/et1eidxo' target="_blank">resnet50_withIphone_100_augmentation_80_160</a></strong> to <a href='https://wandb.ai/arlettedel-universit-t-hamburg/mosquito_landmarks' target="_blank">Weights & Biases</a> (<a href='https://wandb.me/developer-guide' target="_blank">docs</a>)<br>
#  View project at <a href='https://wandb.ai/arlettedel-universit-t-hamburg/mosquito_landmarks' target="_blank">https://wandb.ai/arlettedel-universit-t-hamburg/mosquito_landmarks</a>
#  View run at <a href='https://wandb.ai/arlettedel-universit-t-hamburg/mosquito_landmarks/runs/et1eidxo' target="_blank">https://wandb.ai/arlettedel-universit-t-hamburg/mosquito_landmarks/runs/et1eidxo</a>

# %% [markdown]
# train model

# %%
history = model.fit(train_dataset, validation_data=val_dataset,
                    epochs=config['max_epochs_transfer'],
                    callbacks=callbacks,
                    verbose=1)
# Out:
# Epoch 1/50
# 186/186 ━━━━━━━━━━━━━━━━━━━━ 29s 88ms/step - loss: 0.0920 - mean_pixel_error_metric_80_160: 39.8645 - val_loss: 0.0843 - val_mean_pixel_error_metric_80_160: 38.9723
# Epoch 2/50
# 186/186 ━━━━━━━━━━━━━━━━━━━━ 5s 29ms/step - loss: 0.0853 - mean_pixel_error_metric_80_160: 39.0288 - val_loss: 0.0831 - val_mean_pixel_error_metric_80_160: 38.5721
# Epoch 3/50
# 186/186 ━━━━━━━━━━━━━━━━━━━━ 5s 27ms/step - loss: 0.0850 - mean_pixel_error_metric_80_160: 39.0240 - val_loss: 0.0836 - val_mean_pixel_error_metric_80_160: 38.7950
# Epoch 4/50
# 186/186 ━━━━━━━━━━━━━━━━━━━━ 5s 27ms/step - loss: 0.0841 - mean_pixel_error_metric_80_160: 38.7880 - val_loss: 0.0838 - val_mean_pixel_error_metric_80_160: 38.8467
# Epoch 5/50
# 186/186 ━━━━━━━━━━━━━━━━━━━━ 5s 27ms/step - loss: 0.0840 - mean_pixel_error_metric_80_160: 38.7648 - val_loss: 0.0837 - val_mean_pixel_error_metric_80_160: 38.8292
# Epoch 6/50
# 186/186 ━━━━━━━━━━━━━━━━━━━━ 5s 29ms/step - loss: 0.0833 - mean_pixel_error_metric_80_160: 38.4975 - val_loss: 0.0843 - val_mean_pixel_error_metric_80_160: 38.9577
# Epoch 7/50
# 186/186 ━━━━━━━━━━━━━━━━━━━━ 5s 27ms/step - loss: 0.0834 - mean_pixel_error_metric_80_160: 38.5355 - val_loss: 0.0838 - val_mean_pixel_error_metric_80_160: 38.8583
# Epoch 8/50
# 186/186 ━━━━━━━━━━━━━━━━━━━━ 5s 27ms/step - loss: 0.0831 - mean_pixel_error_metric_80_160: 38.4599 - val_loss: 0.0842 - val_mean_pixel_error_metric_80_160: 38.9619
# Epoch 9/50
# 186/186 ━━━━━━━━━━━━━━━━━━━━ 5s 27ms/step - loss: 0.0827 - mean_pixel_error_metric_80_160: 38.2513 - val_loss: 0.0836 - val_mean_pixel_error_metric_80_160: 38.7882
# Epoch 10/50
# 186/186 ━━━━━━━━━━━━━━━━━━━━ 5s 27ms/step - loss: 0.0827 - mean_pixel_error_metric_80_160: 38.3399 - val_loss: 0.0835 - val_mean_pixel_error_metric_80_160: 38.7533
# Epoch 11/50
# 186/186 ━━━━━━━━━━━━━━━━━━━━ 5s 27ms/step - loss: 0.0826 - mean_pixel_error_metric_80_160: 38.2661 - val_loss: 0.0919 - val_mean_pixel_error_metric_80_160: 40.2873
# Epoch 12/50
# 186/186 ━━━━━━━━━━━━━━━━━━━━ 5s 27ms/step - loss: 0.0834 - mean_pixel_error_metric_80_160: 38.1571 - val_loss: 0.0833 - val_mean_pixel_error_metric_80_160: 38.6795
# Epoch 12: early stopping
# Restoring model weights from the end of the best epoch: 2.

# %% [markdown]
# fine tuning

# %%
# unfreeze layer for fine tuning
for layer in model.layers:
    layer.trainable = True

# new optimizer for fine tuning
optimizer = tf.keras.optimizers.Adam(
    learning_rate=config['learning_rate_tuning'])

model.compile(optimizer=optimizer, loss=landmark_mse)

# callback fine tuning
callbacks_ft = [
    EarlyStopping(
        monitor='val_loss',
        patience=config['early_stop_patience'],
        restore_best_weights=True,
        verbose=1),
    WandbMetricsLogger(),
    WandbModelCheckpoint("wandb_model_finetuned.keras")]

# wandb
wandb.init(
    project='mosquito_landmarks',
    name=f"{config['model_name']}_finetune",
    config=config,
    reinit=True)  # important for new run

# fine tuning
history_ft = model.fit(
    train_dataset,
    validation_data=val_dataset,
    epochs=config['max_epochs_tuning'],
    callbacks=callbacks_ft,
    verbose=1)
# Out:
# Finishing previous runs because reinit is set to True.
# <br>    <style><br>        .wandb-row {<br>            display: flex;<br>            flex-direction: row;<br>            flex-wrap: wrap;<br>            justify-content: flex-start;<br>            width: 100%;<br>        }<br>        .wandb-col {<br>            display: flex;<br>            flex-direction: column;<br>            flex-basis: 100%;<br>            flex: 1;<br>            padding: 10px;<br>        }<br>    </style><br><div class="wandb-row"><div class="wandb-col"><h3>Run history:</h3><br/><table class="wandb"><tr><td>epoch/epoch</td><td>▁▂▂▃▄▄▅▅▆▇▇█</td></tr><tr><td>epoch/learning_rate</td><td>▁▁▁▁▁▁▁▁▁▁▁▁</td></tr><tr><td>epoch/loss</td><td>█▅▄▃▃▃▂▂▂▁▁▂</td></tr><tr><td>epoch/mean_pixel_error_metric_80_160</td><td>█▆▅▅▄▃▃▂▂▂▁▁</td></tr><tr><td>epoch/val_loss</td><td>▂▁▁▂▁▂▂▂▁▁█▁</td></tr><tr><td>epoch/val_mean_pixel_error_metric_80_160</td><td>▃▁▂▂▂▃▂▃▂▂█▁</td></tr></table><br/></div><div class="wandb-col"><h3>Run summary:</h3><br/><table class="wandb"><tr><td>epoch/epoch</td><td>11</td></tr><tr><td>epoch/learning_rate</td><td>0.001</td></tr><tr><td>epoch/loss</td><td>0.08287</td></tr><tr><td>epoch/mean_pixel_error_metric_80_160</td><td>38.11684</td></tr><tr><td>epoch/val_loss</td><td>0.0833</td></tr><tr><td>epoch/val_mean_pixel_error_metric_80_160</td><td>38.67949</td></tr></table><br/></div></div>
#  View run <strong style="color:#cdcd00">resnet50_withIphone_100_augmentation_80_160</strong> at: <a href='https://wandb.ai/arlettedel-universit-t-hamburg/mosquito_landmarks/runs/et1eidxo' target="_blank">https://wandb.ai/arlettedel-universit-t-hamburg/mosquito_landmarks/runs/et1eidxo</a><br> View project at: <a href='https://wandb.ai/arlettedel-universit-t-hamburg/mosquito_landmarks' target="_blank">https://wandb.ai/arlettedel-universit-t-hamburg/mosquito_landmarks</a><br>Synced 5 W&B file(s), 0 media file(s), 24 artifact file(s) and 0 other file(s)
# Find logs at: <code>./wandb/run-20250830_074300-et1eidxo/logs</code>
# wandb: WARNING Using a boolean value for 'reinit' is deprecated. Use 'return_previous' or 'finish_previous' instead.
# Tracking run with wandb version 0.21.1
# Run data is saved locally in <code>/content/wandb/run-20250830_074506-hnp5120t</code>
# Syncing run <strong><a href='https://wandb.ai/arlettedel-universit-t-hamburg/mosquito_landmarks/runs/hnp5120t' target="_blank">resnet50_withIphone_100_augmentation_80_160_finetune</a></strong> to <a href='https://wandb.ai/arlettedel-universit-t-hamburg/mosquito_landmarks' target="_blank">Weights & Biases</a> (<a href='https://wandb.me/developer-guide' target="_blank">docs</a>)<br>
#  View project at <a href='https://wandb.ai/arlettedel-universit-t-hamburg/mosquito_landmarks' target="_blank">https://wandb.ai/arlettedel-universit-t-hamburg/mosquito_landmarks</a>
#  View run at <a href='https://wandb.ai/arlettedel-universit-t-hamburg/mosquito_landmarks/runs/hnp5120t' target="_blank">https://wandb.ai/arlettedel-universit-t-hamburg/mosquito_landmarks/runs/hnp5120t</a>
# Epoch 1/100
# 186/186 ━━━━━━━━━━━━━━━━━━━━ 91s 216ms/step - loss: 0.0912 - mean_pixel_error_metric_80_160: 39.8206 - val_loss: 0.0838 - val_mean_pixel_error_metric_80_160: 38.8500
# Epoch 2/100
# 186/186 ━━━━━━━━━━━━━━━━━━━━ 15s 80ms/step - loss: 0.0849 - mean_pixel_error_metric_80_160: 38.9444 - val_loss: 0.0839 - val_mean_pixel_error_metric_80_160: 38.8917
# Epoch 3/100
# 186/186 ━━━━━━━━━━━━━━━━━━━━ 15s 82ms/step - loss: 0.0846 - mean_pixel_error_metric_80_160: 38.9850 - val_loss: 0.0837 - val_mean_pixel_error_metric_80_160: 38.8216
# Epoch 4/100
# 186/186 ━━━━━━━━━━━━━━━━━━━━ 15s 82ms/step - loss: 0.0844 - mean_pixel_error_metric_80_160: 38.9356 - val_loss: 0.0837 - val_mean_pixel_error_metric_80_160: 38.8282
# Epoch 5/100
# 186/186 ━━━━━━━━━━━━━━━━━━━━ 15s 81ms/step - loss: 0.0847 - mean_pixel_error_metric_80_160: 39.0648 - val_loss: 0.0836 - val_mean_pixel_error_metric_80_160: 38.8177
# Epoch 6/100
# 186/186 ━━━━━━━━━━━━━━━━━━━━ 15s 81ms/step - loss: 0.0846 - mean_pixel_error_metric_80_160: 39.0042 - val_loss: 0.0836 - val_mean_pixel_error_metric_80_160: 38.7960
# Epoch 7/100
# 186/186 ━━━━━━━━━━━━━━━━━━━━ 15s 80ms/step - loss: 0.0845 - mean_pixel_error_metric_80_160: 38.9806 - val_loss: 0.0836 - val_mean_pixel_error_metric_80_160: 38.8071
# Epoch 8/100
# 186/186 ━━━━━━━━━━━━━━━━━━━━ 15s 81ms/step - loss: 0.0847 - mean_pixel_error_metric_80_160: 38.9792 - val_loss: 0.0837 - val_mean_pixel_error_metric_80_160: 38.8324
# Epoch 9/100
# 186/186 ━━━━━━━━━━━━━━━━━━━━ 15s 81ms/step - loss: 0.0841 - mean_pixel_error_metric_80_160: 38.8143 - val_loss: 0.0833 - val_mean_pixel_error_metric_80_160: 38.7201
# Epoch 10/100
# 186/186 ━━━━━━━━━━━━━━━━━━━━ 15s 80ms/step - loss: 0.0845 - mean_pixel_error_metric_80_160: 38.9528 - val_loss: 0.0834 - val_mean_pixel_error_metric_80_160: 38.7436
# Epoch 11/100
# 186/186 ━━━━━━━━━━━━━━━━━━━━ 15s 80ms/step - loss: 0.0845 - mean_pixel_error_metric_80_160: 38.8962 - val_loss: 0.0834 - val_mean_pixel_error_metric_80_160: 38.7272
# Epoch 12/100
# 186/186 ━━━━━━━━━━━━━━━━━━━━ 15s 80ms/step - loss: 0.0843 - mean_pixel_error_metric_80_160: 38.8233 - val_loss: 0.0837 - val_mean_pixel_error_metric_80_160: 38.8316
# Epoch 13/100
# 186/186 ━━━━━━━━━━━━━━━━━━━━ 15s 81ms/step - loss: 0.0845 - mean_pixel_error_metric_80_160: 38.9942 - val_loss: 0.0841 - val_mean_pixel_error_metric_80_160: 38.9450
# Epoch 14/100
# 186/186 ━━━━━━━━━━━━━━━━━━━━ 15s 80ms/step - loss: 0.0848 - mean_pixel_error_metric_80_160: 38.9793 - val_loss: 0.0834 - val_mean_pixel_error_metric_80_160: 38.7527
# Epoch 15/100
# 186/186 ━━━━━━━━━━━━━━━━━━━━ 15s 81ms/step - loss: 0.0846 - mean_pixel_error_metric_80_160: 38.9710 - val_loss: 0.0830 - val_mean_pixel_error_metric_80_160: 38.6469
# Epoch 16/100
# 186/186 ━━━━━━━━━━━━━━━━━━━━ 15s 80ms/step - loss: 0.0846 - mean_pixel_error_metric_80_160: 38.9877 - val_loss: 0.0835 - val_mean_pixel_error_metric_80_160: 38.7629
# Epoch 17/100
# 186/186 ━━━━━━━━━━━━━━━━━━━━ 15s 81ms/step - loss: 0.0845 - mean_pixel_error_metric_80_160: 38.9712 - val_loss: 0.0834 - val_mean_pixel_error_metric_80_160: 38.7566
# Epoch 18/100
# 186/186 ━━━━━━━━━━━━━━━━━━━━ 15s 80ms/step - loss: 0.0846 - mean_pixel_error_metric_80_160: 38.9625 - val_loss: 0.0836 - val_mean_pixel_error_metric_80_160: 38.7990
# Epoch 19/100
# 186/186 ━━━━━━━━━━━━━━━━━━━━ 15s 80ms/step - loss: 0.0843 - mean_pixel_error_metric_80_160: 38.9137 - val_loss: 0.0834 - val_mean_pixel_error_metric_80_160: 38.7483
# Epoch 20/100
# 186/186 ━━━━━━━━━━━━━━━━━━━━ 15s 80ms/step - loss: 0.0844 - mean_pixel_error_metric_80_160: 38.9091 - val_loss: 0.0838 - val_mean_pixel_error_metric_80_160: 38.8486
# Epoch 21/100
# 186/186 ━━━━━━━━━━━━━━━━━━━━ 15s 80ms/step - loss: 0.0839 - mean_pixel_error_metric_80_160: 38.7965 - val_loss: 0.0834 - val_mean_pixel_error_metric_80_160: 38.7505
# Epoch 22/100
# 186/186 ━━━━━━━━━━━━━━━━━━━━ 15s 81ms/step - loss: 0.0841 - mean_pixel_error_metric_80_160: 38.8229 - val_loss: 0.0831 - val_mean_pixel_error_metric_80_160: 38.6736
# Epoch 23/100
# 186/186 ━━━━━━━━━━━━━━━━━━━━ 15s 81ms/step - loss: 0.0840 - mean_pixel_error_metric_80_160: 38.6947 - val_loss: 0.0833 - val_mean_pixel_error_metric_80_160: 38.7101
# Epoch 24/100
# 186/186 ━━━━━━━━━━━━━━━━━━━━ 15s 82ms/step - loss: 0.0837 - mean_pixel_error_metric_80_160: 38.6611 - val_loss: 0.0833 - val_mean_pixel_error_metric_80_160: 38.7203
# Epoch 25/100
# 186/186 ━━━━━━━━━━━━━━━━━━━━ 15s 80ms/step - loss: 0.0836 - mean_pixel_error_metric_80_160: 38.6227 - val_loss: 0.0836 - val_mean_pixel_error_metric_80_160: 38.7835
# Epoch 25: early stopping
# Restoring model weights from the end of the best epoch: 15.

# %% [markdown]
# plot loss for train and evaluation

# %%
fig, ax1 = plt.subplots(figsize=(8, 5))

# y1: loss
ax1.plot(history.history['loss'], label='Train Loss', linestyle='-', color='black')
ax1.plot(history.history['val_loss'], label='Val Loss', linestyle='-', color='gray')
ax1.set_xlabel('Epochs', color='black')
ax1.set_ylabel('Loss', color='black')
ax1.tick_params(axis='y', labelcolor='black')
ax1.tick_params(axis='x', labelcolor='black')

# y2: MPE
ax2 = ax1.twinx()
ax2.plot(history.history['mean_pixel_error_metric_80_160'], label='Train MPE', linestyle='--', color='black')
ax2.plot(history.history['val_mean_pixel_error_metric_80_160'], label='Val MPE', linestyle='--', color='gray')
ax2.set_ylabel('Mean Pixel Error [px]', color='black')
ax2.tick_params(axis='y', labelcolor='black')

lines_1, labels_1 = ax1.get_legend_handles_labels()
lines_2, labels_2 = ax2.get_legend_handles_labels()
ax1.legend(lines_1 + lines_2, labels_1 + labels_2, loc='upper right')

plt.title("Training Loss & Mean Pixel Error", color='black')
plt.show()

# %% [markdown]
# mini evaluation test set

# %%
#mpe +- std
pred_coords_norm = model.predict(X_test)
# Out:
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 10s 183ms/step

# %%
distances = np.linalg.norm(y_test - pred_coords_norm, axis=-1)

# %%
# image size
H, W = 80, 160

# convert to pixel size
diff_pixel = (y_test - pred_coords_norm) * np.array([H, W])
distances_pixel = np.linalg.norm(diff_pixel, axis=-1)

# prediction errors
mpe_mean = distances_pixel.mean()
mpe_std = distances_pixel.std()
mpe_median = np.median(distances_pixel)

print(f"Mean Prediction Error (MPE) in pixels: {mpe_mean:.2f} ± {mpe_std:.2f}")
print(f"Median Prediction Error in pixels: {mpe_median:.2f}")
# Out:
# Mean Prediction Error (MPE) in pixels: 19.79 ± 12.27
# Median Prediction Error in pixels: 15.76

# %% [markdown]
# save predictions in normalized pixel coords for evaluation

# %%
save_dir2 = '/content/drive/MyDrive/Arlette/Model_Outputs'
os.makedirs(save_dir2, exist_ok=True)
np.save(f"{save_dir2}/predictions_norm_CNN_full_augmentation_80_160.npy", pred_coords_norm)

# %% [markdown]
# save model weights and output

# %%
#save best config based on validation loss

# %%
save_dir = '/content/drive/MyDrive/Arlette/model_weights'
os.makedirs(save_dir, exist_ok=True)

model.save(f'{save_dir}/CNN_full_augmentation_80_160.keras')
model.save_weights(f'{save_dir}/CNN_full_augmentation_80_160.weights.h5')
