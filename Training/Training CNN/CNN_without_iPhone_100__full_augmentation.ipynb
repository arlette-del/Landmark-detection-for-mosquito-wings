# %% [markdown]
# setup/ import

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import random
import os

import tensorflow as tf

import wandb
from wandb.integration.keras import WandbMetricsLogger, WandbCallback, WandbModelCheckpoint

from sklearn.model_selection import train_test_split

from tensorflow.keras.layers import Dense, Input
from tensorflow.keras.models import Model
from tensorflow.keras.callbacks import EarlyStopping
from tensorflow.keras import layers

# %%
print('Tensorflow version:', tf.__version__)
print('Weights and biases version:', wandb.__version__)
# Out:
# Tensorflow version: 2.19.0
# Weights and biases version: 0.21.1

# %% [markdown]
# load data

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
X_train = np.load('/content/drive/MyDrive/Arlette/Sets for Training /Dataset without iPhone/train_aug_images_160x320_no_iphone.npy')
X_val = np.load('/content/drive/MyDrive/Arlette/Sets for Training /Dataset without iPhone/val_images_160x320_no_iphone.npy')
X_test = np.load('/content/drive/MyDrive/Arlette/Sets for Training /Dataset without iPhone/test_images_160x320_no_iphone.npy')

y_train = np.load('/content/drive/MyDrive/Arlette/Sets for Training /Dataset without iPhone/train_aug_landmarks_no_iphone.npy')
y_val = np.load('/content/drive/MyDrive/Arlette/Sets for Training /Dataset without iPhone/val_landmarks_no_iphone.npy')
y_test = np.load('/content/drive/MyDrive/Arlette/Sets for Training /Dataset without iPhone/test_landmarks_no_iphone.npy')

# %% [markdown]
# define hyperparameters

# %%
def get_config(model_name='CNN_without_Iphone_100_full_augmentation',
               img_size=(160, 320),
               batch_size=16,
               learning_rate_transfer=1e-3,
               learning_rate_tuning=5e-4,
               max_epochs_transfer=50,
               max_epochs_tuning=100,
               early_stop_patience=10,
               steps_per_epoch=81,
               dropout=0.5,
               seed=42):

    # cosine decay
    cosine_decay_steps = steps_per_epoch * max_epochs_tuning
    learning_schedule = {
        'initial_learning_rate': learning_rate_tuning,
        'decay_steps': cosine_decay_steps,
        'warmup_target': learning_rate_tuning,
        'warmup_steps': int(cosine_decay_steps * 0.02)
    }

    # config dictionary
    config = {
        'model_name': model_name,
        'img_size': img_size,
        'batch_size': batch_size,
        'learning_rate_transfer': learning_rate_transfer,
        'learning_rate_tuning': learning_rate_tuning,
        'max_epochs_transfer': max_epochs_transfer,
        'max_epochs_tuning': max_epochs_tuning,
        'early_stop_patience': early_stop_patience,
        'steps_per_epoch': steps_per_epoch,
        'cosine_decay_steps': cosine_decay_steps,
        'dropout': dropout,
        'learning_schedule': learning_schedule,
        'seed': seed
    }

    return config

# %%
config = get_config()
SEED = config['seed']
img_size = config['img_size']
batch_size = config['batch_size']
seed = config['seed']

# %% [markdown]
# create tensorflow dataset

# %%
train_dataset = tf.data.Dataset.from_tensor_slices((X_train, y_train))
train_dataset = train_dataset.shuffle(buffer_size=1000).batch(batch_size).prefetch(tf.data.AUTOTUNE)

val_dataset = tf.data.Dataset.from_tensor_slices((X_val, y_val)).batch(batch_size).prefetch(tf.data.AUTOTUNE)
test_dataset = tf.data.Dataset.from_tensor_slices((X_test, y_test)).batch(batch_size).prefetch(tf.data.AUTOTUNE)

# %% [markdown]
# define loss and metric

# %%
# loss in normalized units [0,1]
# computes mean squared error per landmark in normalized coordinates
# arg: y_true and y_pred in tensor shape (batch_size, num_landmarks, 2) [0,1]
# returns scalar tensor: average MSE over all landmarks in the batch
def landmark_mse(y_true, y_pred):
    y_true = tf.cast(y_true, tf.float32)
    y_pred = tf.cast(y_pred, tf.float32)
    return tf.reduce_mean(tf.reduce_sum(tf.square(y_true - y_pred), axis=-1))


# metric
# mean pixel error
# computes average euclidean distance per landmark in pixels
# arg: y_true and y_pred in tensor shape (batch_size, num_landmarks, 2) [0,1]
#      img_size: tuple [int, int], image height and with (H, W)
# returns scalar tensor: mean pixel error over batch
def mean_pixel_error_metric_160_320(y_true, y_pred):
    H, W = 160,320
    y_true = tf.cast(y_true, tf.float32)
    y_pred = tf.cast(y_pred, tf.float32)
    y_true_px = y_true * tf.constant([W, H], dtype=tf.float32)
    y_pred_px = y_pred * tf.constant([W, H], dtype=tf.float32)
    dist = tf.sqrt(tf.reduce_sum(tf.square(y_true_px - y_pred_px), axis=-1))
    return tf.reduce_mean(dist)

# %% [markdown]
# define model

# %%
from tensorflow.keras.applications import ResNet50

def build_resnet50_landmark_model(input_shape=(160, 320, 3),
                                  num_landmarks=18,
                                  trainable_backbone=False):
    backbone = ResNet50(
        include_top=False,
        weights='imagenet',
        input_shape=input_shape,
        pooling=None
    )
    backbone.trainable = trainable_backbone

    inputs = tf.keras.Input(shape=input_shape)
    x = backbone(inputs, training=False)
    x = tf.keras.layers.GlobalAveragePooling2D()(x)

    # head
    x = tf.keras.layers.Dense(256, activation='relu')(x)
    x = tf.keras.layers.Dropout(0.3)(x)
    x = tf.keras.layers.Dense(128, activation='relu')(x)
    x = tf.keras.layers.Dropout(0.3)(x)

    # output
    x = tf.keras.layers.Dense(num_landmarks * 2, activation='sigmoid')(x)
    outputs = tf.keras.layers.Reshape((num_landmarks, 2))(x)

    return tf.keras.Model(inputs, outputs, name='resnet50_landmark_model')

# %%
input_shape = (160, 320, 3)
num_landmarks = 18

model = build_resnet50_landmark_model(input_shape=input_shape, num_landmarks=num_landmarks)

model.compile(optimizer=tf.keras.optimizers.Adam(learning_rate=config['learning_rate_transfer']),
              loss=landmark_mse,
              metrics=[mean_pixel_error_metric_160_320])

model.summary()
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/keras-applications/resnet/resnet50_weights_tf_dim_ordering_tf_kernels_notop.h5
# 94765736/94765736 ━━━━━━━━━━━━━━━━━━━━ 5s 0us/step
# Model: "resnet50_landmark_model"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ input_layer_1 (InputLayer)      │ (None, 160, 320, 3)    │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ resnet50 (Functional)           │ (None, 5, 10, 2048)    │    23,587,712 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ global_average_pooling2d        │ (None, 2048)           │             0 │
# │ (GlobalAveragePooling2D)        │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense (Dense)                   │ (None, 256)            │       524,544 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout (Dropout)               │ (None, 256)            │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_1 (Dense)                 │ (None, 128)            │        32,896 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_1 (Dropout)             │ (None, 128)            │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_2 (Dense)                 │ (None, 36)             │         4,644 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ reshape (Reshape)               │ (None, 18, 2)          │             0 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 24,149,796 (92.12 MB)
#  Trainable params: 562,084 (2.14 MB)
#  Non-trainable params: 23,587,712 (89.98 MB)

# %% [markdown]
# callbacks // weights and biases

# %%
wandb.init(project='mosquito_landmarks',name=f"{config['model_name']}",config=config)

callbacks = [EarlyStopping(monitor='val_loss',
            patience=config['early_stop_patience'],
            restore_best_weights=True,
            verbose=1),
            WandbMetricsLogger(),
            WandbModelCheckpoint("wandb_model.keras")]
# Out:
# /usr/local/lib/python3.12/dist-packages/notebook/notebookapp.py:191: SyntaxWarning: invalid escape sequence '\/'
#   | |_| | '_ \/ _` / _` |  _/ -_)
# wandb: Logging into wandb.ai. (Learn how to deploy a W&B server locally: https://wandb.me/wandb-server)
# wandb: You can find your API key in your browser here: https://wandb.ai/authorize?ref=models
# wandb: Paste an API key from your profile and hit enter:
#  ··········
# wandb: WARNING If you're specifying your api key in code, ensure this code is not shared publicly.
# wandb: WARNING Consider setting the WANDB_API_KEY environment variable, or running `wandb login` from the command line.
# wandb: No netrc file found, creating one.
# wandb: Appending key for api.wandb.ai to your netrc file: /root/.netrc
# wandb: Currently logged in as: arlettedel (arlettedel-universit-t-hamburg) to https://api.wandb.ai. Use `wandb login --relogin` to force relogin
# Tracking run with wandb version 0.21.1
# Run data is saved locally in <code>/content/wandb/run-20250829_154712-6gf4necj</code>
# Syncing run <strong><a href='https://wandb.ai/arlettedel-universit-t-hamburg/mosquito_landmarks/runs/6gf4necj' target="_blank">CNN_without_Iphone_100_full_augmentation</a></strong> to <a href='https://wandb.ai/arlettedel-universit-t-hamburg/mosquito_landmarks' target="_blank">Weights & Biases</a> (<a href='https://wandb.me/developer-guide' target="_blank">docs</a>)<br>
#  View project at <a href='https://wandb.ai/arlettedel-universit-t-hamburg/mosquito_landmarks' target="_blank">https://wandb.ai/arlettedel-universit-t-hamburg/mosquito_landmarks</a>
#  View run at <a href='https://wandb.ai/arlettedel-universit-t-hamburg/mosquito_landmarks/runs/6gf4necj' target="_blank">https://wandb.ai/arlettedel-universit-t-hamburg/mosquito_landmarks/runs/6gf4necj</a>

# %% [markdown]
# train model

# %%
history = model.fit(train_dataset, validation_data=val_dataset,
                    epochs=config['max_epochs_transfer'],
                    callbacks=callbacks,
                    verbose=1)
# Out:
# Epoch 1/50
# 162/162 ━━━━━━━━━━━━━━━━━━━━ 33s 113ms/step - loss: 0.0973 - mean_pixel_error_metric_160_320: 80.9561 - val_loss: 0.0786 - val_mean_pixel_error_metric_160_320: 74.6670
# Epoch 2/50
# 162/162 ━━━━━━━━━━━━━━━━━━━━ 11s 70ms/step - loss: 0.0773 - mean_pixel_error_metric_160_320: 72.7537 - val_loss: 0.0405 - val_mean_pixel_error_metric_160_320: 48.9871
# Epoch 3/50
# 162/162 ━━━━━━━━━━━━━━━━━━━━ 11s 70ms/step - loss: 0.0541 - mean_pixel_error_metric_160_320: 55.1076 - val_loss: 0.0241 - val_mean_pixel_error_metric_160_320: 34.3314
# Epoch 4/50
# 162/162 ━━━━━━━━━━━━━━━━━━━━ 11s 70ms/step - loss: 0.0308 - mean_pixel_error_metric_160_320: 38.3270 - val_loss: 0.0127 - val_mean_pixel_error_metric_160_320: 21.9224
# Epoch 5/50
# 162/162 ━━━━━━━━━━━━━━━━━━━━ 12s 72ms/step - loss: 0.0232 - mean_pixel_error_metric_160_320: 31.4125 - val_loss: 0.0097 - val_mean_pixel_error_metric_160_320: 17.7818
# Epoch 6/50
# 162/162 ━━━━━━━━━━━━━━━━━━━━ 11s 71ms/step - loss: 0.0211 - mean_pixel_error_metric_160_320: 28.1146 - val_loss: 0.0077 - val_mean_pixel_error_metric_160_320: 15.3030
# Epoch 7/50
# 162/162 ━━━━━━━━━━━━━━━━━━━━ 11s 71ms/step - loss: 0.0165 - mean_pixel_error_metric_160_320: 24.4938 - val_loss: 0.0083 - val_mean_pixel_error_metric_160_320: 17.2731
# Epoch 8/50
# 162/162 ━━━━━━━━━━━━━━━━━━━━ 12s 72ms/step - loss: 0.0166 - mean_pixel_error_metric_160_320: 24.1357 - val_loss: 0.0066 - val_mean_pixel_error_metric_160_320: 13.2556
# Epoch 9/50
# 162/162 ━━━━━━━━━━━━━━━━━━━━ 12s 71ms/step - loss: 0.0167 - mean_pixel_error_metric_160_320: 24.0834 - val_loss: 0.0072 - val_mean_pixel_error_metric_160_320: 15.1879
# Epoch 10/50
# 162/162 ━━━━━━━━━━━━━━━━━━━━ 12s 72ms/step - loss: 0.0196 - mean_pixel_error_metric_160_320: 25.5328 - val_loss: 0.0063 - val_mean_pixel_error_metric_160_320: 13.5002
# Epoch 11/50
# 162/162 ━━━━━━━━━━━━━━━━━━━━ 12s 71ms/step - loss: 0.0180 - mean_pixel_error_metric_160_320: 23.8264 - val_loss: 0.0062 - val_mean_pixel_error_metric_160_320: 12.9070
# Epoch 12/50
# 162/162 ━━━━━━━━━━━━━━━━━━━━ 12s 72ms/step - loss: 0.0185 - mean_pixel_error_metric_160_320: 25.4612 - val_loss: 0.0059 - val_mean_pixel_error_metric_160_320: 12.2192
# Epoch 13/50
# 162/162 ━━━━━━━━━━━━━━━━━━━━ 11s 71ms/step - loss: 0.0198 - mean_pixel_error_metric_160_320: 25.4848 - val_loss: 0.0070 - val_mean_pixel_error_metric_160_320: 14.7853
# Epoch 14/50
# 162/162 ━━━━━━━━━━━━━━━━━━━━ 11s 70ms/step - loss: 0.0194 - mean_pixel_error_metric_160_320: 24.9827 - val_loss: 0.0103 - val_mean_pixel_error_metric_160_320: 19.4172
# Epoch 15/50
# 162/162 ━━━━━━━━━━━━━━━━━━━━ 11s 70ms/step - loss: 0.0220 - mean_pixel_error_metric_160_320: 25.4156 - val_loss: 0.0069 - val_mean_pixel_error_metric_160_320: 15.9063
# Epoch 16/50
# 162/162 ━━━━━━━━━━━━━━━━━━━━ 11s 71ms/step - loss: 0.0204 - mean_pixel_error_metric_160_320: 24.6684 - val_loss: 0.0078 - val_mean_pixel_error_metric_160_320: 17.0004
# Epoch 17/50
# 162/162 ━━━━━━━━━━━━━━━━━━━━ 11s 70ms/step - loss: 0.0219 - mean_pixel_error_metric_160_320: 25.6563 - val_loss: 0.0064 - val_mean_pixel_error_metric_160_320: 14.4358
# Epoch 18/50
# 162/162 ━━━━━━━━━━━━━━━━━━━━ 11s 71ms/step - loss: 0.0221 - mean_pixel_error_metric_160_320: 24.6587 - val_loss: 0.0154 - val_mean_pixel_error_metric_160_320: 22.9751
# Epoch 19/50
# 162/162 ━━━━━━━━━━━━━━━━━━━━ 11s 71ms/step - loss: 0.0216 - mean_pixel_error_metric_160_320: 24.4201 - val_loss: 0.0059 - val_mean_pixel_error_metric_160_320: 13.8038
# Epoch 20/50
# 162/162 ━━━━━━━━━━━━━━━━━━━━ 12s 71ms/step - loss: 0.0164 - mean_pixel_error_metric_160_320: 20.2417 - val_loss: 0.0062 - val_mean_pixel_error_metric_160_320: 14.5822
# Epoch 21/50
# 162/162 ━━━━━━━━━━━━━━━━━━━━ 11s 71ms/step - loss: 0.0225 - mean_pixel_error_metric_160_320: 24.9842 - val_loss: 0.0080 - val_mean_pixel_error_metric_160_320: 16.6907
# Epoch 22/50
# 162/162 ━━━━━━━━━━━━━━━━━━━━ 12s 71ms/step - loss: 0.0228 - mean_pixel_error_metric_160_320: 24.6110 - val_loss: 0.0057 - val_mean_pixel_error_metric_160_320: 13.6621
# Epoch 23/50
# 162/162 ━━━━━━━━━━━━━━━━━━━━ 11s 71ms/step - loss: 0.0206 - mean_pixel_error_metric_160_320: 22.9731 - val_loss: 0.0058 - val_mean_pixel_error_metric_160_320: 13.8100
# Epoch 24/50
# 162/162 ━━━━━━━━━━━━━━━━━━━━ 11s 71ms/step - loss: 0.0170 - mean_pixel_error_metric_160_320: 20.8244 - val_loss: 0.0062 - val_mean_pixel_error_metric_160_320: 13.9454
# Epoch 25/50
# 162/162 ━━━━━━━━━━━━━━━━━━━━ 11s 70ms/step - loss: 0.0388 - mean_pixel_error_metric_160_320: 35.7879 - val_loss: 0.0120 - val_mean_pixel_error_metric_160_320: 22.1528
# Epoch 26/50
# 162/162 ━━━━━━━━━━━━━━━━━━━━ 11s 71ms/step - loss: 0.0419 - mean_pixel_error_metric_160_320: 41.2786 - val_loss: 0.0107 - val_mean_pixel_error_metric_160_320: 21.2598
# Epoch 27/50
# 162/162 ━━━━━━━━━━━━━━━━━━━━ 12s 71ms/step - loss: 0.0424 - mean_pixel_error_metric_160_320: 40.4848 - val_loss: 0.0120 - val_mean_pixel_error_metric_160_320: 23.4034
# Epoch 28/50
# 162/162 ━━━━━━━━━━━━━━━━━━━━ 11s 71ms/step - loss: 0.0390 - mean_pixel_error_metric_160_320: 39.3268 - val_loss: 0.0111 - val_mean_pixel_error_metric_160_320: 22.3475
# Epoch 29/50
# 162/162 ━━━━━━━━━━━━━━━━━━━━ 11s 71ms/step - loss: 0.0403 - mean_pixel_error_metric_160_320: 39.9361 - val_loss: 0.0131 - val_mean_pixel_error_metric_160_320: 22.9403
# Epoch 30/50
# 162/162 ━━━━━━━━━━━━━━━━━━━━ 11s 71ms/step - loss: 0.0417 - mean_pixel_error_metric_160_320: 41.4306 - val_loss: 0.0094 - val_mean_pixel_error_metric_160_320: 20.0464
# Epoch 31/50
# 162/162 ━━━━━━━━━━━━━━━━━━━━ 12s 71ms/step - loss: 0.0396 - mean_pixel_error_metric_160_320: 38.0515 - val_loss: 0.0099 - val_mean_pixel_error_metric_160_320: 21.0227
# Epoch 32/50
# 162/162 ━━━━━━━━━━━━━━━━━━━━ 12s 73ms/step - loss: 0.0383 - mean_pixel_error_metric_160_320: 37.9485 - val_loss: 0.0123 - val_mean_pixel_error_metric_160_320: 23.8252
# Epoch 32: early stopping
# Restoring model weights from the end of the best epoch: 22.

# %% [markdown]
# fine tuning

# %%
# unfreeze layer for fine tuning
for layer in model.layers:
    layer.trainable = True

# new optimizer for fine tuning
optimizer = tf.keras.optimizers.Adam(
    learning_rate=config['learning_rate_tuning'])

model.compile(optimizer=optimizer, loss=landmark_mse)

# callback fine tuning
callbacks_ft = [
    EarlyStopping(
        monitor='val_loss',
        patience=config['early_stop_patience'],
        restore_best_weights=True,
        verbose=1),
    WandbMetricsLogger(),
    WandbModelCheckpoint("wandb_model_finetuned.keras")]

# wandb
wandb.init(
    project='mosquito_landmarks',
    name=f"{config['model_name']}_finetune",
    config=config,
    reinit=True)  # important for new run

# fine tuning
history_ft = model.fit(
    train_dataset,
    validation_data=val_dataset,
    epochs=config['max_epochs_tuning'],
    callbacks=callbacks_ft,
    verbose=1)
# Out:
# Finishing previous runs because reinit is set to True.
# <br>    <style><br>        .wandb-row {<br>            display: flex;<br>            flex-direction: row;<br>            flex-wrap: wrap;<br>            justify-content: flex-start;<br>            width: 100%;<br>        }<br>        .wandb-col {<br>            display: flex;<br>            flex-direction: column;<br>            flex-basis: 100%;<br>            flex: 1;<br>            padding: 10px;<br>        }<br>    </style><br><div class="wandb-row"><div class="wandb-col"><h3>Run history:</h3><br/><table class="wandb"><tr><td>epoch/epoch</td><td>▁▁▁▂▂▂▂▃▃▃▃▃▄▄▄▄▅▅▅▅▆▆▆▆▆▇▇▇▇███</td></tr><tr><td>epoch/learning_rate</td><td>▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁</td></tr><tr><td>epoch/loss</td><td>█▆▄▂▂▁▁▁▁▁▁▁▁▁▂▂▂▂▁▁▁▂▁▁▄▃▃▃▄▃▃▃</td></tr><tr><td>epoch/mean_pixel_error_metric_160_320</td><td>█▇▅▃▂▂▁▁▁▁▂▂▁▁▂▁▂▁▁▁▁▁▁▁▃▃▃▃▄▃▃▃</td></tr><tr><td>epoch/val_loss</td><td>█▄▃▂▁▁▁▁▁▁▁▁▁▁▁▁▁▂▁▁▁▁▁▁▂▁▂▂▂▁▁▂</td></tr><tr><td>epoch/val_mean_pixel_error_metric_160_320</td><td>█▅▃▂▂▁▂▁▁▁▁▁▁▂▁▂▁▂▁▁▂▁▁▁▂▂▂▂▂▂▂▂</td></tr></table><br/></div><div class="wandb-col"><h3>Run summary:</h3><br/><table class="wandb"><tr><td>epoch/epoch</td><td>31</td></tr><tr><td>epoch/learning_rate</td><td>0.001</td></tr><tr><td>epoch/loss</td><td>0.04074</td></tr><tr><td>epoch/mean_pixel_error_metric_160_320</td><td>40.05692</td></tr><tr><td>epoch/val_loss</td><td>0.01229</td></tr><tr><td>epoch/val_mean_pixel_error_metric_160_320</td><td>23.82516</td></tr></table><br/></div></div>
#  View run <strong style="color:#cdcd00">CNN_without_Iphone_100_full_augmentation</strong> at: <a href='https://wandb.ai/arlettedel-universit-t-hamburg/mosquito_landmarks/runs/6gf4necj' target="_blank">https://wandb.ai/arlettedel-universit-t-hamburg/mosquito_landmarks/runs/6gf4necj</a><br> View project at: <a href='https://wandb.ai/arlettedel-universit-t-hamburg/mosquito_landmarks' target="_blank">https://wandb.ai/arlettedel-universit-t-hamburg/mosquito_landmarks</a><br>Synced 5 W&B file(s), 0 media file(s), 64 artifact file(s) and 0 other file(s)
# Find logs at: <code>./wandb/run-20250829_154712-6gf4necj/logs</code>
# wandb: WARNING Using a boolean value for 'reinit' is deprecated. Use 'return_previous' or 'finish_previous' instead.
# Tracking run with wandb version 0.21.1
# Run data is saved locally in <code>/content/wandb/run-20250829_155353-23dfub6k</code>
# Syncing run <strong><a href='https://wandb.ai/arlettedel-universit-t-hamburg/mosquito_landmarks/runs/23dfub6k' target="_blank">CNN_without_Iphone_100_full_augmentation_finetune</a></strong> to <a href='https://wandb.ai/arlettedel-universit-t-hamburg/mosquito_landmarks' target="_blank">Weights & Biases</a> (<a href='https://wandb.me/developer-guide' target="_blank">docs</a>)<br>
#  View project at <a href='https://wandb.ai/arlettedel-universit-t-hamburg/mosquito_landmarks' target="_blank">https://wandb.ai/arlettedel-universit-t-hamburg/mosquito_landmarks</a>
#  View run at <a href='https://wandb.ai/arlettedel-universit-t-hamburg/mosquito_landmarks/runs/23dfub6k' target="_blank">https://wandb.ai/arlettedel-universit-t-hamburg/mosquito_landmarks/runs/23dfub6k</a>
# Epoch 1/100
# 162/162 ━━━━━━━━━━━━━━━━━━━━ 93s 240ms/step - loss: 0.0847 - mean_pixel_error_metric_160_320: 57.6380 - val_loss: 0.0910 - val_mean_pixel_error_metric_160_320: 80.3941
# Epoch 2/100
# 162/162 ━━━━━━━━━━━━━━━━━━━━ 32s 200ms/step - loss: 0.0040 - mean_pixel_error_metric_160_320: 13.9437 - val_loss: 0.0856 - val_mean_pixel_error_metric_160_320: 78.4389
# Epoch 3/100
# 162/162 ━━━━━━━━━━━━━━━━━━━━ 32s 199ms/step - loss: 0.0029 - mean_pixel_error_metric_160_320: 11.5744 - val_loss: 0.0812 - val_mean_pixel_error_metric_160_320: 67.4561
# Epoch 4/100
# 162/162 ━━━━━━━━━━━━━━━━━━━━ 32s 198ms/step - loss: 0.0023 - mean_pixel_error_metric_160_320: 10.3643 - val_loss: 0.0843 - val_mean_pixel_error_metric_160_320: 58.1895
# Epoch 5/100
# 162/162 ━━━━━━━━━━━━━━━━━━━━ 32s 199ms/step - loss: 0.0022 - mean_pixel_error_metric_160_320: 9.9650 - val_loss: 0.0859 - val_mean_pixel_error_metric_160_320: 53.4784
# Epoch 6/100
# 162/162 ━━━━━━━━━━━━━━━━━━━━ 32s 200ms/step - loss: 0.0021 - mean_pixel_error_metric_160_320: 9.7286 - val_loss: 0.0236 - val_mean_pixel_error_metric_160_320: 23.5443
# Epoch 7/100
# 162/162 ━━━━━━━━━━━━━━━━━━━━ 32s 200ms/step - loss: 0.0020 - mean_pixel_error_metric_160_320: 9.7236 - val_loss: 0.0022 - val_mean_pixel_error_metric_160_320: 9.3158
# Epoch 8/100
# 162/162 ━━━━━━━━━━━━━━━━━━━━ 33s 204ms/step - loss: 0.0021 - mean_pixel_error_metric_160_320: 9.6656 - val_loss: 0.0031 - val_mean_pixel_error_metric_160_320: 11.4217
# Epoch 9/100
# 162/162 ━━━━━━━━━━━━━━━━━━━━ 32s 199ms/step - loss: 0.0024 - mean_pixel_error_metric_160_320: 10.1265 - val_loss: 0.0024 - val_mean_pixel_error_metric_160_320: 9.5244
# Epoch 10/100
# 162/162 ━━━━━━━━━━━━━━━━━━━━ 32s 198ms/step - loss: 0.0021 - mean_pixel_error_metric_160_320: 9.4268 - val_loss: 0.0025 - val_mean_pixel_error_metric_160_320: 9.8589
# Epoch 11/100
# 162/162 ━━━━━━━━━━━━━━━━━━━━ 33s 204ms/step - loss: 0.0019 - mean_pixel_error_metric_160_320: 9.1864 - val_loss: 0.0020 - val_mean_pixel_error_metric_160_320: 8.6657
# Epoch 12/100
# 162/162 ━━━━━━━━━━━━━━━━━━━━ 32s 199ms/step - loss: 0.0019 - mean_pixel_error_metric_160_320: 9.1475 - val_loss: 0.0020 - val_mean_pixel_error_metric_160_320: 8.2238
# Epoch 13/100
# 162/162 ━━━━━━━━━━━━━━━━━━━━ 33s 201ms/step - loss: 0.0017 - mean_pixel_error_metric_160_320: 8.7739 - val_loss: 0.0021 - val_mean_pixel_error_metric_160_320: 8.6230
# Epoch 14/100
# 162/162 ━━━━━━━━━━━━━━━━━━━━ 32s 198ms/step - loss: 0.0018 - mean_pixel_error_metric_160_320: 8.7317 - val_loss: 0.0026 - val_mean_pixel_error_metric_160_320: 10.4112
# Epoch 15/100
# 162/162 ━━━━━━━━━━━━━━━━━━━━ 32s 199ms/step - loss: 0.0017 - mean_pixel_error_metric_160_320: 8.5463 - val_loss: 0.0021 - val_mean_pixel_error_metric_160_320: 8.6598
# Epoch 16/100
# 162/162 ━━━━━━━━━━━━━━━━━━━━ 33s 201ms/step - loss: 0.0018 - mean_pixel_error_metric_160_320: 8.5780 - val_loss: 0.0019 - val_mean_pixel_error_metric_160_320: 8.0604
# Epoch 17/100
# 162/162 ━━━━━━━━━━━━━━━━━━━━ 32s 200ms/step - loss: 0.0016 - mean_pixel_error_metric_160_320: 8.4703 - val_loss: 0.0018 - val_mean_pixel_error_metric_160_320: 8.1673
# Epoch 18/100
# 162/162 ━━━━━━━━━━━━━━━━━━━━ 32s 198ms/step - loss: 0.0016 - mean_pixel_error_metric_160_320: 8.4019 - val_loss: 0.0018 - val_mean_pixel_error_metric_160_320: 8.5458
# Epoch 19/100
# 162/162 ━━━━━━━━━━━━━━━━━━━━ 32s 199ms/step - loss: 0.0017 - mean_pixel_error_metric_160_320: 8.3386 - val_loss: 0.0017 - val_mean_pixel_error_metric_160_320: 8.1266
# Epoch 20/100
# 162/162 ━━━━━━━━━━━━━━━━━━━━ 32s 200ms/step - loss: 0.0015 - mean_pixel_error_metric_160_320: 8.1689 - val_loss: 0.0017 - val_mean_pixel_error_metric_160_320: 8.0986
# Epoch 21/100
# 162/162 ━━━━━━━━━━━━━━━━━━━━ 33s 201ms/step - loss: 0.0020 - mean_pixel_error_metric_160_320: 8.6288 - val_loss: 0.0049 - val_mean_pixel_error_metric_160_320: 15.1975
# Epoch 22/100
# 162/162 ━━━━━━━━━━━━━━━━━━━━ 32s 198ms/step - loss: 0.0019 - mean_pixel_error_metric_160_320: 9.4741 - val_loss: 0.0042 - val_mean_pixel_error_metric_160_320: 10.4970
# Epoch 23/100
# 162/162 ━━━━━━━━━━━━━━━━━━━━ 32s 199ms/step - loss: 0.0026 - mean_pixel_error_metric_160_320: 10.2667 - val_loss: 0.0021 - val_mean_pixel_error_metric_160_320: 8.9251
# Epoch 24/100
# 162/162 ━━━━━━━━━━━━━━━━━━━━ 33s 201ms/step - loss: 0.0017 - mean_pixel_error_metric_160_320: 8.9152 - val_loss: 0.0021 - val_mean_pixel_error_metric_160_320: 9.1228
# Epoch 25/100
# 162/162 ━━━━━━━━━━━━━━━━━━━━ 32s 199ms/step - loss: 0.0015 - mean_pixel_error_metric_160_320: 8.4927 - val_loss: 0.0022 - val_mean_pixel_error_metric_160_320: 10.1555
# Epoch 26/100
# 162/162 ━━━━━━━━━━━━━━━━━━━━ 32s 198ms/step - loss: 0.0051 - mean_pixel_error_metric_160_320: 11.7125 - val_loss: 0.5859 - val_mean_pixel_error_metric_160_320: 200.9251
# Epoch 27/100
# 162/162 ━━━━━━━━━━━━━━━━━━━━ 32s 199ms/step - loss: 0.0041 - mean_pixel_error_metric_160_320: 12.2733 - val_loss: 0.0039 - val_mean_pixel_error_metric_160_320: 10.7839
# Epoch 28/100
# 162/162 ━━━━━━━━━━━━━━━━━━━━ 33s 202ms/step - loss: 0.0025 - mean_pixel_error_metric_160_320: 10.2278 - val_loss: 0.0050 - val_mean_pixel_error_metric_160_320: 13.5251
# Epoch 29/100
# 162/162 ━━━━━━━━━━━━━━━━━━━━ 32s 197ms/step - loss: 0.0020 - mean_pixel_error_metric_160_320: 9.5146 - val_loss: 0.0027 - val_mean_pixel_error_metric_160_320: 9.7238
# Epoch 30/100
# 162/162 ━━━━━━━━━━━━━━━━━━━━ 32s 198ms/step - loss: 0.0021 - mean_pixel_error_metric_160_320: 9.5211 - val_loss: 0.0101 - val_mean_pixel_error_metric_160_320: 14.1882
# Epoch 30: early stopping
# Restoring model weights from the end of the best epoch: 20.

# %% [markdown]
# plot loss for train and evaluation

# %%
fig, ax1 = plt.subplots(figsize=(8, 5))

# y1: loss
ax1.plot(history.history['loss'], label='Train Loss', linestyle='-', color='black')
ax1.plot(history.history['val_loss'], label='Val Loss', linestyle='-', color='gray')
ax1.set_xlabel('Epochs', color='black')
ax1.set_ylabel('Loss', color='black')
ax1.tick_params(axis='y', labelcolor='black')
ax1.tick_params(axis='x', labelcolor='black')

# y2: MPE
ax2 = ax1.twinx()
ax2.plot(history.history['mean_pixel_error_metric_160_320'], label='Train MPE', linestyle='--', color='black')
ax2.plot(history.history['val_mean_pixel_error_metric_160_320'], label='Val MPE', linestyle='--', color='gray')
ax2.set_ylabel('Mean Pixel Error [px]', color='black')
ax2.tick_params(axis='y', labelcolor='black')

lines_1, labels_1 = ax1.get_legend_handles_labels()
lines_2, labels_2 = ax2.get_legend_handles_labels()
ax1.legend(lines_1 + lines_2, labels_1 + labels_2, loc='upper right')

plt.title("Training Loss & Mean Pixel Error", color='black')
plt.show()

# %% [markdown]
# mini evaluation test set

# %%
#mpe +- std
pred_coords_norm = model.predict(X_test)
# Out:
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 13s 220ms/step

# %%
distances = np.linalg.norm(y_test - pred_coords_norm, axis=-1)

# %%
# image size
H, W = 160, 320

# convert to pixel size
diff_pixel = (y_test - pred_coords_norm) * np.array([H, W])
distances_pixel = np.linalg.norm(diff_pixel, axis=-1)

# prediction errors
mpe_mean = distances_pixel.mean()
mpe_std = distances_pixel.std()
mpe_median = np.median(distances_pixel)

print(f"Mean Prediction Error (MPE) in pixels: {mpe_mean:.2f} ± {mpe_std:.2f}")
print(f"Median Prediction Error in pixels: {mpe_median:.2f}")
# Out:
# Mean Prediction Error (MPE) in pixels: 6.16 ± 4.43
# Median Prediction Error in pixels: 5.26

# %% [markdown]
# save predictions in normalized pixel coords for evaluation

# %%
save_dir2 = '/content/drive/MyDrive/Arlette/Model_Outputs'
os.makedirs(save_dir2, exist_ok=True)
np.save(f"{save_dir2}/predictions_norm_CNN_full_augmentation_without_iPhone.npy", pred_coords_norm)

# %% [markdown]
# save model weights and output

# %%
#save best config based on validation loss

# %%
save_dir = '/content/drive/MyDrive/Arlette/model_weights'
os.makedirs(save_dir, exist_ok=True)

model.save(f'{save_dir}/CNN_full_augmentation_without_iPhone.keras')
model.save_weights(f'{save_dir}/CNN_full_augmentation_without_iPhone.weights.h5')
