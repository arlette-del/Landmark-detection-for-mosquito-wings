# %% [markdown]
# setup/ import

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import random
import os

import tensorflow as tf

import wandb
from wandb.integration.keras import WandbMetricsLogger, WandbCallback, WandbModelCheckpoint

from sklearn.model_selection import train_test_split

from tensorflow.keras.layers import Dense, Input
from tensorflow.keras.models import Model
from tensorflow.keras.callbacks import EarlyStopping
from tensorflow.keras import layers

# %%
print('Tensorflow version:', tf.__version__)
print('Weights and biases version:', wandb.__version__)
# Out:
# Tensorflow version: 2.19.0
# Weights and biases version: 0.21.1

# %% [markdown]
# load data

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
X_train = np.load('/content/drive/MyDrive/Arlette/Sets for Training /Dataset with iPhone/train_aug_images_320x640.npy')
X_val = np.load('/content/drive/MyDrive/Arlette/Sets for Training /Dataset with iPhone/val_images_320x640.npy')
X_test = np.load('/content/drive/MyDrive/Arlette/Sets for Training /Dataset with iPhone/test_images_320x640.npy')

y_train = np.load('/content/drive/MyDrive/Arlette/Sets for Training /Dataset with iPhone/train_aug_landmarks.npy')
y_val = np.load('/content/drive/MyDrive/Arlette/Sets for Training /Dataset with iPhone/val_landmarks.npy')
y_test = np.load('/content/drive/MyDrive/Arlette/Sets for Training /Dataset with iPhone/test_landmarks.npy')

# %% [markdown]
# define hyperparameters

# %%
def get_config(model_name='resnet50_withIphone_100_augmentation_320_640',
               img_size=(320, 640),
               batch_size=16,
               learning_rate_transfer=1e-3,
               learning_rate_tuning=5e-4,
               max_epochs_transfer=50,
               max_epochs_tuning=100,
               early_stop_patience=10,
               steps_per_epoch=81,
               dropout=0.5,
               seed=42):

    # cosine decay
    cosine_decay_steps = steps_per_epoch * max_epochs_tuning
    learning_schedule = {
        'initial_learning_rate': learning_rate_tuning,
        'decay_steps': cosine_decay_steps,
        'warmup_target': learning_rate_tuning,
        'warmup_steps': int(cosine_decay_steps * 0.02)
    }

    # config dictionary
    config = {
        'model_name': model_name,
        'img_size': img_size,
        'batch_size': batch_size,
        'learning_rate_transfer': learning_rate_transfer,
        'learning_rate_tuning': learning_rate_tuning,
        'max_epochs_transfer': max_epochs_transfer,
        'max_epochs_tuning': max_epochs_tuning,
        'early_stop_patience': early_stop_patience,
        'steps_per_epoch': steps_per_epoch,
        'cosine_decay_steps': cosine_decay_steps,
        'dropout': dropout,
        'learning_schedule': learning_schedule,
        'seed': seed
    }

    return config

# %%
config = get_config()
SEED = config['seed']
img_size = config['img_size']
batch_size = config['batch_size']
seed = config['seed']

# %% [markdown]
# create tensorflow dataset

# %%
train_dataset = tf.data.Dataset.from_tensor_slices((X_train, y_train))
train_dataset = train_dataset.shuffle(buffer_size=1000).batch(batch_size).prefetch(tf.data.AUTOTUNE)

val_dataset = tf.data.Dataset.from_tensor_slices((X_val, y_val)).batch(batch_size).prefetch(tf.data.AUTOTUNE)
test_dataset = tf.data.Dataset.from_tensor_slices((X_test, y_test)).batch(batch_size).prefetch(tf.data.AUTOTUNE)

# %% [markdown]
# define loss and metric

# %%
# loss in normalized units [0,1]
# computes mean squared error per landmark in normalized coordinates
# arg: y_true and y_pred in tensor shape (batch_size, num_landmarks, 2) [0,1]
# returns scalar tensor: average MSE over all landmarks in the batch
def landmark_mse(y_true, y_pred):
    y_true = tf.cast(y_true, tf.float32)
    y_pred = tf.cast(y_pred, tf.float32)
    return tf.reduce_mean(tf.reduce_sum(tf.square(y_true - y_pred), axis=-1))


# metric
# mean pixel error
# computes average euclidean distance per landmark in pixels
# arg: y_true and y_pred in tensor shape (batch_size, num_landmarks, 2) [0,1]
#      img_size: tuple [int, int], image height and with (H, W)
# returns scalar tensor: mean pixel error over batch
def mean_pixel_error_metric_320_640(y_true, y_pred):
    H, W = 320,640
    y_true = tf.cast(y_true, tf.float32)
    y_pred = tf.cast(y_pred, tf.float32)
    y_true_px = y_true * tf.constant([W, H], dtype=tf.float32)
    y_pred_px = y_pred * tf.constant([W, H], dtype=tf.float32)
    dist = tf.sqrt(tf.reduce_sum(tf.square(y_true_px - y_pred_px), axis=-1))
    return tf.reduce_mean(dist)

# %% [markdown]
# define model

# %%
from tensorflow.keras.applications import ResNet50

def build_resnet50_landmark_model(input_shape=(320, 640, 3),
                                  num_landmarks=18,
                                  trainable_backbone=False):
    backbone = ResNet50(
        include_top=False,
        weights='imagenet',
        input_shape=input_shape,
        pooling=None
    )
    backbone.trainable = trainable_backbone

    inputs = tf.keras.Input(shape=input_shape)
    x = backbone(inputs, training=False)
    x = tf.keras.layers.GlobalAveragePooling2D()(x)

    # head
    x = tf.keras.layers.Dense(256, activation='relu')(x)
    x = tf.keras.layers.Dropout(0.3)(x)
    x = tf.keras.layers.Dense(128, activation='relu')(x)
    x = tf.keras.layers.Dropout(0.3)(x)

    # output
    x = tf.keras.layers.Dense(num_landmarks * 2, activation='sigmoid')(x)
    outputs = tf.keras.layers.Reshape((num_landmarks, 2))(x)

    return tf.keras.Model(inputs, outputs, name='resnet50_landmark_model')

# %%
input_shape = (320, 640, 3)
num_landmarks = 18

model = build_resnet50_landmark_model(input_shape=input_shape, num_landmarks=num_landmarks)

model.compile(optimizer=tf.keras.optimizers.Adam(learning_rate=config['learning_rate_transfer']),
              loss=landmark_mse,
              metrics=[mean_pixel_error_metric_320_640])

model.summary()
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/keras-applications/resnet/resnet50_weights_tf_dim_ordering_tf_kernels_notop.h5
# 94765736/94765736 ━━━━━━━━━━━━━━━━━━━━ 0s 0us/step
# Model: "resnet50_landmark_model"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ input_layer_1 (InputLayer)      │ (None, 320, 640, 3)    │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ resnet50 (Functional)           │ (None, 10, 20, 2048)   │    23,587,712 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ global_average_pooling2d        │ (None, 2048)           │             0 │
# │ (GlobalAveragePooling2D)        │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense (Dense)                   │ (None, 256)            │       524,544 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout (Dropout)               │ (None, 256)            │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_1 (Dense)                 │ (None, 128)            │        32,896 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_1 (Dropout)             │ (None, 128)            │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_2 (Dense)                 │ (None, 36)             │         4,644 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ reshape (Reshape)               │ (None, 18, 2)          │             0 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 24,149,796 (92.12 MB)
#  Trainable params: 562,084 (2.14 MB)
#  Non-trainable params: 23,587,712 (89.98 MB)

# %% [markdown]
# callbacks // weights and biases

# %%
wandb.init(project='mosquito_landmarks',name=f"{config['model_name']}",config=config)

callbacks = [EarlyStopping(monitor='val_loss',
            patience=config['early_stop_patience'],
            restore_best_weights=True,
            verbose=1),
            WandbMetricsLogger(),
            WandbModelCheckpoint("wandb_model.keras")]
# Out:
# /usr/local/lib/python3.12/dist-packages/notebook/notebookapp.py:191: SyntaxWarning: invalid escape sequence '\/'
#   | |_| | '_ \/ _` / _` |  _/ -_)
# wandb: Logging into wandb.ai. (Learn how to deploy a W&B server locally: https://wandb.me/wandb-server)
# wandb: You can find your API key in your browser here: https://wandb.ai/authorize?ref=models
# wandb: Paste an API key from your profile and hit enter:
#  ··········
# wandb: WARNING If you're specifying your api key in code, ensure this code is not shared publicly.
# wandb: WARNING Consider setting the WANDB_API_KEY environment variable, or running `wandb login` from the command line.
# wandb: No netrc file found, creating one.
# wandb: Appending key for api.wandb.ai to your netrc file: /root/.netrc
# wandb: Currently logged in as: arlettedel (arlettedel-universit-t-hamburg) to https://api.wandb.ai. Use `wandb login --relogin` to force relogin
# Tracking run with wandb version 0.21.1
# Run data is saved locally in <code>/content/wandb/run-20250830_080004-3sfm5nsr</code>
# Syncing run <strong><a href='https://wandb.ai/arlettedel-universit-t-hamburg/mosquito_landmarks/runs/3sfm5nsr' target="_blank">resnet50_withIphone_100_augmentation_320_640</a></strong> to <a href='https://wandb.ai/arlettedel-universit-t-hamburg/mosquito_landmarks' target="_blank">Weights & Biases</a> (<a href='https://wandb.me/developer-guide' target="_blank">docs</a>)<br>
#  View project at <a href='https://wandb.ai/arlettedel-universit-t-hamburg/mosquito_landmarks' target="_blank">https://wandb.ai/arlettedel-universit-t-hamburg/mosquito_landmarks</a>
#  View run at <a href='https://wandb.ai/arlettedel-universit-t-hamburg/mosquito_landmarks/runs/3sfm5nsr' target="_blank">https://wandb.ai/arlettedel-universit-t-hamburg/mosquito_landmarks/runs/3sfm5nsr</a>

# %% [markdown]
# train model

# %%
history = model.fit(train_dataset, validation_data=val_dataset,
                    epochs=config['max_epochs_transfer'],
                    callbacks=callbacks,
                    verbose=1)
# Out:
# Epoch 1/50
# 186/186 ━━━━━━━━━━━━━━━━━━━━ 38s 204ms/step - loss: 0.0847 - mean_pixel_error_metric_320_640: 156.1147 - val_loss: 0.0835 - val_mean_pixel_error_metric_320_640: 155.1156
# Epoch 2/50
# 186/186 ━━━━━━━━━━━━━━━━━━━━ 37s 201ms/step - loss: 0.0849 - mean_pixel_error_metric_320_640: 156.3456 - val_loss: 0.0832 - val_mean_pixel_error_metric_320_640: 154.7953
# Epoch 3/50
# 186/186 ━━━━━━━━━━━━━━━━━━━━ 37s 198ms/step - loss: 0.0848 - mean_pixel_error_metric_320_640: 156.1528 - val_loss: 0.0833 - val_mean_pixel_error_metric_320_640: 154.8893
# Epoch 4/50
# 186/186 ━━━━━━━━━━━━━━━━━━━━ 37s 201ms/step - loss: 0.0843 - mean_pixel_error_metric_320_640: 155.7179 - val_loss: 0.0835 - val_mean_pixel_error_metric_320_640: 155.0558
# Epoch 5/50
# 186/186 ━━━━━━━━━━━━━━━━━━━━ 37s 199ms/step - loss: 0.0844 - mean_pixel_error_metric_320_640: 155.8743 - val_loss: 0.0836 - val_mean_pixel_error_metric_320_640: 155.2383
# Epoch 6/50
# 186/186 ━━━━━━━━━━━━━━━━━━━━ 37s 199ms/step - loss: 0.0846 - mean_pixel_error_metric_320_640: 156.1318 - val_loss: 0.0833 - val_mean_pixel_error_metric_320_640: 154.7323
# Epoch 7/50
# 186/186 ━━━━━━━━━━━━━━━━━━━━ 37s 202ms/step - loss: 0.0847 - mean_pixel_error_metric_320_640: 156.0579 - val_loss: 0.0831 - val_mean_pixel_error_metric_320_640: 154.6120
# Epoch 8/50
# 186/186 ━━━━━━━━━━━━━━━━━━━━ 37s 200ms/step - loss: 0.0845 - mean_pixel_error_metric_320_640: 155.9396 - val_loss: 0.0833 - val_mean_pixel_error_metric_320_640: 154.7846
# Epoch 9/50
# 186/186 ━━━━━━━━━━━━━━━━━━━━ 37s 200ms/step - loss: 0.0844 - mean_pixel_error_metric_320_640: 155.6513 - val_loss: 0.0833 - val_mean_pixel_error_metric_320_640: 154.7798
# Epoch 10/50
# 186/186 ━━━━━━━━━━━━━━━━━━━━ 37s 200ms/step - loss: 0.0846 - mean_pixel_error_metric_320_640: 156.0022 - val_loss: 0.0835 - val_mean_pixel_error_metric_320_640: 155.1169
# Epoch 11/50
# 186/186 ━━━━━━━━━━━━━━━━━━━━ 37s 200ms/step - loss: 0.0847 - mean_pixel_error_metric_320_640: 156.1752 - val_loss: 0.0835 - val_mean_pixel_error_metric_320_640: 155.0808
# Epoch 12/50
# 186/186 ━━━━━━━━━━━━━━━━━━━━ 37s 200ms/step - loss: 0.0849 - mean_pixel_error_metric_320_640: 156.4133 - val_loss: 0.0833 - val_mean_pixel_error_metric_320_640: 154.8166
# Epoch 13/50
# 186/186 ━━━━━━━━━━━━━━━━━━━━ 37s 199ms/step - loss: 0.0844 - mean_pixel_error_metric_320_640: 155.7800 - val_loss: 0.0834 - val_mean_pixel_error_metric_320_640: 155.0481
# Epoch 14/50
# 186/186 ━━━━━━━━━━━━━━━━━━━━ 37s 200ms/step - loss: 0.0847 - mean_pixel_error_metric_320_640: 156.2237 - val_loss: 0.0835 - val_mean_pixel_error_metric_320_640: 155.0634
# Epoch 15/50
# 186/186 ━━━━━━━━━━━━━━━━━━━━ 37s 200ms/step - loss: 0.0846 - mean_pixel_error_metric_320_640: 156.0645 - val_loss: 0.0833 - val_mean_pixel_error_metric_320_640: 154.7874
# Epoch 16/50
# 186/186 ━━━━━━━━━━━━━━━━━━━━ 37s 199ms/step - loss: 0.0846 - mean_pixel_error_metric_320_640: 155.9895 - val_loss: 0.0831 - val_mean_pixel_error_metric_320_640: 154.5626
# Epoch 17/50
# 186/186 ━━━━━━━━━━━━━━━━━━━━ 37s 199ms/step - loss: 0.0845 - mean_pixel_error_metric_320_640: 155.8485 - val_loss: 0.0835 - val_mean_pixel_error_metric_320_640: 155.1117
# Epoch 17: early stopping
# Restoring model weights from the end of the best epoch: 7.

# %% [markdown]
# fine tuning

# %%
# unfreeze layer for fine tuning
for layer in model.layers:
    layer.trainable = True

# new optimizer for fine tuning
optimizer = tf.keras.optimizers.Adam(
    learning_rate=config['learning_rate_tuning'])

model.compile(optimizer=optimizer, loss=landmark_mse)

# callback fine tuning
callbacks_ft = [
    EarlyStopping(
        monitor='val_loss',
        patience=config['early_stop_patience'],
        restore_best_weights=True,
        verbose=1),
    WandbMetricsLogger(),
    WandbModelCheckpoint("wandb_model_finetuned.keras")]

# wandb
wandb.init(
    project='mosquito_landmarks',
    name=f"{config['model_name']}_finetune",
    config=config,
    reinit=True)  # important for new run

# fine tuning
history_ft = model.fit(
    train_dataset,
    validation_data=val_dataset,
    epochs=config['max_epochs_tuning'],
    callbacks=callbacks_ft,
    verbose=1)
# Out:
# Finishing previous runs because reinit is set to True.
# <br>    <style><br>        .wandb-row {<br>            display: flex;<br>            flex-direction: row;<br>            flex-wrap: wrap;<br>            justify-content: flex-start;<br>            width: 100%;<br>        }<br>        .wandb-col {<br>            display: flex;<br>            flex-direction: column;<br>            flex-basis: 100%;<br>            flex: 1;<br>            padding: 10px;<br>        }<br>    </style><br><div class="wandb-row"><div class="wandb-col"><h3>Run history:</h3><br/><table class="wandb"><tr><td>epoch/epoch</td><td>▁▁▂▂▃▁▁▂▂▃▃▄▄▅▅▅▆▆▇▇██</td></tr><tr><td>epoch/learning_rate</td><td>▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁</td></tr><tr><td>epoch/loss</td><td>█▂▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁</td></tr><tr><td>epoch/mean_pixel_error_metric_320_640</td><td>█▂▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁</td></tr><tr><td>epoch/val_loss</td><td>▁▆▅▂▂▆▃▄▆█▄▂▄▃▆▆▃▅▆▃▂▆</td></tr><tr><td>epoch/val_mean_pixel_error_metric_320_640</td><td>▁▆▇▂▄▇▅▆▇█▄▄▅▅▇▇▅▇▇▅▃▇</td></tr></table><br/></div><div class="wandb-col"><h3>Run summary:</h3><br/><table class="wandb"><tr><td>epoch/epoch</td><td>16</td></tr><tr><td>epoch/learning_rate</td><td>0.001</td></tr><tr><td>epoch/loss</td><td>0.0845</td></tr><tr><td>epoch/mean_pixel_error_metric_320_640</td><td>155.9175</td></tr><tr><td>epoch/val_loss</td><td>0.0835</td></tr><tr><td>epoch/val_mean_pixel_error_metric_320_640</td><td>155.11166</td></tr></table><br/></div></div>
#  View run <strong style="color:#cdcd00">resnet50_withIphone_100_augmentation_320_640</strong> at: <a href='https://wandb.ai/arlettedel-universit-t-hamburg/mosquito_landmarks/runs/3sfm5nsr' target="_blank">https://wandb.ai/arlettedel-universit-t-hamburg/mosquito_landmarks/runs/3sfm5nsr</a><br> View project at: <a href='https://wandb.ai/arlettedel-universit-t-hamburg/mosquito_landmarks' target="_blank">https://wandb.ai/arlettedel-universit-t-hamburg/mosquito_landmarks</a><br>Synced 5 W&B file(s), 0 media file(s), 44 artifact file(s) and 0 other file(s)
# Find logs at: <code>./wandb/run-20250830_080004-3sfm5nsr/logs</code>
# wandb: WARNING Using a boolean value for 'reinit' is deprecated. Use 'return_previous' or 'finish_previous' instead.
# Tracking run with wandb version 0.21.1
# Run data is saved locally in <code>/content/wandb/run-20250830_081937-nygyak63</code>
# Syncing run <strong><a href='https://wandb.ai/arlettedel-universit-t-hamburg/mosquito_landmarks/runs/nygyak63' target="_blank">resnet50_withIphone_100_augmentation_320_640_finetune</a></strong> to <a href='https://wandb.ai/arlettedel-universit-t-hamburg/mosquito_landmarks' target="_blank">Weights & Biases</a> (<a href='https://wandb.me/developer-guide' target="_blank">docs</a>)<br>
#  View project at <a href='https://wandb.ai/arlettedel-universit-t-hamburg/mosquito_landmarks' target="_blank">https://wandb.ai/arlettedel-universit-t-hamburg/mosquito_landmarks</a>
#  View run at <a href='https://wandb.ai/arlettedel-universit-t-hamburg/mosquito_landmarks/runs/nygyak63' target="_blank">https://wandb.ai/arlettedel-universit-t-hamburg/mosquito_landmarks/runs/nygyak63</a>
# Epoch 1/100
# 186/186 ━━━━━━━━━━━━━━━━━━━━ 198s 717ms/step - loss: 0.0857 - mean_pixel_error_metric_320_640: 156.3955 - val_loss: 0.0833 - val_mean_pixel_error_metric_320_640: 154.8502
# Epoch 2/100
# 186/186 ━━━━━━━━━━━━━━━━━━━━ 104s 561ms/step - loss: 0.0845 - mean_pixel_error_metric_320_640: 155.8553 - val_loss: 0.0833 - val_mean_pixel_error_metric_320_640: 154.8273
# Epoch 3/100
# 186/186 ━━━━━━━━━━━━━━━━━━━━ 102s 551ms/step - loss: 0.0848 - mean_pixel_error_metric_320_640: 156.2988 - val_loss: 0.0834 - val_mean_pixel_error_metric_320_640: 154.9001
# Epoch 4/100
# 186/186 ━━━━━━━━━━━━━━━━━━━━ 102s 549ms/step - loss: 0.0844 - mean_pixel_error_metric_320_640: 155.7957 - val_loss: 0.0834 - val_mean_pixel_error_metric_320_640: 154.9479
# Epoch 5/100
# 186/186 ━━━━━━━━━━━━━━━━━━━━ 100s 538ms/step - loss: 0.0846 - mean_pixel_error_metric_320_640: 156.1338 - val_loss: 0.0834 - val_mean_pixel_error_metric_320_640: 154.9210
# Epoch 6/100
# 186/186 ━━━━━━━━━━━━━━━━━━━━ 100s 537ms/step - loss: 0.0845 - mean_pixel_error_metric_320_640: 155.9592 - val_loss: 0.0835 - val_mean_pixel_error_metric_320_640: 155.1506
# Epoch 7/100
# 186/186 ━━━━━━━━━━━━━━━━━━━━ 99s 533ms/step - loss: 0.0844 - mean_pixel_error_metric_320_640: 155.8613 - val_loss: 0.0835 - val_mean_pixel_error_metric_320_640: 155.1369
# Epoch 8/100
# 186/186 ━━━━━━━━━━━━━━━━━━━━ 99s 535ms/step - loss: 0.0847 - mean_pixel_error_metric_320_640: 156.1649 - val_loss: 0.0835 - val_mean_pixel_error_metric_320_640: 154.9977
# Epoch 9/100
# 186/186 ━━━━━━━━━━━━━━━━━━━━ 99s 533ms/step - loss: 0.0847 - mean_pixel_error_metric_320_640: 156.1459 - val_loss: 0.0835 - val_mean_pixel_error_metric_320_640: 155.0203
# Epoch 10/100
# 186/186 ━━━━━━━━━━━━━━━━━━━━ 102s 549ms/step - loss: 0.0847 - mean_pixel_error_metric_320_640: 156.0374 - val_loss: 0.0831 - val_mean_pixel_error_metric_320_640: 154.5539
# Epoch 11/100
# 186/186 ━━━━━━━━━━━━━━━━━━━━ 102s 547ms/step - loss: 0.0844 - mean_pixel_error_metric_320_640: 155.8460 - val_loss: 0.0832 - val_mean_pixel_error_metric_320_640: 154.7762
# Epoch 12/100
# 186/186 ━━━━━━━━━━━━━━━━━━━━ 101s 544ms/step - loss: 0.0846 - mean_pixel_error_metric_320_640: 155.8820 - val_loss: 0.0833 - val_mean_pixel_error_metric_320_640: 154.8879
# Epoch 13/100
# 186/186 ━━━━━━━━━━━━━━━━━━━━ 100s 539ms/step - loss: 0.0844 - mean_pixel_error_metric_320_640: 155.9228 - val_loss: 0.0834 - val_mean_pixel_error_metric_320_640: 155.0291
# Epoch 14/100
# 186/186 ━━━━━━━━━━━━━━━━━━━━ 100s 537ms/step - loss: 0.0844 - mean_pixel_error_metric_320_640: 155.8870 - val_loss: 0.0833 - val_mean_pixel_error_metric_320_640: 154.8645
# Epoch 15/100
# 186/186 ━━━━━━━━━━━━━━━━━━━━ 100s 536ms/step - loss: 0.0845 - mean_pixel_error_metric_320_640: 155.8557 - val_loss: 0.0834 - val_mean_pixel_error_metric_320_640: 154.9678
# Epoch 16/100
# 186/186 ━━━━━━━━━━━━━━━━━━━━ 101s 542ms/step - loss: 0.0846 - mean_pixel_error_metric_320_640: 155.9694 - val_loss: 0.0834 - val_mean_pixel_error_metric_320_640: 155.0159
# Epoch 17/100
# 186/186 ━━━━━━━━━━━━━━━━━━━━ 101s 542ms/step - loss: 0.0845 - mean_pixel_error_metric_320_640: 155.9512 - val_loss: 0.0835 - val_mean_pixel_error_metric_320_640: 155.0903
# Epoch 18/100
# 186/186 ━━━━━━━━━━━━━━━━━━━━ 101s 541ms/step - loss: 0.0845 - mean_pixel_error_metric_320_640: 156.0252 - val_loss: 0.0835 - val_mean_pixel_error_metric_320_640: 155.0684
# Epoch 19/100
# 186/186 ━━━━━━━━━━━━━━━━━━━━ 101s 542ms/step - loss: 0.0849 - mean_pixel_error_metric_320_640: 156.2337 - val_loss: 0.0835 - val_mean_pixel_error_metric_320_640: 155.0106
# Epoch 20/100
# 186/186 ━━━━━━━━━━━━━━━━━━━━ 100s 537ms/step - loss: 0.0846 - mean_pixel_error_metric_320_640: 156.1882 - val_loss: 0.0836 - val_mean_pixel_error_metric_320_640: 155.1701
# Epoch 20: early stopping
# Restoring model weights from the end of the best epoch: 10.

# %% [markdown]
# plot loss for train and evaluation

# %%
fig, ax1 = plt.subplots(figsize=(8, 5))

# y1: loss
ax1.plot(history.history['loss'], label='Train Loss', linestyle='-', color='black')
ax1.plot(history.history['val_loss'], label='Val Loss', linestyle='-', color='gray')
ax1.set_xlabel('Epochs', color='black')
ax1.set_ylabel('Loss', color='black')
ax1.tick_params(axis='y', labelcolor='black')
ax1.tick_params(axis='x', labelcolor='black')

# y2: MPE
ax2 = ax1.twinx()
ax2.plot(history.history['mean_pixel_error_metric_320_640'], label='Train MPE', linestyle='--', color='black')
ax2.plot(history.history['val_mean_pixel_error_metric_320_640'], label='Val MPE', linestyle='--', color='gray')
ax2.set_ylabel('Mean Pixel Error [px]', color='black')
ax2.tick_params(axis='y', labelcolor='black')

lines_1, labels_1 = ax1.get_legend_handles_labels()
lines_2, labels_2 = ax2.get_legend_handles_labels()
ax1.legend(lines_1 + lines_2, labels_1 + labels_2, loc='upper right')

plt.title("Training Loss & Mean Pixel Error", color='black')
plt.show()

# %% [markdown]
# mini evaluation test set

# %%
#mpe +- std
pred_coords_norm = model.predict(X_test)
# Out:
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 42s 811ms/step

# %%
distances = np.linalg.norm(y_test - pred_coords_norm, axis=-1)

# %%
# image size
H, W = 320, 640

# convert to pixel size
diff_pixel = (y_test - pred_coords_norm) * np.array([H, W])
distances_pixel = np.linalg.norm(diff_pixel, axis=-1)

# prediction errors
mpe_mean = distances_pixel.mean()
mpe_std = distances_pixel.std()
mpe_median = np.median(distances_pixel)

print(f"Mean Prediction Error (MPE) in pixels: {mpe_mean:.2f} ± {mpe_std:.2f}")
print(f"Median Prediction Error in pixels: {mpe_median:.2f}")
# Out:
# Mean Prediction Error (MPE) in pixels: 79.15 ± 49.16
# Median Prediction Error in pixels: 62.98

# %% [markdown]
# save predictions in normalized pixel coords for evaluation

# %%
save_dir2 = '/content/drive/MyDrive/Arlette/Model_Outputs'
os.makedirs(save_dir2, exist_ok=True)
np.save(f"{save_dir2}/predictions_norm_CNN_full_augmentation_320_640.npy", pred_coords_norm)

# %% [markdown]
# save model weights and output

# %%
#save best config based on validation loss

# %%
save_dir = '/content/drive/MyDrive/Arlette/model_weights'
os.makedirs(save_dir, exist_ok=True)

model.save(f'{save_dir}/CNN_full_augmentation_320_640.keras')
model.save_weights(f'{save_dir}/CNN_full_augmentation_320_640.weights.h5')
